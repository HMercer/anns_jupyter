# %%
import numpy as np
import tensorflow as tf
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
from utils import shuffle_batch, variable_summaries
import os

# %matplotlib notebook

dir_path = os.getcwd()

now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)
print(dir_path)
# Out:
# C:\Users\kicjo\Desktop\my-anns\nuclei-first

# %%
df = pd.read_csv("nuclei.csv")
print(df.info())
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 4 columns):
# N             3179 non-null int64
# Z             3179 non-null int64
# D to use      3179 non-null float64
# Unnamed: 3    0 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 99.4 KB
# None
# Index(['N', 'Z', 'D to use', 'Unnamed: 3'], dtype='object')

# %%
df = df.rename(columns={"D to use": "d", "Z":'z', 'N':'n'})

# %%
df = df.drop(df.columns[3], axis='columns')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 3 columns):
# n    3179 non-null int64
# z    3179 non-null int64
# d    3179 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 74.6 KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['z'].shape
# Out:
# (3179,)

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = df['n']
ys = df['z']
zs = df['d']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy as np

data = list(zip(df['n'],df['z'],df['d']))
print(len(data))
x, y, z = zip(*data)
zs = list(df['d'].to_numpy())

z = list(map(float, z))
grid_x, grid_y = np.mgrid[min(x):max(x):100j, min(y):max(y):100j]
grid_z = griddata((x, y), z, (grid_x, grid_y), method='cubic')

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(grid_x, grid_y, grid_z, cmap=plt.cm.hsv)
plt.show()
# Out:
# 3179
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Z contains NaN values. This may result in rendering artifacts.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colors.py:479: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
from scipy.interpolate import griddata

x= df['n'].to_numpy()
y= df['z'].to_numpy()
z= df['d'].to_numpy()
fig = plt.figure()
ax = fig.gca(projection='3d')
xi = np.linspace(x.min(), x.max(), 50)
yi = np.linspace(y.min(), y.max(), 50)
zi = griddata((x, y), z, (xi[None, :], yi[:, None]), method='nearest')    # create a uniform spaced grid
xig, yig = np.meshgrid(xi, yi)
surf = ax.plot_wireframe(X=xig, Y=yig, Z=zi, rstride=5, cstride=3, linewidth=1,cmap=plt.cm.hsv)   # 3d plot
plt.show()

# %%
fig, (ax)=plt.subplots(ncols=1)
ax.tripcolor(df["n"], df["z"], df["d"])
#ax2.set_title("tricontour")
#ax2.tricontourf(df["n"], df["z"], df["d"])

plt.show()

# %%
x = df.drop('d', axis='columns')
print(x.info())
x = x.to_numpy()
print(x.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 2 columns):
# n    3179 non-null int64
# z    3179 non-null int64
# dtypes: int64(2)
# memory usage: 49.8 KB
# None
# (3179, 2)

# %%
y = df['d'].to_numpy()
y = y.reshape(-1,1)
y.shape
# Out:
# (3179, 1)

# %%
X_train_o, X_test_o, y_train_o, y_test_o = train_test_split(x, y, test_size=0.2, random_state=1)
X_train_o, X_val_o, y_train_o, y_val_o  = train_test_split(X_train_o, y_train_o, test_size=0.2, random_state=1)
n_inputs = X_train_o.shape[1]
n_outputs = y_train_o.shape[1]
print(n_inputs)
print(n_outputs)
# Out:
# 2
# 1

# %%
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train_o.reshape(-1, n_inputs))
X_test = x_scaler.transform(X_test_o.reshape(-1, n_inputs))
X_val = x_scaler.transform(X_val_o.reshape(-1, n_inputs))

y_train = y_scaler.fit_transform(y_train_o.reshape(-1, n_outputs))
y_test = y_scaler.transform(y_test_o.reshape(-1, n_outputs))
y_val = y_scaler.transform(y_val_o.reshape(-1, n_outputs))

n_inputs = X_train.shape[1]
n_outputs = y_train.shape[1]
print(n_inputs)
print(n_outputs)
# Out:
# 2
# 1

# %%
def cust_layer(inputs,number_of_neurons, name, activation=None, dropout=False):
    init = tf.initializers.he_normal(seed=None)
    hidden = tf.keras.layers.Dense(number_of_neurons,
                                   name=name,
                                    kernel_initializer=init,
                                   activation = activation,
                                   kernel_regularizer = tf.keras.regularizers.l1(l=0.01)
                                  )(inputs)
    
    batch_norm = tf.keras.layers.BatchNormalization()(hidden, training=True)
    
    if dropout:
        dropout_layer = tf.keras.layers.Dropout(0.5)(batch_norm)
        return dropout_layer
    else:
        return batch_norm
    
tf.reset_default_graph()
with tf.name_scope("dnn"):
    with tf.name_scope("inputs"):
        X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
        y = tf.placeholder(tf.float32, shape=(None, n_outputs), name="y")
    
    init = tf.initializers.he_normal(seed=None)    
    hidden1 = tf.keras.layers.Dense(20, name="hidden1",
                                    kernel_initializer=init)(X)    
    batch_norm_1 = tf.keras.layers.BatchNormalization()(hidden1, training=True)    
    dropout1 = tf.keras.layers.Dropout(0.5)(batch_norm_1)
        
    
    last_layer = cust_layer(X,20,"hidden1")
    
    n_layers = 5
    
    for i in range(n_layers):
        is_odd = False
            
        last_layer = cust_layer(last_layer,50,"hidden"+str(i),activation=tf.nn.elu,dropout=True)
   
    
    y_pred = tf.keras.layers.Dense(1, name="output",
                                   kernel_initializer=init)(last_layer)

with tf.name_scope('MSE'):
    error = y_pred - y
    mse = tf.reduce_mean(tf.square(error), name="mse")
    variable_summaries(mse)


with tf.name_scope('optimiser'):
    optimiser = tf.train.AdamOptimizer(0.01)
    training_op = optimiser.minimize(mse)

for var in tf.trainable_variables():
    tf.summary.histogram(var.name, var)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0812 16:36:46.402194 24332 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei-first\utils.py:16: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0812 16:36:46.415160 24332 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei-first\utils.py:22: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# W0812 16:36:47.455951 24332 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
test_writer = tf.summary.FileWriter(logdir + '/test')
valid_writer = tf.summary.FileWriter(logdir + '/valid')
init = tf.global_variables_initializer()

saver = tf.train.Saver()

checkpoint_path = os.path.join(dir_path, "sinus_tmp","sinus_full_model.ckpt")
checkpoint_epoch_path = checkpoint_path + ".epoch"
final_model_path = os.path.join(dir_path, "model", "my_sinus_full_model")

# %%
n_epochs = 600
n_batches = 50

best_loss = np.infty
epochs_without_progress = 0
max_epochs_without_progress = n_epochs * 0.4
print(max_epochs_without_progress)
# Out:
# 240.0

# %%
with tf.Session() as sess:
    if os.path.isfile(checkpoint_epoch_path):
        # if the checkpoint file exists, restore the model and load the epoch number
        with open(checkpoint_epoch_path, "rb") as f:
            start_epoch = int(f.read())
        print("Training was interrupted. Continuing at epoch", start_epoch)
        saver.restore(sess, checkpoint_path)
    else:
        start_epoch = 0
        sess.run(init)

    for epoch in range(start_epoch, n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, n_batches):
            summary, _ = sess.run([merged, training_op],
                                  feed_dict={X: X_batch, y: y_batch})

        train_summary, _ = sess.run([merged, training_op],feed_dict={X: X_train, y: y_train})
        test_summary, _ =sess.run([merged, training_op],feed_dict={X: X_test, y: y_test})
        validation_summary, _ = sess.run([merged, training_op], feed_dict={X: X_val, y: y_val})

        train_writer.add_summary(train_summary, epoch)
        test_writer.add_summary(test_summary, epoch)
        valid_writer.add_summary(validation_summary,epoch)

        loss_train = mse.eval(feed_dict={X: X_train, y: y_train})
        loss_val = mse.eval(feed_dict={X: X_val, y: y_val})
        print(epoch, "train loss:", loss_train, "valid loss:", loss_val)

        iteration_skip = 10
        if epoch % iteration_skip == 0:
            saver.save(sess, checkpoint_path)
            with open(checkpoint_epoch_path, "wb") as f:
                f.write(b"%d" % (epoch + 1))

            if loss_val < best_loss:
                saver.save(sess, final_model_path)
                best_loss = loss_val
                print("best loss:", best_loss)
            else:
                epochs_without_progress += iteration_skip
                if epochs_without_progress > max_epochs_without_progress:
                    print("Early stopping")
                    break


train_writer.close()
test_writer.close()
valid_writer.close()
# Out:
# 0 train loss: 40.940884 valid loss: 40.93649
# best loss: 40.93649
# 1 train loss: 17.805553 valid loss: 17.809183
# 2 train loss: 9.003193 valid loss: 8.996378
# 3 train loss: 4.221793 valid loss: 4.212553
# 4 train loss: 2.4645555 valid loss: 2.4559124
# 5 train loss: 1.7929455 valid loss: 1.7838589
# 6 train loss: 1.4004462 valid loss: 1.3982286
# 7 train loss: 1.3110683 valid loss: 1.3089722
# 8 train loss: 1.1949255 valid loss: 1.192082
# 9 train loss: 1.1257359 valid loss: 1.117425
# 10 train loss: 1.1587216 valid loss: 1.1543149
# best loss: 1.1543149
# 11 train loss: 1.0764674 valid loss: 1.0732177
# 12 train loss: 1.1073961 valid loss: 1.1074438
# 13 train loss: 1.0368373 valid loss: 1.03596
# 14 train loss: 1.076941 valid loss: 1.0739701
# 15 train loss: 1.0463632 valid loss: 1.0458632
# 16 train loss: 1.0912124 valid loss: 1.08276
# 17 train loss: 1.1268642 valid loss: 1.1230987
# 18 train loss: 1.136372 valid loss: 1.1237974
# 19 train loss: 1.0928807 valid loss: 1.0902227
# 20 train loss: 1.0766671 valid loss: 1.0756342
# best loss: 1.0756342
# 21 train loss: 1.0841162 valid loss: 1.0854214
# 22 train loss: 1.0719765 valid loss: 1.0668591
# 23 train loss: 1.1429051 valid loss: 1.1341382
# 24 train loss: 1.0848534 valid loss: 1.0858004
# 25 train loss: 1.1218193 valid loss: 1.1181854
# 26 train loss: 1.0802466 valid loss: 1.0779147
# 27 train loss: 1.1052598 valid loss: 1.1028492
# 28 train loss: 1.1040806 valid loss: 1.1044543
# 29 train loss: 1.0876185 valid loss: 1.0850462
# 30 train loss: 1.1733632 valid loss: 1.1632388
# 31 train loss: 1.0859743 valid loss: 1.0843778
# 32 train loss: 1.1102116 valid loss: 1.1085452
# 33 train loss: 1.0910302 valid loss: 1.0936642
# 34 train loss: 1.1142454 valid loss: 1.1054968
# 35 train loss: 1.1191752 valid loss: 1.11501
# 36 train loss: 1.1193241 valid loss: 1.114244
# 37 train loss: 1.1217184 valid loss: 1.1162143
# 38 train loss: 1.1047779 valid loss: 1.1028539
# 39 train loss: 1.1080674 valid loss: 1.1058302
# 40 train loss: 1.2186596 valid loss: 1.2069367
# 41 train loss: 1.112232 valid loss: 1.1123923
# 42 train loss: 1.1309595 valid loss: 1.1263663
# 43 train loss: 1.115436 valid loss: 1.1118883
# 44 train loss: 1.1190968 valid loss: 1.1162195
# 45 train loss: 1.1418018 valid loss: 1.1425229
# 46 train loss: 1.1289015 valid loss: 1.1246511
# 47 train loss: 1.1723951 valid loss: 1.1718154
# 48 train loss: 1.1260115 valid loss: 1.1234969
# 49 train loss: 1.1600914 valid loss: 1.1555364
# 50 train loss: 1.1694148 valid loss: 1.1670817
# 51 train loss: 1.1377938 valid loss: 1.1330897
# 52 train loss: 1.1445489 valid loss: 1.1432666
# 53 train loss: 1.1344666 valid loss: 1.1270437
# 54 train loss: 1.1547762 valid loss: 1.1462096
# 55 train loss: 1.1091897 valid loss: 1.106756
# 56 train loss: 1.1502447 valid loss: 1.1487614
# 57 train loss: 1.1111965 valid loss: 1.108384
# 58 train loss: 1.1172363 valid loss: 1.1145147
# 59 train loss: 1.1240864 valid loss: 1.1177267
# 60 train loss: 1.125805 valid loss: 1.1220024
# 61 train loss: 1.1581612 valid loss: 1.150304
# 62 train loss: 1.1458567 valid loss: 1.1409203
# 63 train loss: 1.1707628 valid loss: 1.164653
# 64 train loss: 1.1194706 valid loss: 1.1205018
# 65 train loss: 1.1476778 valid loss: 1.1456805
# 66 train loss: 1.1341726 valid loss: 1.1320919
# 67 train loss: 1.130742 valid loss: 1.1263762
# 68 train loss: 1.1385767 valid loss: 1.1377468
# 69 train loss: 1.1314616 valid loss: 1.1268648
# 70 train loss: 1.1731145 valid loss: 1.1647949
# 71 train loss: 1.1181427 valid loss: 1.1182246
# 72 train loss: 1.1682315 valid loss: 1.17065
# 73 train loss: 1.1323507 valid loss: 1.1297506
# 74 train loss: 1.1482294 valid loss: 1.1406599
# 75 train loss: 1.1425564 valid loss: 1.1396638
# 76 train loss: 1.1524858 valid loss: 1.1497865
# 77 train loss: 1.1438965 valid loss: 1.1370658
# 78 train loss: 1.1292495 valid loss: 1.1269192
# 79 train loss: 1.1447356 valid loss: 1.1408501
# 80 train loss: 1.153297 valid loss: 1.1495657
# 81 train loss: 1.1534451 valid loss: 1.1552926
# 82 train loss: 1.1232469 valid loss: 1.1237947
# 83 train loss: 1.1565366 valid loss: 1.152703
# 84 train loss: 1.1308066 valid loss: 1.1338762
# 85 train loss: 1.144181 valid loss: 1.1457915
# 86 train loss: 1.1661928 valid loss: 1.1591868
# 87 train loss: 1.1331153 valid loss: 1.1260979
# 88 train loss: 1.157744 valid loss: 1.1491841
# 89 train loss: 1.1119229 valid loss: 1.1114855
# 90 train loss: 1.1511712 valid loss: 1.1495464
# 91 train loss: 1.1658609 valid loss: 1.1614376
# 92 train loss: 1.2058053 valid loss: 1.1990094
# 93 train loss: 1.1728956 valid loss: 1.1641152
# 94 train loss: 1.1597228 valid loss: 1.1540303
# 95 train loss: 1.2280009 valid loss: 1.216079
# 96 train loss: 1.1305552 valid loss: 1.128459
# 97 train loss: 1.1376472 valid loss: 1.1346455
# 98 train loss: 1.1553454 valid loss: 1.1474276
# 99 train loss: 1.1484383 valid loss: 1.1437963
# 100 train loss: 1.1476237 valid loss: 1.1427453
# 101 train loss: 1.1299727 valid loss: 1.1329099
# 102 train loss: 1.2563633 valid loss: 1.2422743
# 103 train loss: 1.1415038 valid loss: 1.1411971
# 104 train loss: 1.1802124 valid loss: 1.1736339
# 105 train loss: 1.145561 valid loss: 1.1417677
# 106 train loss: 1.1645558 valid loss: 1.1547825
# 107 train loss: 1.1511146 valid loss: 1.1473687
# 108 train loss: 1.1521326 valid loss: 1.1524111
# 109 train loss: 1.1231515 valid loss: 1.1246611
# 110 train loss: 1.1271292 valid loss: 1.1226025
# 111 train loss: 1.1475883 valid loss: 1.1435084
# 112 train loss: 1.1367782 valid loss: 1.1308954
# 113 train loss: 1.1381818 valid loss: 1.1403022
# 114 train loss: 1.1527151 valid loss: 1.1528808
# 115 train loss: 1.1307843 valid loss: 1.127166
# 116 train loss: 1.1556927 valid loss: 1.1491003
# 117 train loss: 1.1749184 valid loss: 1.1683497
# 118 train loss: 1.1785367 valid loss: 1.1696221
# 119 train loss: 1.13143 valid loss: 1.1300972
# 120 train loss: 1.1642778 valid loss: 1.1653448
# 121 train loss: 1.1427146 valid loss: 1.1382318
# 122 train loss: 1.1745648 valid loss: 1.1787981
# 123 train loss: 1.1465621 valid loss: 1.1406024
# 124 train loss: 1.1312804 valid loss: 1.130955
# 125 train loss: 1.1603442 valid loss: 1.1546017
# 126 train loss: 1.1452274 valid loss: 1.1414983
# 127 train loss: 1.1610515 valid loss: 1.1607502
# 128 train loss: 1.1408082 valid loss: 1.1406064
# 129 train loss: 1.1398952 valid loss: 1.1339787
# 130 train loss: 1.1371901 valid loss: 1.1300272
# 131 train loss: 1.1496139 valid loss: 1.1471714
# 132 train loss: 1.1347628 valid loss: 1.1318153
# 133 train loss: 1.1655041 valid loss: 1.1583928
# 134 train loss: 1.1426457 valid loss: 1.1403788
# 135 train loss: 1.1491585 valid loss: 1.1445485
# 136 train loss: 1.1553009 valid loss: 1.1461833
# 137 train loss: 1.1331749 valid loss: 1.1282588
# 138 train loss: 1.1320863 valid loss: 1.1330919
# 139 train loss: 1.2573168 valid loss: 1.242857
# 140 train loss: 1.1658233 valid loss: 1.1594675
# 141 train loss: 1.1298541 valid loss: 1.1255522
# 142 train loss: 1.2570435 valid loss: 1.2569132
# 143 train loss: 1.1352066 valid loss: 1.1343197
# 144 train loss: 1.1376544 valid loss: 1.138151
# 145 train loss: 1.1449543 valid loss: 1.1376879
# 146 train loss: 1.1490747 valid loss: 1.1445107
# 147 train loss: 1.1393942 valid loss: 1.1376286
# 148 train loss: 1.1867608 valid loss: 1.1840801
# 149 train loss: 1.1720328 valid loss: 1.1710287
# 150 train loss: 1.1256613 valid loss: 1.1253312
# 151 train loss: 1.1360112 valid loss: 1.136764
# 152 train loss: 1.2018913 valid loss: 1.1912016
# 153 train loss: 1.1850326 valid loss: 1.1777081
# 154 train loss: 1.1366881 valid loss: 1.1323199
# 155 train loss: 1.1440938 valid loss: 1.1462711
# 156 train loss: 1.141269 valid loss: 1.1387023
# 157 train loss: 1.139601 valid loss: 1.1348956
# 158 train loss: 1.1113697 valid loss: 1.1107042
# 159 train loss: 1.2313147 valid loss: 1.222372
# 160 train loss: 1.1272411 valid loss: 1.1269486
# 161 train loss: 1.130467 valid loss: 1.1278278
# 162 train loss: 1.1387366 valid loss: 1.137116
# 163 train loss: 1.1561604 valid loss: 1.1514671
# 164 train loss: 1.1490155 valid loss: 1.1419923
# 165 train loss: 1.1638513 valid loss: 1.1629019
# 166 train loss: 1.1381207 valid loss: 1.1334794
# 167 train loss: 1.1675764 valid loss: 1.1636341
# 168 train loss: 1.1270218 valid loss: 1.1234719
# 169 train loss: 1.1319808 valid loss: 1.1333002
# 170 train loss: 1.1564142 valid loss: 1.1519575
# 171 train loss: 1.1739484 valid loss: 1.16951
# 172 train loss: 1.2125467 valid loss: 1.2048769
# 173 train loss: 1.1353742 valid loss: 1.1341165
# 174 train loss: 1.1684955 valid loss: 1.1574552
# 175 train loss: 1.2102275 valid loss: 1.2110789
# 176 train loss: 1.1377802 valid loss: 1.1331048
# 177 train loss: 1.1533207 valid loss: 1.1477602
# 178 train loss: 1.1915282 valid loss: 1.1838851
# 179 train loss: 1.1220385 valid loss: 1.1236199
# 180 train loss: 1.1654686 valid loss: 1.1585902
# 181 train loss: 1.1246926 valid loss: 1.1215264
# 182 train loss: 1.1721737 valid loss: 1.1663942
# 183 train loss: 1.1484034 valid loss: 1.1438415
# 184 train loss: 1.139985 valid loss: 1.1383164
# 185 train loss: 1.2164645 valid loss: 1.215212
# 186 train loss: 1.1420556 valid loss: 1.1414729
# 187 train loss: 1.1426089 valid loss: 1.1330115
# 188 train loss: 1.1392592 valid loss: 1.1366906
# 189 train loss: 1.2120017 valid loss: 1.1987605
# 190 train loss: 1.15543 valid loss: 1.1507101
# 191 train loss: 1.1199241 valid loss: 1.1160959
# 192 train loss: 1.1247259 valid loss: 1.1198539
# 193 train loss: 1.1549859 valid loss: 1.1537395
# 194 train loss: 1.1499732 valid loss: 1.1491226
# 195 train loss: 1.1634382 valid loss: 1.1609383
# 196 train loss: 1.1558048 valid loss: 1.151813
# 197 train loss: 1.1309633 valid loss: 1.1277869
# 198 train loss: 1.1552758 valid loss: 1.1493028
# 199 train loss: 1.1438551 valid loss: 1.1443688
# 200 train loss: 1.1575325 valid loss: 1.1522906
# 201 train loss: 1.1596076 valid loss: 1.1564096
# 202 train loss: 1.1285129 valid loss: 1.1248176
# 203 train loss: 1.1576889 valid loss: 1.1549305
# 204 train loss: 1.1423942 valid loss: 1.1365583
# 205 train loss: 1.1303154 valid loss: 1.1292444
# 206 train loss: 1.1332536 valid loss: 1.1284189
# 207 train loss: 1.1291283 valid loss: 1.1269523
# 208 train loss: 1.1366975 valid loss: 1.1367933
# 209 train loss: 1.132433 valid loss: 1.128429
# 210 train loss: 1.1344458 valid loss: 1.1306218
# 211 train loss: 1.1779019 valid loss: 1.1707418
# 212 train loss: 1.1227387 valid loss: 1.1212157
# 213 train loss: 1.151743 valid loss: 1.1466569
# 214 train loss: 1.161933 valid loss: 1.163461
# 215 train loss: 1.1530355 valid loss: 1.1518904
# 216 train loss: 1.1636449 valid loss: 1.1565112
# 217 train loss: 1.1634903 valid loss: 1.1620158
# 218 train loss: 1.139202 valid loss: 1.1422585
# 219 train loss: 1.1613977 valid loss: 1.1617898
# 220 train loss: 1.1690121 valid loss: 1.1656401
# 221 train loss: 1.1498077 valid loss: 1.1451465
# 222 train loss: 1.1454289 valid loss: 1.1452341
# 223 train loss: 1.1927657 valid loss: 1.1908189
# 224 train loss: 1.1326362 valid loss: 1.1275163
# 225 train loss: 1.1241243 valid loss: 1.1248685
# 226 train loss: 1.1525719 valid loss: 1.1560823
# 227 train loss: 1.2444011 valid loss: 1.2332385
# 228 train loss: 1.139873 valid loss: 1.13848
# 229 train loss: 1.1553626 valid loss: 1.1552665
# 230 train loss: 1.1280681 valid loss: 1.122894
# 231 train loss: 1.1443789 valid loss: 1.1418389
# 232 train loss: 1.2184979 valid loss: 1.2108542
# 233 train loss: 1.1596489 valid loss: 1.1495761
# 234 train loss: 1.1427433 valid loss: 1.1347893
# 235 train loss: 1.1248506 valid loss: 1.1238042
# 236 train loss: 1.1169075 valid loss: 1.1162705
# 237 train loss: 1.2092197 valid loss: 1.2071542
# 238 train loss: 1.1490412 valid loss: 1.1479057
# 239 train loss: 1.154297 valid loss: 1.1493868
# 240 train loss: 1.1768997 valid loss: 1.1718535
# 241 train loss: 1.1593442 valid loss: 1.1532751
# 242 train loss: 1.1887996 valid loss: 1.1796889
# 243 train loss: 1.1721585 valid loss: 1.1674289
# 244 train loss: 1.1346095 valid loss: 1.132478
# 245 train loss: 1.1554224 valid loss: 1.1595241
# 246 train loss: 1.2346531 valid loss: 1.2260032
# 247 train loss: 1.1487039 valid loss: 1.1477238
# 248 train loss: 1.1302702 valid loss: 1.1273875
# 249 train loss: 1.1782316 valid loss: 1.172893
# 250 train loss: 1.1404927 valid loss: 1.1414402
# 251 train loss: 1.1141725 valid loss: 1.1153197
# 252 train loss: 1.1425922 valid loss: 1.1428169
# 253 train loss: 1.1272141 valid loss: 1.1262331
# 254 train loss: 1.1611394 valid loss: 1.1615571
# 255 train loss: 1.2337037 valid loss: 1.2231686
# 256 train loss: 1.1337544 valid loss: 1.1358819
# 257 train loss: 1.1466781 valid loss: 1.139841
# 258 train loss: 1.1238536 valid loss: 1.1250567
# 259 train loss: 1.1358224 valid loss: 1.137664
# 260 train loss: 1.1296146 valid loss: 1.1257429
# 261 train loss: 1.1407449 valid loss: 1.1351879
# 262 train loss: 1.2014804 valid loss: 1.1994892
# 263 train loss: 1.1578361 valid loss: 1.1548859
# 264 train loss: 1.1876614 valid loss: 1.1784805
# 265 train loss: 1.1467743 valid loss: 1.1433074
# 266 train loss: 1.1592015 valid loss: 1.1494333
# 267 train loss: 1.133756 valid loss: 1.1301632
# 268 train loss: 1.1315713 valid loss: 1.1292338
# 269 train loss: 1.1399679 valid loss: 1.1367805
# 270 train loss: 1.1234361 valid loss: 1.1246191
# Early stopping

# %%
os.remove(checkpoint_epoch_path)

# %%
with tf.Session() as sess:
    saver.restore(sess, final_model_path)
    test_mse = mse.eval(feed_dict={X: X_test, y: y_test})
    predictions = y_pred.eval(feed_dict={X: X_test, y: y_test})
    
    
print(test_mse)
# Out:
# W0812 16:37:56.689124 24332 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 1.0686553

# %%
x_test_inverse = x_scaler.inverse_transform(X_test)
x_test_inverse.shape
# Out:
# (636, 2)

# %%
x_test_inverse[:,0].shape
# Out:
# (636,)

# %%
y_new_inverse = y_scaler.inverse_transform(predictions)
y_new_inverse.shape
# Out:
# (636, 1)

# %%
y_new_inverse[:,0].shape
# Out:
# (636,)

# %%
y_new_inverse = y_scaler.inverse_transform(predictions)
x_test_inverse = x_scaler.inverse_transform(X_test)

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = y_new_inverse[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
diff = (y_new_inverse - y_test_o) / y_test_o
diff_abs = y_new_inverse - y_test_o
print(diff[:5])
reshaped_diff = diff.reshape(-1,1)[:,0]
print(reshaped_diff.shape)
print(reshaped_diff[:5])
# Out:
# [[ 0.2046108 ]
#  [-0.20577274]
#  [-0.09088206]
#  [ 0.02583438]
#  [ 0.09844481]]
# (636,)
# [ 0.2046108  -0.20577274 -0.09088206  0.02583438  0.09844481]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
df = pd.DataFrame(data={'diff': reshaped_diff})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 1 columns):
# diff    636 non-null float64
# dtypes: float64(1)
# memory usage: 5.0 KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.max()
# Out:
# diff    inf
# dtype: float64

# %%
#df = df.replace([np.inf, -np.inf], 0)

# %%
df.describe()
# Out:
#              diff
# count  636.000000
# mean          inf
# std           NaN
# min   -982.995653
# 25%     -0.209075
# 50%     -0.095373
# 75%      0.066363
# max           inf

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = diff[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.5)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in true_divide
#   if sys.path[0] == '':
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colors.py:479: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
range_x = x_test_inverse.shape[0]
range_x
# Out:
# 636

# %%
iterate_x = list(range(0,range_x))
len(iterate_x)
# Out:
# 636

# %%
diff[:,0].shape
# Out:
# (636,)

# %%
plt.scatter(iterate_x, diff[:,0], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %%
plt.scatter(iterate_x, diff_abs[:,0], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %%
 y_new_inverse[304]
# Out:
# array([26341.984], dtype=float32)

# %%
 y_test_o[304]
# Out:
# array([59364.01])
