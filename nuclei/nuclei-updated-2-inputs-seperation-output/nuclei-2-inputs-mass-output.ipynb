# %% [markdown]
# # Two imputs (N,Z) and 1 outputs (Seperation energy) in single ANN

# %% [markdown]
# # Imports

# %%
import numpy as np
import tensorflow as tf
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
from utils import shuffle_batch, variable_summaries
import os

# %matplotlib notebook

dir_path = os.getcwd()

now = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)
print(dir_path)
print(now)
# Out:
# C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-seperation-output
# 2019-08-20-18-24-07

# %%
#%matplotlib notebook

# %% [markdown]
# # Read the data set

# %%
df = pd.read_csv("better-nuclei-19-08.csv")
print(df.info())
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436 entries, 0 to 3435
# Data columns (total 10 columns):
# Z                                  3436 non-null int64
# N                                  3436 non-null int64
# UQ                                 3436 non-null int64
# DQ                                 3436 non-null int64
# Mass Excess [MeV]                  3436 non-null float64
# Mass Error                         3436 non-null float64
# Mass Estimated                     3436 non-null int64
# Neutron separation energy [MeV]    3318 non-null float64
# Separation Error                   3318 non-null float64
# Separation Estimated               3318 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 268.5 KB
# None
# Index(['Z', 'N', 'UQ', 'DQ', 'Mass Excess [MeV]', 'Mass Error',
#        'Mass Estimated', 'Neutron separation energy [MeV]', 'Separation Error',
#        'Separation Estimated'],
#       dtype='object')

# %%
df = df.rename(columns=
               {"Mass Excess [MeV]": "d",
                "Z":'z',
                'N':'n',
                'UQ':"uq",
                'DQ':"dq",
                "Mass Error":"mass error",
                "Mass Estimated":"mass estimated",
                "Neutron separation energy [MeV]":"d2",
                "Separation Error":"separation error",
                "Separation Estimated":"separation estimated"               
               })
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436 entries, 0 to 3435
# Data columns (total 10 columns):
# z                       3436 non-null int64
# n                       3436 non-null int64
# uq                      3436 non-null int64
# dq                      3436 non-null int64
# d                       3436 non-null float64
# mass error              3436 non-null float64
# mass estimated          3436 non-null int64
# d2                      3318 non-null float64
# separation error        3318 non-null float64
# separation estimated    3318 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 268.5 KB
# None

# %%
df.describe()
# Out:
#                  z            n           uq           dq            d  \
# count  3436.000000  3436.000000  3436.000000  3436.000000  3436.000000
# mean     57.857392    82.034051   197.748836   221.925495   -24.144121
# std      27.809406    43.293558    98.188326   113.771063    56.200706
# min       0.000000     0.000000     1.000000     1.000000   -91.652853
# 25%      36.000000    47.000000   120.750000   131.000000   -65.400443
# 50%      58.000000    81.000000   197.000000   219.000000   -39.335024
# 75%      80.000000   114.000000   273.000000   308.000000     1.172301
# max     118.000000   177.000000   413.000000   472.000000   201.512000
#
#         mass error  mass estimated           d2  separation error  \
# count  3436.000000     3436.000000  3318.000000       3318.000000
# mean      0.123589        0.272992     7.755557          0.164216
# std       0.197548        0.445562     3.631747          0.254378
# min       0.000000        0.000000    -2.488000          0.000000
# 25%       0.003006        0.000000     5.414787          0.005140
# 50%       0.014474        0.000000     7.249960          0.025005
# 75%       0.196000        1.000000     9.654658          0.269058
# max       2.003000        1.000000    27.715000          2.011000
#
#        separation estimated
# count           3318.000000
# mean               0.295660
# std                0.456408
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                1.000000
# max                1.000000

# %% [markdown]
# # Remove estimated Excess and estimated Seperation

# %%
not_estimated_filter = (df["mass estimated"] == 0)
df = df[not_estimated_filter]

not_estimated_filter = (df["separation estimated"] == 0)
df = df[not_estimated_filter]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 10 columns):
# z                       2337 non-null int64
# n                       2337 non-null int64
# uq                      2337 non-null int64
# dq                      2337 non-null int64
# d                       2337 non-null float64
# mass error              2337 non-null float64
# mass estimated          2337 non-null int64
# d2                      2337 non-null float64
# separation error        2337 non-null float64
# separation estimated    2337 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 200.8 KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['z'].shape
# Out:
# (2337,)

# %%
df.count()
# Out:
# z                       2337
# n                       2337
# uq                      2337
# dq                      2337
# d                       2337
# mass error              2337
# mass estimated          2337
# d2                      2337
# separation error        2337
# separation estimated    2337
# dtype: int64

# %%
df.head()
# Out:
#    z  n  uq  dq          d    mass error  mass estimated       d2  \
# 0  0  1   1   2   8.071317  4.000000e-07               0  0.00000
# 2  1  1   3   3  13.135722  1.000000e-07               0  2.22457
# 3  1  2   4   5  14.949810  2.000000e-07               0  6.25723
# 4  1  3   5   7  24.621127  1.000000e-01               0 -1.60000
# 5  1  4   6   9  32.892444  8.944300e-02               0 -0.20000
#
#    separation error  separation estimated
# 0           0.00000                   0.0
# 2           0.00000                   0.0
# 3           0.00000                   0.0
# 4           0.10000                   0.0
# 5           0.13416                   0.0

# %% [markdown]
# # Plot seperation energy column

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = df['n']
ys = df['z']
zs = df['d2']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D2')


plt.show()

# %%
df['d2'].to_numpy().shape
# Out:
# (2337,)

# %%
plt.scatter(range(df['d2'].count()), df['d2'].to_numpy(), s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Dividing Mass Excess by A = Z + N

# %%
zes = df['z'].to_numpy()
ns = df['n'].to_numpy()
a = zes + ns

des = df['d'].to_numpy() / a
df['d'] = des

# %% [markdown]
# # Plot Mass excess output column

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = df['n']
ys = df['z']
zs = df['d']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Tripcolor

# %%
zs = df['d']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

#yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)


fig, (ax)=plt.subplots(ncols=1)
ax.tripcolor(df["n"], df["z"], df["d"])
cb = fig.colorbar(colmap)

plt.show()

# %% [markdown]
# # Set X inputs

# %%
x = df[['z','n']]
print(x.info())
x = x.to_numpy()
print(x.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 2 columns):
# z    2337 non-null int64
# n    2337 non-null int64
# dtypes: int64(2)
# memory usage: 54.8 KB
# None
# (2337, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 10 columns):
# z                       2337 non-null int64
# n                       2337 non-null int64
# uq                      2337 non-null int64
# dq                      2337 non-null int64
# d                       2337 non-null float64
# mass error              2337 non-null float64
# mass estimated          2337 non-null int64
# d2                      2337 non-null float64
# separation error        2337 non-null float64
# separation estimated    2337 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 200.8 KB

# %% [markdown]
# # Set Y inputs _(HERE CHANGE NUMBER OF INPUTS AND RESHAPE)

# %%
y = df[['d2']].to_numpy() #HERE
y.shape
# Out:
# (2337, 1)

# %%
y = y.reshape(-1,1) #HERE
y.shape
# Out:
# (2337, 1)

# %%
y[0:5]
# Out:
# array([[ 0.     ],
#        [ 2.22457],
#        [ 6.25723],
#        [-1.6    ],
#        [-0.2    ]])

# %% [markdown]
# # Prepare X_train_o, Y_train_o etc

# %%
X_train_o, X_test_o, y_train_o, y_test_o = train_test_split(x, y, test_size=0.2, random_state=1)
X_train_o, X_val_o, y_train_o, y_val_o  = train_test_split(X_train_o, y_train_o, test_size=0.2, random_state=1)
n_inputs = X_train_o.shape[1]
n_outputs = y_train_o.shape[1]
print(n_inputs)
print(n_outputs)
print(X_train_o.shape, X_test_o.shape,X_val_o.shape)
# Out:
# 2
# 1
# (1495, 2) (468, 2) (374, 2)

# %% [markdown]
# # Scaling

# %%
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train_o.reshape(-1, n_inputs))
X_test = x_scaler.transform(X_test_o.reshape(-1, n_inputs))
X_val = x_scaler.transform(X_val_o.reshape(-1, n_inputs))

y_train = y_scaler.fit_transform(y_train_o.reshape(-1, n_outputs))
y_test = y_scaler.transform(y_test_o.reshape(-1, n_outputs))
y_val = y_scaler.transform(y_val_o.reshape(-1, n_outputs))

n_inputs = X_train.shape[1]
n_outputs = y_train.shape[1]
print(n_inputs)
print(n_outputs)
# Out:
# 2
# 1

# %% [markdown]
# # ANN TOPOLOGY

# %%
def cust_layer(inputs,number_of_neurons, name, activation=None, dropout=False):
    init = tf.initializers.he_normal(seed=None)
    hidden = tf.keras.layers.Dense(number_of_neurons,
                                   name=name,
                                    kernel_initializer=init,
                                   activation = activation,
                                   kernel_regularizer = tf.keras.regularizers.l2(l=0.1)
                                  )(inputs)
    
    batch_norm = tf.keras.layers.BatchNormalization()(hidden, training=True)
    
    if dropout:
        dropout_layer = tf.keras.layers.Dropout(0.5)(batch_norm)
        return dropout_layer
    else:
        return batch_norm
    
tf.reset_default_graph()
with tf.name_scope("dnn"):
    with tf.name_scope("inputs"):
        X_node = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
        y_node = tf.placeholder(tf.float32, shape=(None, n_outputs), name="y")
    
    last_layer = cust_layer(X_node,50,"hidden1")    
    n_layers = 10
    
    for i in range(n_layers):      
            
        last_layer = cust_layer(last_layer,150,"hidden"+str(i),activation=tf.nn.elu,dropout=True)
    last_layer = cust_layer(last_layer,50,"hidden"+str(i+1),activation=tf.nn.elu,dropout=True)
    
    init = tf.initializers.he_normal()    
    y_pred = tf.keras.layers.Dense(n_outputs, name="output",kernel_initializer=init)(last_layer)

    
with tf.name_scope('MSE'):
    error_f = y_pred - y_node
    square_f = tf.square(error_f)
    mse = tf.reduce_mean(square_f, name="mse_first")
    variable_summaries(mse)
    print(error_f.get_shape())


with tf.name_scope('optimiser'):
    optimiser = tf.train.AdamOptimizer(0.01)
    training_op = optimiser.minimize(mse)

for var in tf.trainable_variables():
    tf.summary.histogram(var.name, var)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0820 18:24:10.849406 16172 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-seperation-output\utils.py:16: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0820 18:24:10.862339 16172 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-seperation-output\utils.py:22: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
# (?, 1)

# %% [markdown]
# # File writers

# %%
merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
test_writer = tf.summary.FileWriter(logdir + '/test')
valid_writer = tf.summary.FileWriter(logdir + '/valid')
init = tf.global_variables_initializer()

saver = tf.train.Saver()

checkpoint_path = os.path.join(dir_path, "sinus_tmp","sinus_full_model.ckpt")
checkpoint_epoch_path = checkpoint_path + ".epoch"
final_model_path = os.path.join(dir_path, "model", "my_sinus_full_model")

# %% [markdown]
# # Number of epochs and batches

# %%
n_epochs = 2000
n_batches = 50

best_loss = np.infty
epochs_without_progress = 0
max_epochs_without_progress = n_epochs * 0.2
print(max_epochs_without_progress)
# Out:
# 400.0

# %% [markdown]
# # Training

# %%
with tf.Session() as sess:
    if os.path.isfile(checkpoint_epoch_path):
        # if the checkpoint file exists, restore the model and load the epoch number
        with open(checkpoint_epoch_path, "rb") as f:
            start_epoch = int(f.read())
        print("Training was interrupted. Continuing at epoch", start_epoch)
        saver.restore(sess, checkpoint_path)
    else:
        start_epoch = 0
        sess.run(init)

    for epoch in range(start_epoch, n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, n_batches):
            summary, _ = sess.run([merged, training_op],
                                  feed_dict={X_node: X_batch, y_node: y_batch})

        train_summary, _ = sess.run([merged, training_op],feed_dict={X_node: X_train, y_node: y_train})
        test_summary, _ =sess.run([merged, training_op],feed_dict={X_node: X_test, y_node: y_test})
        validation_summary, _ = sess.run([merged, training_op], feed_dict={X_node: X_val, y_node: y_val})

        train_writer.add_summary(train_summary, epoch)
        test_writer.add_summary(test_summary, epoch)
        valid_writer.add_summary(validation_summary,epoch)

        loss_train = mse.eval(feed_dict={X_node: X_train, y_node: y_train})
        loss_val = mse.eval(feed_dict={X_node: X_val, y_node: y_val})
        print(epoch, "train loss:", loss_train, "valid loss:", loss_val)

        iteration_skip = 10
        if epoch % iteration_skip == 0:
            saver.save(sess, checkpoint_path)
            with open(checkpoint_epoch_path, "wb") as f:
                f.write(b"%d" % (epoch + 1))

        if loss_val < best_loss:
            saver.save(sess, final_model_path)
            best_loss = loss_val
            print("best loss:", best_loss)
            epochs_without_progress = 0
        else:
            epochs_without_progress += 1
            if epochs_without_progress > max_epochs_without_progress:
                print("Early stopping")
                break


train_writer.close()
test_writer.close()
valid_writer.close()
# Out:
# 0 train loss: 0.27372384 valid loss: 0.29646596
# best loss: 0.29646596
# 1 train loss: 0.29105046 valid loss: 0.2860675
# best loss: 0.2860675
# 2 train loss: 0.2538244 valid loss: 0.27571598
# best loss: 0.27571598
# 3 train loss: 0.2235758 valid loss: 0.25487018
# best loss: 0.25487018
# 4 train loss: 0.29336518 valid loss: 0.37395322
# 5 train loss: 0.28493774 valid loss: 0.29599553
# 6 train loss: 0.28098932 valid loss: 0.3613977
# 7 train loss: 0.33428907 valid loss: 0.42896357
# 8 train loss: 0.22831973 valid loss: 0.2403899
# best loss: 0.2403899
# 9 train loss: 0.29420087 valid loss: 0.27772686
# 10 train loss: 0.24730232 valid loss: 0.22547339
# best loss: 0.22547339
# 11 train loss: 0.21314709 valid loss: 0.212606
# best loss: 0.212606
# 12 train loss: 0.4271794 valid loss: 0.52699816
# 13 train loss: 0.26822394 valid loss: 0.35840407
# 14 train loss: 0.2560456 valid loss: 0.23573387
# 15 train loss: 0.21722904 valid loss: 0.24605687
# 16 train loss: 0.24094461 valid loss: 0.236724
# 17 train loss: 0.24753039 valid loss: 0.2910469
# 18 train loss: 0.24078348 valid loss: 0.3022545
# 19 train loss: 0.22531238 valid loss: 0.2638785
# 20 train loss: 0.2162288 valid loss: 0.25003275
# 21 train loss: 0.23742256 valid loss: 0.23123407
# 22 train loss: 0.22264957 valid loss: 0.2427528
# 23 train loss: 0.3049971 valid loss: 0.37093848
# 24 train loss: 0.21188574 valid loss: 0.22717707
# 25 train loss: 0.22420825 valid loss: 0.2549211
# 26 train loss: 0.25416014 valid loss: 0.2701086
# 27 train loss: 0.238341 valid loss: 0.22738393
# 28 train loss: 0.22795926 valid loss: 0.28502822
# 29 train loss: 0.21013625 valid loss: 0.22714129
# 30 train loss: 0.31333402 valid loss: 0.27258414
# 31 train loss: 0.2197626 valid loss: 0.21682794
# 32 train loss: 0.22663839 valid loss: 0.26575628
# 33 train loss: 0.28271464 valid loss: 0.3027783
# 34 train loss: 0.26176098 valid loss: 0.25933117
# 35 train loss: 0.23992245 valid loss: 0.27361268
# 36 train loss: 0.21538384 valid loss: 0.25321648
# 37 train loss: 0.38402843 valid loss: 0.46101445
# 38 train loss: 0.2095493 valid loss: 0.21535286
# 39 train loss: 0.22657414 valid loss: 0.2643951
# 40 train loss: 0.24406579 valid loss: 0.25485983
# 41 train loss: 0.21729201 valid loss: 0.23830616
# 42 train loss: 0.21882644 valid loss: 0.24892795
# 43 train loss: 0.2599374 valid loss: 0.29738343
# 44 train loss: 0.23124559 valid loss: 0.21426868
# 45 train loss: 0.23680654 valid loss: 0.25707403
# 46 train loss: 0.23808086 valid loss: 0.2612937
# 47 train loss: 0.24130332 valid loss: 0.21239363
# best loss: 0.21239363
# 48 train loss: 0.22980879 valid loss: 0.24801585
# 49 train loss: 0.2195147 valid loss: 0.24251226
# 50 train loss: 0.21858686 valid loss: 0.24933125
# 51 train loss: 0.21817115 valid loss: 0.23637004
# 52 train loss: 0.21939076 valid loss: 0.25161204
# 53 train loss: 0.28350008 valid loss: 0.24236299
# 54 train loss: 0.20827071 valid loss: 0.21365446
# 55 train loss: 0.23975587 valid loss: 0.2634815
# 56 train loss: 0.22215638 valid loss: 0.25376177
# 57 train loss: 0.21798535 valid loss: 0.25067514
# 58 train loss: 0.22169983 valid loss: 0.24116798
# 59 train loss: 0.20377165 valid loss: 0.2145756
# 60 train loss: 0.20608233 valid loss: 0.22762656
# 61 train loss: 0.23793525 valid loss: 0.27714643
# 62 train loss: 0.22418086 valid loss: 0.24931253
# 63 train loss: 0.21336322 valid loss: 0.23003955
# 64 train loss: 0.2157419 valid loss: 0.22897573
# 65 train loss: 0.250931 valid loss: 0.25601918
# 66 train loss: 0.21881977 valid loss: 0.2516571
# 67 train loss: 0.2150065 valid loss: 0.22349605
# 68 train loss: 0.22422004 valid loss: 0.25646764
# 69 train loss: 0.20668696 valid loss: 0.22312938
# 70 train loss: 0.22422208 valid loss: 0.24462174
# 71 train loss: 0.20880622 valid loss: 0.22054799
# 72 train loss: 0.21736212 valid loss: 0.19998543
# best loss: 0.19998543
# 73 train loss: 0.2203148 valid loss: 0.27058685
# 74 train loss: 0.27061617 valid loss: 0.22460073
# 75 train loss: 0.2490288 valid loss: 0.28942513
# 76 train loss: 0.23545615 valid loss: 0.27964503
# 77 train loss: 0.21250261 valid loss: 0.22378579
# 78 train loss: 0.23119701 valid loss: 0.252351
# 79 train loss: 0.215125 valid loss: 0.24375716
# 80 train loss: 0.27266556 valid loss: 0.33068755
# 81 train loss: 0.21336725 valid loss: 0.22950937
# 82 train loss: 0.20490913 valid loss: 0.20952298
# 83 train loss: 0.208003 valid loss: 0.22322379
# 84 train loss: 0.20865119 valid loss: 0.21187817
# 85 train loss: 0.21786323 valid loss: 0.20619759
# 86 train loss: 0.21425587 valid loss: 0.22620054
# 87 train loss: 0.22349629 valid loss: 0.23668589
# 88 train loss: 0.21795264 valid loss: 0.25154984
# 89 train loss: 0.2105899 valid loss: 0.24385303
# 90 train loss: 0.20800294 valid loss: 0.22956014
# 91 train loss: 0.27546224 valid loss: 0.25704235
# 92 train loss: 0.28391403 valid loss: 0.23059994
# 93 train loss: 0.2433609 valid loss: 0.22622383
# 94 train loss: 0.22576573 valid loss: 0.26176333
# 95 train loss: 0.21915059 valid loss: 0.19135195
# best loss: 0.19135195
# 96 train loss: 0.23471771 valid loss: 0.28637105
# 97 train loss: 0.24491566 valid loss: 0.27667856
# 98 train loss: 0.23669639 valid loss: 0.2856969
# 99 train loss: 0.21313101 valid loss: 0.22073586
# 100 train loss: 0.24561462 valid loss: 0.28833702
# 101 train loss: 0.218163 valid loss: 0.23061946
# 102 train loss: 0.22884022 valid loss: 0.2716162
# 103 train loss: 0.20804094 valid loss: 0.22184294
# 104 train loss: 0.2087611 valid loss: 0.23200537
# 105 train loss: 0.2199634 valid loss: 0.2691017
# 106 train loss: 0.23624612 valid loss: 0.2625426
# 107 train loss: 0.22014475 valid loss: 0.22454928
# 108 train loss: 0.24476732 valid loss: 0.23262401
# 109 train loss: 0.21970858 valid loss: 0.26573482
# 110 train loss: 0.2242575 valid loss: 0.23278481
# 111 train loss: 0.21266305 valid loss: 0.22570354
# 112 train loss: 0.21980712 valid loss: 0.20975883
# 113 train loss: 0.21945253 valid loss: 0.24254367
# 114 train loss: 0.22547981 valid loss: 0.23125932
# 115 train loss: 0.2675919 valid loss: 0.24817203
# 116 train loss: 0.2073402 valid loss: 0.20841202
# 117 train loss: 0.20678224 valid loss: 0.2020794
# 118 train loss: 0.253557 valid loss: 0.30714402
# 119 train loss: 0.21187174 valid loss: 0.20492046
# 120 train loss: 0.20848264 valid loss: 0.22440073
# 121 train loss: 0.21570629 valid loss: 0.25115913
# 122 train loss: 0.24312119 valid loss: 0.23358446
# 123 train loss: 0.22201681 valid loss: 0.26992685
# 124 train loss: 0.21658376 valid loss: 0.21146536
# 125 train loss: 0.21336626 valid loss: 0.24182335
# 126 train loss: 0.22103608 valid loss: 0.21227266
# 127 train loss: 0.21264228 valid loss: 0.2315446
# 128 train loss: 0.21062188 valid loss: 0.2294583
# 129 train loss: 0.22246036 valid loss: 0.20645064
# 130 train loss: 0.22560944 valid loss: 0.25110394
# 131 train loss: 0.2014143 valid loss: 0.19956334
# 132 train loss: 0.20810159 valid loss: 0.20203501
# 133 train loss: 0.22710873 valid loss: 0.2479848
# 134 train loss: 0.20694472 valid loss: 0.21467048
# 135 train loss: 0.20856188 valid loss: 0.22920121
# 136 train loss: 0.2376982 valid loss: 0.21486513
# 137 train loss: 0.2698557 valid loss: 0.21933787
# 138 train loss: 0.21906534 valid loss: 0.2411686
# 139 train loss: 0.22312687 valid loss: 0.24420696
# 140 train loss: 0.24554177 valid loss: 0.27727404
# 141 train loss: 0.2132657 valid loss: 0.19643827
# 142 train loss: 0.21197149 valid loss: 0.239393
# 143 train loss: 0.21104257 valid loss: 0.21819387
# 144 train loss: 0.20830521 valid loss: 0.23551527
# 145 train loss: 0.22948958 valid loss: 0.27031115
# 146 train loss: 0.27621347 valid loss: 0.33685255
# 147 train loss: 0.19975856 valid loss: 0.20941046
# 148 train loss: 0.19923133 valid loss: 0.19445525
# 149 train loss: 0.20033969 valid loss: 0.21410564
# 150 train loss: 0.2003211 valid loss: 0.21550448
# 151 train loss: 0.23916997 valid loss: 0.27664673
# 152 train loss: 0.21330468 valid loss: 0.21551675
# 153 train loss: 0.20502344 valid loss: 0.20452075
# 154 train loss: 0.24497844 valid loss: 0.1877328
# best loss: 0.1877328
# 155 train loss: 0.216887 valid loss: 0.23336692
# 156 train loss: 0.20501307 valid loss: 0.21612301
# 157 train loss: 0.20582551 valid loss: 0.20855087
# 158 train loss: 0.22434358 valid loss: 0.2075873
# 159 train loss: 0.2161575 valid loss: 0.23631465
# 160 train loss: 0.20102753 valid loss: 0.22263381
# 161 train loss: 0.2179323 valid loss: 0.25010276
# 162 train loss: 0.23257771 valid loss: 0.2564102
# 163 train loss: 0.23765214 valid loss: 0.21350959
# 164 train loss: 0.21806748 valid loss: 0.21596266
# 165 train loss: 0.20443335 valid loss: 0.20429406
# 166 train loss: 0.23540577 valid loss: 0.21849902
# 167 train loss: 0.23437339 valid loss: 0.28017253
# 168 train loss: 0.2079785 valid loss: 0.23002546
# 169 train loss: 0.19981939 valid loss: 0.20477293
# 170 train loss: 0.21022984 valid loss: 0.20476986
# 171 train loss: 0.20536488 valid loss: 0.22563507
# 172 train loss: 0.21006975 valid loss: 0.24184746
# 173 train loss: 0.20386012 valid loss: 0.20713927
# 174 train loss: 0.21289699 valid loss: 0.19652784
# 175 train loss: 0.25115812 valid loss: 0.2186069
# 176 train loss: 0.25713938 valid loss: 0.2406551
# 177 train loss: 0.21730486 valid loss: 0.19485912
# 178 train loss: 0.22446883 valid loss: 0.19790551
# 179 train loss: 0.20458718 valid loss: 0.21308187
# 180 train loss: 0.21554159 valid loss: 0.22874944
# 181 train loss: 0.24067067 valid loss: 0.23286174
# 182 train loss: 0.22222596 valid loss: 0.26953608
# 183 train loss: 0.19817394 valid loss: 0.20802358
# 184 train loss: 0.20634449 valid loss: 0.20857438
# 185 train loss: 0.20278963 valid loss: 0.2223747
# 186 train loss: 0.22761518 valid loss: 0.22558637
# 187 train loss: 0.20768856 valid loss: 0.21594593
# 188 train loss: 0.22476102 valid loss: 0.18540636
# best loss: 0.18540636
# 189 train loss: 0.20767173 valid loss: 0.25744584
# 190 train loss: 0.20509373 valid loss: 0.21643388
# 191 train loss: 0.22486368 valid loss: 0.21261764
# 192 train loss: 0.20321904 valid loss: 0.19982275
# 193 train loss: 0.22204459 valid loss: 0.24743842
# 194 train loss: 0.22375065 valid loss: 0.19622475
# 195 train loss: 0.20405781 valid loss: 0.23334381
# 196 train loss: 0.3006987 valid loss: 0.3846588
# 197 train loss: 0.22631666 valid loss: 0.27569985
# 198 train loss: 0.20913978 valid loss: 0.22374925
# 199 train loss: 0.21519218 valid loss: 0.21958107
# 200 train loss: 0.25402328 valid loss: 0.2816562
# 201 train loss: 0.27851853 valid loss: 0.33162066
# 202 train loss: 0.24906106 valid loss: 0.29465955
# 203 train loss: 0.20708546 valid loss: 0.23281887
# 204 train loss: 0.2204734 valid loss: 0.2255955
# 205 train loss: 0.22795941 valid loss: 0.19362983
# 206 train loss: 0.220703 valid loss: 0.20473026
# 207 train loss: 0.2118803 valid loss: 0.20894806
# 208 train loss: 0.21315497 valid loss: 0.22041717
# 209 train loss: 0.2324115 valid loss: 0.28356156
# 210 train loss: 0.2519726 valid loss: 0.295639
# 211 train loss: 0.21832412 valid loss: 0.2557623
# 212 train loss: 0.21343689 valid loss: 0.23440559
# 213 train loss: 0.22639671 valid loss: 0.2580138
# 214 train loss: 0.20460536 valid loss: 0.22253622
# 215 train loss: 0.22023784 valid loss: 0.2574986
# 216 train loss: 0.21027361 valid loss: 0.18216467
# best loss: 0.18216467
# 217 train loss: 0.21171916 valid loss: 0.21832216
# 218 train loss: 0.209593 valid loss: 0.24129
# 219 train loss: 0.19604217 valid loss: 0.20751803
# 220 train loss: 0.20492989 valid loss: 0.21607733
# 221 train loss: 0.20974873 valid loss: 0.22815837
# 222 train loss: 0.21545762 valid loss: 0.23305397
# 223 train loss: 0.2072477 valid loss: 0.23112294
# 224 train loss: 0.20962659 valid loss: 0.19928895
# 225 train loss: 0.21610172 valid loss: 0.20763646
# 226 train loss: 0.21626157 valid loss: 0.24613029
# 227 train loss: 0.20544885 valid loss: 0.23005842
# 228 train loss: 0.23115136 valid loss: 0.27697504
# 229 train loss: 0.20501864 valid loss: 0.23264486
# 230 train loss: 0.20317245 valid loss: 0.2130012
# 231 train loss: 0.22359884 valid loss: 0.25825962
# 232 train loss: 0.20543997 valid loss: 0.20902212
# 233 train loss: 0.23688734 valid loss: 0.20682038
# 234 train loss: 0.21584752 valid loss: 0.24579357
# 235 train loss: 0.23478554 valid loss: 0.23093875
# 236 train loss: 0.23378384 valid loss: 0.21690634
# 237 train loss: 0.242056 valid loss: 0.27479544
# 238 train loss: 0.2109098 valid loss: 0.21576287
# 239 train loss: 0.21848159 valid loss: 0.26087636
# 240 train loss: 0.20398043 valid loss: 0.21131074
# 241 train loss: 0.28580832 valid loss: 0.34823674
# 242 train loss: 0.21662036 valid loss: 0.25748175
# 243 train loss: 0.21860631 valid loss: 0.2612473
# 244 train loss: 0.2078932 valid loss: 0.20214619
# 245 train loss: 0.21704139 valid loss: 0.26959565
# 246 train loss: 0.22704703 valid loss: 0.20071389
# 247 train loss: 0.22147882 valid loss: 0.24137993
# 248 train loss: 0.23857963 valid loss: 0.30452162
# 249 train loss: 0.20313434 valid loss: 0.20645079
# 250 train loss: 0.22344671 valid loss: 0.20589288
# 251 train loss: 0.20885266 valid loss: 0.22192869
# 252 train loss: 0.21339959 valid loss: 0.24471353
# 253 train loss: 0.23020998 valid loss: 0.29177305
# 254 train loss: 0.20354213 valid loss: 0.21701087
# 255 train loss: 0.20799828 valid loss: 0.22854082
# 256 train loss: 0.21085969 valid loss: 0.22736257
# 257 train loss: 0.24142063 valid loss: 0.21419182
# 258 train loss: 0.21104093 valid loss: 0.22497068
# 259 train loss: 0.22949529 valid loss: 0.2645158
# 260 train loss: 0.20493455 valid loss: 0.20204042
# 261 train loss: 0.20690985 valid loss: 0.21126671
# 262 train loss: 0.2096307 valid loss: 0.20479485
# 263 train loss: 0.21789296 valid loss: 0.20945773
# 264 train loss: 0.20850316 valid loss: 0.21218866
# 265 train loss: 0.22617404 valid loss: 0.2633942
# 266 train loss: 0.2064833 valid loss: 0.22812933
# 267 train loss: 0.21309195 valid loss: 0.20795307
# 268 train loss: 0.20212327 valid loss: 0.20691895
# 269 train loss: 0.20971349 valid loss: 0.2332405
# 270 train loss: 0.20485367 valid loss: 0.19624476
# 271 train loss: 0.21870711 valid loss: 0.20360361
# 272 train loss: 0.20201991 valid loss: 0.19874683
# 273 train loss: 0.21739593 valid loss: 0.25437284
# 274 train loss: 0.21192801 valid loss: 0.25818053
# 275 train loss: 0.24246116 valid loss: 0.29442397
# 276 train loss: 0.22313277 valid loss: 0.25175878
# 277 train loss: 0.21059822 valid loss: 0.19343442
# 278 train loss: 0.216626 valid loss: 0.21780059
# 279 train loss: 0.20411836 valid loss: 0.2168941
# 280 train loss: 0.21401082 valid loss: 0.21622422
# 281 train loss: 0.21424048 valid loss: 0.24453287
# 282 train loss: 0.20747186 valid loss: 0.22838698
# 283 train loss: 0.21295586 valid loss: 0.20983623
# 284 train loss: 0.23161905 valid loss: 0.196165
# 285 train loss: 0.20876971 valid loss: 0.23141967
# 286 train loss: 0.20557 valid loss: 0.2136972
# 287 train loss: 0.20614228 valid loss: 0.2093797
# 288 train loss: 0.20637941 valid loss: 0.22927366
# 289 train loss: 0.21079293 valid loss: 0.21286872
# 290 train loss: 0.21337907 valid loss: 0.24384175
# 291 train loss: 0.22148307 valid loss: 0.2702447
# 292 train loss: 0.24024709 valid loss: 0.2949338
# 293 train loss: 0.19990124 valid loss: 0.21092139
# 294 train loss: 0.24897963 valid loss: 0.24358489
# 295 train loss: 0.21603514 valid loss: 0.22138193
# 296 train loss: 0.20143887 valid loss: 0.19864678
# 297 train loss: 0.21215047 valid loss: 0.23583083
# 298 train loss: 0.21310237 valid loss: 0.20943911
# 299 train loss: 0.2022875 valid loss: 0.2152924
# 300 train loss: 0.21029466 valid loss: 0.20045102
# 301 train loss: 0.24751598 valid loss: 0.24854878
# 302 train loss: 0.20752871 valid loss: 0.22411823
# 303 train loss: 0.21746247 valid loss: 0.2285393
# 304 train loss: 0.20189534 valid loss: 0.20429242
# 305 train loss: 0.22230467 valid loss: 0.21901041
# 306 train loss: 0.21338397 valid loss: 0.25492093
# 307 train loss: 0.20098177 valid loss: 0.20196943
# 308 train loss: 0.2240802 valid loss: 0.26206464
# 309 train loss: 0.21582925 valid loss: 0.25113443
# 310 train loss: 0.20032206 valid loss: 0.22681074
# 311 train loss: 0.2128139 valid loss: 0.21744834
# 312 train loss: 0.2135482 valid loss: 0.2500608
# 313 train loss: 0.20499456 valid loss: 0.19370277
# 314 train loss: 0.20679003 valid loss: 0.22803971
# 315 train loss: 0.20520996 valid loss: 0.23091364
# 316 train loss: 0.23366885 valid loss: 0.26035914
# 317 train loss: 0.2085329 valid loss: 0.22281802
# 318 train loss: 0.21247424 valid loss: 0.22249033
# 319 train loss: 0.21578518 valid loss: 0.21950968
# 320 train loss: 0.20840736 valid loss: 0.23547721
# 321 train loss: 0.20245494 valid loss: 0.22717679
# 322 train loss: 0.20077911 valid loss: 0.208447
# 323 train loss: 0.23333657 valid loss: 0.28549972
# 324 train loss: 0.2091537 valid loss: 0.22853337
# 325 train loss: 0.20491137 valid loss: 0.23152857
# 326 train loss: 0.19916439 valid loss: 0.22436894
# 327 train loss: 0.21224721 valid loss: 0.21294944
# 328 train loss: 0.20062901 valid loss: 0.21698555
# 329 train loss: 0.20457493 valid loss: 0.22418135
# 330 train loss: 0.20500053 valid loss: 0.22358891
# 331 train loss: 0.20146017 valid loss: 0.22030313
# 332 train loss: 0.20835152 valid loss: 0.23212284
# 333 train loss: 0.20310071 valid loss: 0.21332371
# 334 train loss: 0.20987506 valid loss: 0.19980106
# 335 train loss: 0.22273143 valid loss: 0.2526466
# 336 train loss: 0.22217016 valid loss: 0.28424057
# 337 train loss: 0.21407771 valid loss: 0.18843858
# 338 train loss: 0.20603846 valid loss: 0.24039337
# 339 train loss: 0.20440954 valid loss: 0.22532852
# 340 train loss: 0.19980307 valid loss: 0.22534701
# 341 train loss: 0.23727296 valid loss: 0.26791355
# 342 train loss: 0.2107088 valid loss: 0.21632773
# 343 train loss: 0.21668352 valid loss: 0.23247463
# 344 train loss: 0.22101425 valid loss: 0.22754115
# 345 train loss: 0.23708732 valid loss: 0.2650614
# 346 train loss: 0.2072217 valid loss: 0.20201868
# 347 train loss: 0.22081856 valid loss: 0.27167827
# 348 train loss: 0.20297259 valid loss: 0.204671
# 349 train loss: 0.21809344 valid loss: 0.2456869
# 350 train loss: 0.20643872 valid loss: 0.23908012
# 351 train loss: 0.19834809 valid loss: 0.20254922
# 352 train loss: 0.20630828 valid loss: 0.19515081
# 353 train loss: 0.20996839 valid loss: 0.20881814
# 354 train loss: 0.21133472 valid loss: 0.25367805
# 355 train loss: 0.20798889 valid loss: 0.19791408
# 356 train loss: 0.2081789 valid loss: 0.22599837
# 357 train loss: 0.2052678 valid loss: 0.19606088
# 358 train loss: 0.21214105 valid loss: 0.25503504
# 359 train loss: 0.19781272 valid loss: 0.20975164
# 360 train loss: 0.19490793 valid loss: 0.2060662
# 361 train loss: 0.23846298 valid loss: 0.25119343
# 362 train loss: 0.20857127 valid loss: 0.23266852
# 363 train loss: 0.21147119 valid loss: 0.21966426
# 364 train loss: 0.2074016 valid loss: 0.20800236
# 365 train loss: 0.25735122 valid loss: 0.34331405
# 366 train loss: 0.23106681 valid loss: 0.28841454
# 367 train loss: 0.2295024 valid loss: 0.21505177
# 368 train loss: 0.21155244 valid loss: 0.21216837
# 369 train loss: 0.22544873 valid loss: 0.2699436
# 370 train loss: 0.20968756 valid loss: 0.24824089
# 371 train loss: 0.2016905 valid loss: 0.20228593
# 372 train loss: 0.22666824 valid loss: 0.27828902
# 373 train loss: 0.21964948 valid loss: 0.2691865
# 374 train loss: 0.20663197 valid loss: 0.21998753
# 375 train loss: 0.19949351 valid loss: 0.20511256
# 376 train loss: 0.2122699 valid loss: 0.23118918
# 377 train loss: 0.21159807 valid loss: 0.2088513
# 378 train loss: 0.20213978 valid loss: 0.22330624
# 379 train loss: 0.19987004 valid loss: 0.2023228
# 380 train loss: 0.21516274 valid loss: 0.25351328
# 381 train loss: 0.20551996 valid loss: 0.23226286
# 382 train loss: 0.2011763 valid loss: 0.22985193
# 383 train loss: 0.22242074 valid loss: 0.2714179
# 384 train loss: 0.2160336 valid loss: 0.22074252
# 385 train loss: 0.20138201 valid loss: 0.22182679
# 386 train loss: 0.20574376 valid loss: 0.21332386
# 387 train loss: 0.21220478 valid loss: 0.23689099
# 388 train loss: 0.22799954 valid loss: 0.2602324
# 389 train loss: 0.20898442 valid loss: 0.21017827
# 390 train loss: 0.21655661 valid loss: 0.27463385
# 391 train loss: 0.20525017 valid loss: 0.23866934
# 392 train loss: 0.20762254 valid loss: 0.26313993
# 393 train loss: 0.21177031 valid loss: 0.25727236
# 394 train loss: 0.20762631 valid loss: 0.22544026
# 395 train loss: 0.2135953 valid loss: 0.24315402
# 396 train loss: 0.20282924 valid loss: 0.21514516
# 397 train loss: 0.20163925 valid loss: 0.19325238
# 398 train loss: 0.22724344 valid loss: 0.19282721
# 399 train loss: 0.21406822 valid loss: 0.24914639
# 400 train loss: 0.22599226 valid loss: 0.1984087
# 401 train loss: 0.2057695 valid loss: 0.2256627
# 402 train loss: 0.20617092 valid loss: 0.23562358
# 403 train loss: 0.21665771 valid loss: 0.22011526
# 404 train loss: 0.20958687 valid loss: 0.23990929
# 405 train loss: 0.2092912 valid loss: 0.21173716
# 406 train loss: 0.20688148 valid loss: 0.23673034
# 407 train loss: 0.20641914 valid loss: 0.20733614
# 408 train loss: 0.20332818 valid loss: 0.21739583
# 409 train loss: 0.21608813 valid loss: 0.1909439
# 410 train loss: 0.21457593 valid loss: 0.25423765
# 411 train loss: 0.20096564 valid loss: 0.19955194
# 412 train loss: 0.20119253 valid loss: 0.21652392
# 413 train loss: 0.21064478 valid loss: 0.21683338
# 414 train loss: 0.2056027 valid loss: 0.222558
# 415 train loss: 0.20823175 valid loss: 0.23077972
# 416 train loss: 0.19767167 valid loss: 0.21901828
# 417 train loss: 0.24806838 valid loss: 0.3140812
# 418 train loss: 0.2038423 valid loss: 0.21256152
# 419 train loss: 0.22517972 valid loss: 0.18367702
# 420 train loss: 0.22667243 valid loss: 0.21362531
# 421 train loss: 0.20737565 valid loss: 0.23551476
# 422 train loss: 0.20634285 valid loss: 0.24416101
# 423 train loss: 0.20107473 valid loss: 0.21934935
# 424 train loss: 0.23399228 valid loss: 0.28424707
# 425 train loss: 0.21100882 valid loss: 0.19136888
# 426 train loss: 0.20641135 valid loss: 0.24895065
# 427 train loss: 0.25302172 valid loss: 0.22231077
# 428 train loss: 0.20811178 valid loss: 0.2251887
# 429 train loss: 0.21363026 valid loss: 0.26377243
# 430 train loss: 0.20995499 valid loss: 0.20093659
# 431 train loss: 0.20953818 valid loss: 0.22261958
# 432 train loss: 0.21053624 valid loss: 0.2428881
# 433 train loss: 0.21147566 valid loss: 0.25859
# 434 train loss: 0.20385703 valid loss: 0.22282797
# 435 train loss: 0.204061 valid loss: 0.21184917
# 436 train loss: 0.20339441 valid loss: 0.23089677
# 437 train loss: 0.21532387 valid loss: 0.26270464
# 438 train loss: 0.20904024 valid loss: 0.22687623
# 439 train loss: 0.20457655 valid loss: 0.21400546
# 440 train loss: 0.2162037 valid loss: 0.19655664
# 441 train loss: 0.21401441 valid loss: 0.2308265
# 442 train loss: 0.34292266 valid loss: 0.40488058
# 443 train loss: 0.22813025 valid loss: 0.27972427
# 444 train loss: 0.24273886 valid loss: 0.27590978
# 445 train loss: 0.21646966 valid loss: 0.2372755
# 446 train loss: 0.20896877 valid loss: 0.22238813
# 447 train loss: 0.22770369 valid loss: 0.27746373
# 448 train loss: 0.216043 valid loss: 0.24420711
# 449 train loss: 0.22009262 valid loss: 0.25390932
# 450 train loss: 0.21021241 valid loss: 0.24227783
# 451 train loss: 0.21469007 valid loss: 0.21866524
# 452 train loss: 0.22596502 valid loss: 0.26754034
# 453 train loss: 0.27215913 valid loss: 0.33138603
# 454 train loss: 0.20923272 valid loss: 0.22280233
# 455 train loss: 0.20610255 valid loss: 0.23596956
# 456 train loss: 0.21222337 valid loss: 0.20162567
# 457 train loss: 0.20238855 valid loss: 0.20643087
# 458 train loss: 0.21719593 valid loss: 0.24048345
# 459 train loss: 0.20809355 valid loss: 0.21367282
# 460 train loss: 0.21171428 valid loss: 0.20851833
# 461 train loss: 0.2068743 valid loss: 0.2341579
# 462 train loss: 0.20729487 valid loss: 0.23133552
# 463 train loss: 0.20342197 valid loss: 0.22283427
# 464 train loss: 0.23581472 valid loss: 0.20102228
# 465 train loss: 0.20996763 valid loss: 0.22374293
# 466 train loss: 0.20886783 valid loss: 0.22511673
# 467 train loss: 0.2173287 valid loss: 0.25936663
# 468 train loss: 0.20581341 valid loss: 0.20815983
# 469 train loss: 0.2408741 valid loss: 0.22277167
# 470 train loss: 0.21268213 valid loss: 0.24230082
# 471 train loss: 0.2227488 valid loss: 0.20801122
# 472 train loss: 0.22793147 valid loss: 0.1912395
# 473 train loss: 0.2195243 valid loss: 0.19642226
# 474 train loss: 0.20818453 valid loss: 0.2295875
# 475 train loss: 0.20738272 valid loss: 0.21609248
# 476 train loss: 0.22503911 valid loss: 0.2762488
# 477 train loss: 0.22130695 valid loss: 0.2619926
# 478 train loss: 0.20814645 valid loss: 0.21499276
# 479 train loss: 0.20689511 valid loss: 0.19665174
# 480 train loss: 0.22898225 valid loss: 0.19272722
# 481 train loss: 0.20620729 valid loss: 0.23026188
# 482 train loss: 0.22302505 valid loss: 0.20220733
# 483 train loss: 0.21758193 valid loss: 0.21948639
# 484 train loss: 0.21190362 valid loss: 0.25087145
# 485 train loss: 0.22986442 valid loss: 0.19645697
# 486 train loss: 0.20783481 valid loss: 0.2363029
# 487 train loss: 0.20354612 valid loss: 0.23036306
# 488 train loss: 0.213466 valid loss: 0.24460697
# 489 train loss: 0.1995187 valid loss: 0.21050756
# 490 train loss: 0.21021447 valid loss: 0.24639837
# 491 train loss: 0.2103258 valid loss: 0.21457209
# 492 train loss: 0.21434318 valid loss: 0.25771925
# 493 train loss: 0.21966977 valid loss: 0.25766876
# 494 train loss: 0.2240967 valid loss: 0.2633425
# 495 train loss: 0.20827322 valid loss: 0.21266447
# 496 train loss: 0.20573859 valid loss: 0.22335245
# 497 train loss: 0.22403093 valid loss: 0.2007888
# 498 train loss: 0.21640058 valid loss: 0.2200196
# 499 train loss: 0.20358524 valid loss: 0.20540191
# 500 train loss: 0.20782119 valid loss: 0.22150923
# 501 train loss: 0.20631556 valid loss: 0.2262792
# 502 train loss: 0.20111454 valid loss: 0.21880881
# 503 train loss: 0.20344222 valid loss: 0.22596847
# 504 train loss: 0.22142789 valid loss: 0.22179489
# 505 train loss: 0.20924623 valid loss: 0.23328505
# 506 train loss: 0.23332079 valid loss: 0.28549394
# 507 train loss: 0.21290056 valid loss: 0.23744859
# 508 train loss: 0.20912798 valid loss: 0.22916988
# 509 train loss: 0.20599344 valid loss: 0.21418612
# 510 train loss: 0.20245917 valid loss: 0.2112906
# 511 train loss: 0.23145501 valid loss: 0.2316017
# 512 train loss: 0.20733969 valid loss: 0.21998967
# 513 train loss: 0.22142926 valid loss: 0.2544723
# 514 train loss: 0.26124203 valid loss: 0.33159238
# 515 train loss: 0.21712308 valid loss: 0.26285508
# 516 train loss: 0.21629708 valid loss: 0.21525061
# 517 train loss: 0.23516193 valid loss: 0.25077724
# 518 train loss: 0.20808332 valid loss: 0.22386798
# 519 train loss: 0.22578068 valid loss: 0.28080148
# 520 train loss: 0.20060223 valid loss: 0.2282255
# 521 train loss: 0.20523268 valid loss: 0.21104969
# 522 train loss: 0.20617379 valid loss: 0.24572866
# 523 train loss: 0.20518734 valid loss: 0.21596874
# 524 train loss: 0.20690328 valid loss: 0.22246143
# 525 train loss: 0.19816211 valid loss: 0.20813657
# 526 train loss: 0.20042427 valid loss: 0.20055997
# 527 train loss: 0.19781755 valid loss: 0.22328319
# 528 train loss: 0.19942546 valid loss: 0.22040214
# 529 train loss: 0.2259994 valid loss: 0.2699785
# 530 train loss: 0.19951655 valid loss: 0.22679938
# 531 train loss: 0.20726463 valid loss: 0.24598761
# 532 train loss: 0.21022579 valid loss: 0.20543206
# 533 train loss: 0.22040595 valid loss: 0.21518983
# 534 train loss: 0.20068134 valid loss: 0.22162253
# 535 train loss: 0.2384867 valid loss: 0.28547886
# 536 train loss: 0.20598528 valid loss: 0.2250488
# 537 train loss: 0.20908345 valid loss: 0.2282697
# 538 train loss: 0.20904037 valid loss: 0.23318325
# 539 train loss: 0.2067836 valid loss: 0.19197941
# 540 train loss: 0.20016867 valid loss: 0.22782493
# 541 train loss: 0.21014239 valid loss: 0.19997977
# 542 train loss: 0.20813903 valid loss: 0.23592055
# 543 train loss: 0.21734188 valid loss: 0.25539702
# 544 train loss: 0.20649676 valid loss: 0.19834524
# 545 train loss: 0.20416243 valid loss: 0.23459427
# 546 train loss: 0.20024541 valid loss: 0.19767612
# 547 train loss: 0.20330815 valid loss: 0.23574077
# 548 train loss: 0.1986015 valid loss: 0.2129018
# 549 train loss: 0.20368344 valid loss: 0.23919223
# 550 train loss: 0.20172186 valid loss: 0.21516265
# 551 train loss: 0.20366788 valid loss: 0.20974335
# 552 train loss: 0.21073188 valid loss: 0.19444486
# 553 train loss: 0.2685191 valid loss: 0.27435634
# 554 train loss: 0.2470142 valid loss: 0.20781885
# 555 train loss: 0.22113185 valid loss: 0.2429839
# 556 train loss: 0.21622759 valid loss: 0.24384445
# 557 train loss: 0.2506332 valid loss: 0.31883144
# 558 train loss: 0.21706876 valid loss: 0.23066846
# 559 train loss: 0.21249984 valid loss: 0.22598173
# 560 train loss: 0.20718573 valid loss: 0.24737339
# 561 train loss: 0.26955655 valid loss: 0.32969692
# 562 train loss: 0.22839865 valid loss: 0.23100545
# 563 train loss: 0.213413 valid loss: 0.2426026
# 564 train loss: 0.22302036 valid loss: 0.25642166
# 565 train loss: 0.20840406 valid loss: 0.21121489
# 566 train loss: 0.21099015 valid loss: 0.19910702
# 567 train loss: 0.2202738 valid loss: 0.24806286
# 568 train loss: 0.21086246 valid loss: 0.2448486
# 569 train loss: 0.2097556 valid loss: 0.2363123
# 570 train loss: 0.21405365 valid loss: 0.20473619
# 571 train loss: 0.20708582 valid loss: 0.24373153
# 572 train loss: 0.20753194 valid loss: 0.24150717
# 573 train loss: 0.21490066 valid loss: 0.20894434
# 574 train loss: 0.23604655 valid loss: 0.29193327
# 575 train loss: 0.20083979 valid loss: 0.20314991
# 576 train loss: 0.21049796 valid loss: 0.20189701
# 577 train loss: 0.23428653 valid loss: 0.2240134
# 578 train loss: 0.20403966 valid loss: 0.23306197
# 579 train loss: 0.20634788 valid loss: 0.21047255
# 580 train loss: 0.20448884 valid loss: 0.2226097
# 581 train loss: 0.20637354 valid loss: 0.23817119
# 582 train loss: 0.21405233 valid loss: 0.24322876
# 583 train loss: 0.20934348 valid loss: 0.22590156
# 584 train loss: 0.1980586 valid loss: 0.2063378
# 585 train loss: 0.20653965 valid loss: 0.23006156
# 586 train loss: 0.21599025 valid loss: 0.19924486
# 587 train loss: 0.20807971 valid loss: 0.23159808
# 588 train loss: 0.21505551 valid loss: 0.24781471
# 589 train loss: 0.20308666 valid loss: 0.21361831
# 590 train loss: 0.20910352 valid loss: 0.24711655
# 591 train loss: 0.2085943 valid loss: 0.24518535
# 592 train loss: 0.21018627 valid loss: 0.23229225
# 593 train loss: 0.203964 valid loss: 0.23324034
# 594 train loss: 0.20169906 valid loss: 0.21590276
# 595 train loss: 0.21183781 valid loss: 0.20600758
# 596 train loss: 0.20488383 valid loss: 0.21667773
# 597 train loss: 0.23295148 valid loss: 0.22758153
# 598 train loss: 0.21181248 valid loss: 0.22028847
# 599 train loss: 0.20229447 valid loss: 0.20313297
# 600 train loss: 0.21406654 valid loss: 0.23669909
# 601 train loss: 0.20356704 valid loss: 0.21131136
# 602 train loss: 0.21203183 valid loss: 0.22166978
# 603 train loss: 0.21447535 valid loss: 0.2244055
# 604 train loss: 0.22124702 valid loss: 0.21110357
# 605 train loss: 0.21339922 valid loss: 0.25197822
# 606 train loss: 0.22955048 valid loss: 0.19364737
# 607 train loss: 0.22347066 valid loss: 0.19806628
# 608 train loss: 0.20217273 valid loss: 0.22556613
# 609 train loss: 0.209859 valid loss: 0.2149421
# 610 train loss: 0.20461778 valid loss: 0.2012067
# 611 train loss: 0.21030384 valid loss: 0.25773886
# 612 train loss: 0.21077812 valid loss: 0.21055587
# 613 train loss: 0.23286591 valid loss: 0.28764385
# 614 train loss: 0.22253886 valid loss: 0.21875757
# 615 train loss: 0.2075096 valid loss: 0.24280168
# 616 train loss: 0.21796829 valid loss: 0.2394339
# 617 train loss: 0.20719731 valid loss: 0.2128434
# Early stopping

# %%
os.remove(checkpoint_epoch_path)

# %% [markdown]
# # Predictions

# %%
with tf.Session() as sess:
    saver.restore(sess, final_model_path)
    test_mse = mse.eval(feed_dict={X_node: X_test, y_node: y_test})
    predictions = y_pred.eval(feed_dict={X_node: X_test, y_node: y_test})
    
    
print(test_mse)
# Out:
# W0820 18:29:53.874913 16172 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 0.25294155

# %%
predictions.shape
# Out:
# (468, 1)

# %% [markdown]
# # Plot  _first (0th)_ output column of _predictions_

# %%
y_new_inverse = y_scaler.inverse_transform(predictions)
x_test_inverse = x_scaler.inverse_transform(X_test)

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = y_new_inverse[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
y_test_o.shape[0]
# Out:
# 468

# %%
plt.scatter(range(y_new_inverse.shape[0]), y_new_inverse[:,0], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot _first 0th_ column of TEST set

# %%
plt.scatter(range(y_test_o.shape[0]), y_test_o, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = X_test_o[:,0]
ys = X_test_o[:,1]
zs = y_test_o[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Calculate _diff_ and _diff_abs_ (no distinction for columns)

# %%
#diff = np.square((y_new_inverse - y_test_o) / y_test_o)
substraction = y_new_inverse - y_test_o
diff = np.divide( substraction , y_test_o, out = substraction, where = y_test_o != 0)
diff_abs = y_new_inverse - y_test_o

# %%
print(diff.shape)
print(diff_abs.shape)
# Out:
# (468, 1)
# (468, 1)

# %%
diff_df = pd.DataFrame(data={
                            'rel diff mass': diff[:,0],                            
                            'abs diff mass' : diff_abs[:,0]                             
                            })
diff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 2 columns):
# rel diff mass    468 non-null float64
# abs diff mass    468 non-null float64
# dtypes: float64(2)
# memory usage: 7.4 KB

# %% [markdown]
# # Replace inf and -inf with Nan, then drop the nans

# %%
diff_df = diff_df.replace([np.inf, -np.inf], np.nan)

# %%
print(diff_df.isnull().values.any())
print(diff_df.isnull().sum())
diff_df = diff_df.dropna()
# Out:
# False
# rel diff mass    0
# abs diff mass    0
# dtype: int64

# %%
diff_df.describe()
# Out:
#        rel diff mass  abs diff mass
# count     468.000000     468.000000
# mean        0.117462       0.427025
# std         0.597087       1.500179
# min        -2.681203      -9.492953
# 25%        -0.072958      -0.623651
# 50%         0.076073       0.522773
# 75%         0.219820       1.453913
# max        10.376635       7.707971

# %% [markdown]
# # Plot the relative diff of the first column

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = diff_df['rel diff mass']# diff[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.5)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
#%matplotlib notebook

# %%
vals = diff_df['rel diff mass'].to_numpy()
print(vals.shape)
print(vals.shape[0])
# Out:
# (468,)
# 468

# %%
#plt.scatter(iterate_x, diff[:,0], s=5)

plt.scatter(range(vals.shape[0]),vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Diff ABSOLUTE of first column

# %%
vals = diff_df['abs diff mass'].to_numpy()
print(vals.shape)
range_x = range(vals.shape[0])
# Out:
# (468,)

# %%
plt.scatter(range_x,vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()
