# %% [markdown]
# # Two imputs (N,Z) and two outputs (Mass excess, seperation energey) in single ANN

# %% [markdown]
# # Imports

# %%
import numpy as np
import tensorflow as tf
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
from utils import shuffle_batch, variable_summaries
import os

# %matplotlib notebook

dir_path = os.getcwd()

now = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)
print(dir_path)
print(now)
# Out:
# C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-mass-output
# 2019-08-20-14-13-33

# %%
#%matplotlib notebook

# %% [markdown]
# # Read the data set

# %%
df = pd.read_csv("better-nuclei-19-08.csv")
print(df.info())
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436 entries, 0 to 3435
# Data columns (total 10 columns):
# Z                                  3436 non-null int64
# N                                  3436 non-null int64
# UQ                                 3436 non-null int64
# DQ                                 3436 non-null int64
# Mass Excess [MeV]                  3436 non-null float64
# Mass Error                         3436 non-null float64
# Mass Estimated                     3436 non-null int64
# Neutron separation energy [MeV]    3318 non-null float64
# Separation Error                   3318 non-null float64
# Separation Estimated               3318 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 268.5 KB
# None
# Index(['Z', 'N', 'UQ', 'DQ', 'Mass Excess [MeV]', 'Mass Error',
#        'Mass Estimated', 'Neutron separation energy [MeV]', 'Separation Error',
#        'Separation Estimated'],
#       dtype='object')

# %%
df = df.rename(columns=
               {"Mass Excess [MeV]": "d",
                "Z":'z',
                'N':'n',
                'UQ':"uq",
                'DQ':"dq",
                "Mass Error":"mass error",
                "Mass Estimated":"mass estimated",
                "Neutron separation energy [MeV]":"d2",
                "Separation Error":"separation error",
                "Separation Estimated":"separation estimated"               
               })
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436 entries, 0 to 3435
# Data columns (total 10 columns):
# z                       3436 non-null int64
# n                       3436 non-null int64
# uq                      3436 non-null int64
# dq                      3436 non-null int64
# d                       3436 non-null float64
# mass error              3436 non-null float64
# mass estimated          3436 non-null int64
# d2                      3318 non-null float64
# separation error        3318 non-null float64
# separation estimated    3318 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 268.5 KB
# None

# %%
df.describe()
# Out:
#                  z            n           uq           dq            d  \
# count  3436.000000  3436.000000  3436.000000  3436.000000  3436.000000
# mean     57.857392    82.034051   197.748836   221.925495   -24.144121
# std      27.809406    43.293558    98.188326   113.771063    56.200706
# min       0.000000     0.000000     1.000000     1.000000   -91.652853
# 25%      36.000000    47.000000   120.750000   131.000000   -65.400443
# 50%      58.000000    81.000000   197.000000   219.000000   -39.335024
# 75%      80.000000   114.000000   273.000000   308.000000     1.172301
# max     118.000000   177.000000   413.000000   472.000000   201.512000
#
#         mass error  mass estimated           d2  separation error  \
# count  3436.000000     3436.000000  3318.000000       3318.000000
# mean      0.123589        0.272992     7.755557          0.164216
# std       0.197548        0.445562     3.631747          0.254378
# min       0.000000        0.000000    -2.488000          0.000000
# 25%       0.003006        0.000000     5.414787          0.005140
# 50%       0.014474        0.000000     7.249960          0.025005
# 75%       0.196000        1.000000     9.654658          0.269058
# max       2.003000        1.000000    27.715000          2.011000
#
#        separation estimated
# count           3318.000000
# mean               0.295660
# std                0.456408
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                1.000000
# max                1.000000

# %% [markdown]
# # Remove estimated Excess and estimated Seperation

# %%
not_estimated_filter = (df["mass estimated"] == 0)
df = df[not_estimated_filter]

not_estimated_filter = (df["separation estimated"] == 0)
df = df[not_estimated_filter]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 10 columns):
# z                       2337 non-null int64
# n                       2337 non-null int64
# uq                      2337 non-null int64
# dq                      2337 non-null int64
# d                       2337 non-null float64
# mass error              2337 non-null float64
# mass estimated          2337 non-null int64
# d2                      2337 non-null float64
# separation error        2337 non-null float64
# separation estimated    2337 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 200.8 KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['z'].shape
# Out:
# (2337,)

# %%
df.count()
# Out:
# z                       2337
# n                       2337
# uq                      2337
# dq                      2337
# d                       2337
# mass error              2337
# mass estimated          2337
# d2                      2337
# separation error        2337
# separation estimated    2337
# dtype: int64

# %%
df.head()
# Out:
#    z  n  uq  dq          d    mass error  mass estimated       d2  \
# 0  0  1   1   2   8.071317  4.000000e-07               0  0.00000
# 2  1  1   3   3  13.135722  1.000000e-07               0  2.22457
# 3  1  2   4   5  14.949810  2.000000e-07               0  6.25723
# 4  1  3   5   7  24.621127  1.000000e-01               0 -1.60000
# 5  1  4   6   9  32.892444  8.944300e-02               0 -0.20000
#
#    separation error  separation estimated
# 0           0.00000                   0.0
# 2           0.00000                   0.0
# 3           0.00000                   0.0
# 4           0.10000                   0.0
# 5           0.13416                   0.0

# %% [markdown]
# # Plot seperation energy column

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = df['n']
ys = df['z']
zs = df['d2']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D2')


plt.show()

# %%
df['d2'].to_numpy().shape
# Out:
# (2337,)

# %%
plt.scatter(range(df['d2'].count()), df['d2'].to_numpy(), s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Dividing Mass Excess by A = Z + N

# %%
zes = df['z'].to_numpy()
ns = df['n'].to_numpy()
a = zes + ns

des = df['d'].to_numpy() / a
df['d'] = des

# %% [markdown]
# # Plot Mass excess output column

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = df['n']
ys = df['z']
zs = df['d']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Tripcolor

# %%
zs = df['d']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

#yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)


fig, (ax)=plt.subplots(ncols=1)
ax.tripcolor(df["n"], df["z"], df["d"])
cb = fig.colorbar(colmap)

plt.show()

# %% [markdown]
# # Set X inputs

# %%
x = df[['z','n']]
print(x.info())
x = x.to_numpy()
print(x.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 2 columns):
# z    2337 non-null int64
# n    2337 non-null int64
# dtypes: int64(2)
# memory usage: 54.8 KB
# None
# (2337, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 10 columns):
# z                       2337 non-null int64
# n                       2337 non-null int64
# uq                      2337 non-null int64
# dq                      2337 non-null int64
# d                       2337 non-null float64
# mass error              2337 non-null float64
# mass estimated          2337 non-null int64
# d2                      2337 non-null float64
# separation error        2337 non-null float64
# separation estimated    2337 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 200.8 KB

# %% [markdown]
# # Set Y inputs _(HERE CHANGE NUMBER OF INPUTS AND RESHAPE)

# %%
y = df[['d']].to_numpy() #HERE
y.shape
# Out:
# (2337, 2)

# %%
y = y.reshape(-1,1) #HERE
y.shape
# Out:
# (2337, 2)

# %%
y[0:5]
# Out:
# array([[ 8.07131713,  0.        ],
#        [ 6.56786088,  2.22457   ],
#        [ 4.98326998,  6.25723   ],
#        [ 6.15528175, -1.6       ],
#        [ 6.5784888 , -0.2       ]])

# %% [markdown]
# # Prepare X_train_o, Y_train_o etc

# %%
X_train_o, X_test_o, y_train_o, y_test_o = train_test_split(x, y, test_size=0.2, random_state=1)
X_train_o, X_val_o, y_train_o, y_val_o  = train_test_split(X_train_o, y_train_o, test_size=0.2, random_state=1)
n_inputs = X_train_o.shape[1]
n_outputs = y_train_o.shape[1]
print(n_inputs)
print(n_outputs)
print(X_train_o.shape, X_test_o.shape,X_val_o.shape)
# Out:
# 2
# 2
# (1495, 2) (468, 2) (374, 2)

# %% [markdown]
# # Scaling

# %%
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train_o.reshape(-1, n_inputs))
X_test = x_scaler.transform(X_test_o.reshape(-1, n_inputs))
X_val = x_scaler.transform(X_val_o.reshape(-1, n_inputs))

y_train = y_scaler.fit_transform(y_train_o.reshape(-1, n_outputs))
y_test = y_scaler.transform(y_test_o.reshape(-1, n_outputs))
y_val = y_scaler.transform(y_val_o.reshape(-1, n_outputs))

n_inputs = X_train.shape[1]
n_outputs = y_train.shape[1]
print(n_inputs)
print(n_outputs)
# Out:
# 2
# 2

# %% [markdown]
# # ANN TOPOLOGY

# %%
def cust_layer(inputs,number_of_neurons, name, activation=None, dropout=False):
    init = tf.initializers.he_normal(seed=None)
    hidden = tf.keras.layers.Dense(number_of_neurons,
                                   name=name,
                                    kernel_initializer=init,
                                   activation = activation,
                                   kernel_regularizer = tf.keras.regularizers.l2(l=0.1)
                                  )(inputs)
    
    batch_norm = tf.keras.layers.BatchNormalization()(hidden, training=True)
    
    if dropout:
        dropout_layer = tf.keras.layers.Dropout(0.5)(batch_norm)
        return dropout_layer
    else:
        return batch_norm
    
tf.reset_default_graph()
with tf.name_scope("dnn"):
    with tf.name_scope("inputs"):
        X_node = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
        y_node = tf.placeholder(tf.float32, shape=(None, n_outputs), name="y")
    
    last_layer = cust_layer(X_node,50,"hidden1")    
    n_layers = 10
    
    for i in range(n_layers):      
            
        last_layer = cust_layer(last_layer,150,"hidden"+str(i),activation=tf.nn.elu,dropout=True)
    last_layer = cust_layer(last_layer,50,"hidden"+str(i+1),activation=tf.nn.elu,dropout=True)
    
    init = tf.initializers.he_normal()    
    y_pred = tf.keras.layers.Dense(n_outputs, name="output",kernel_initializer=init)(last_layer)

    
with tf.name_scope('MSE'):
    error_f = y_pred - y_node
    square_f = tf.square(error_f)
    mse = tf.reduce_mean(square_f, name="mse_first")
    variable_summaries(mse)
    print(error_f.get_shape())


with tf.name_scope('optimiser'):
    optimiser = tf.train.AdamOptimizer(0.01)
    training_op = optimiser.minimize(mse)

for var in tf.trainable_variables():
    tf.summary.histogram(var.name, var)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 14:03:04.076491 26740 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-2-outputs\utils.py:16: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0819 14:03:04.102995 26740 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-2-outputs\utils.py:22: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
# (?,)

# %% [markdown]
# # File writers

# %%
merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
test_writer = tf.summary.FileWriter(logdir + '/test')
valid_writer = tf.summary.FileWriter(logdir + '/valid')
init = tf.global_variables_initializer()

saver = tf.train.Saver()

checkpoint_path = os.path.join(dir_path, "sinus_tmp","sinus_full_model.ckpt")
checkpoint_epoch_path = checkpoint_path + ".epoch"
final_model_path = os.path.join(dir_path, "model", "my_sinus_full_model")

# %% [markdown]
# # Number of epochs and batches

# %%
n_epochs = 2000
n_batches = 50

best_loss = np.infty
epochs_without_progress = 0
max_epochs_without_progress = n_epochs * 0.2
print(max_epochs_without_progress)
# Out:
# 400.0

# %% [markdown]
# # Training

# %%
with tf.Session() as sess:
    if os.path.isfile(checkpoint_epoch_path):
        # if the checkpoint file exists, restore the model and load the epoch number
        with open(checkpoint_epoch_path, "rb") as f:
            start_epoch = int(f.read())
        print("Training was interrupted. Continuing at epoch", start_epoch)
        saver.restore(sess, checkpoint_path)
    else:
        start_epoch = 0
        sess.run(init)

    for epoch in range(start_epoch, n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, n_batches):
            summary, _ = sess.run([merged, training_op],
                                  feed_dict={X_node: X_batch, y_node: y_batch})

        train_summary, _ = sess.run([merged, training_op],feed_dict={X_node: X_train, y_node: y_train})
        test_summary, _ =sess.run([merged, training_op],feed_dict={X_node: X_test, y_node: y_test})
        validation_summary, _ = sess.run([merged, training_op], feed_dict={X_node: X_val, y_node: y_val})

        train_writer.add_summary(train_summary, epoch)
        test_writer.add_summary(test_summary, epoch)
        valid_writer.add_summary(validation_summary,epoch)

        loss_train = mse.eval(feed_dict={X_node: X_train, y_node: y_train})
        loss_val = mse.eval(feed_dict={X_node: X_val, y_node: y_val})
        print(epoch, "train loss:", loss_train, "valid loss:", loss_val)

        iteration_skip = 10
        if epoch % iteration_skip == 0:
            saver.save(sess, checkpoint_path)
            with open(checkpoint_epoch_path, "wb") as f:
                f.write(b"%d" % (epoch + 1))

        if loss_val < best_loss:
            saver.save(sess, final_model_path)
            best_loss = loss_val
            print("best loss:", best_loss)
            epochs_without_progress = 0
        else:
            epochs_without_progress += 1
            if epochs_without_progress > max_epochs_without_progress:
                print("Early stopping")
                break


train_writer.close()
test_writer.close()
valid_writer.close()
# Out:
# 0 train loss: 0.505047 valid loss: 0.6595248
# best loss: 0.6595248
# 1 train loss: 0.38662034 valid loss: 0.53300613
# best loss: 0.53300613
# 2 train loss: 0.46508962 valid loss: 0.61758876
# 3 train loss: 0.4272284 valid loss: 0.5562154
# 4 train loss: 0.5453763 valid loss: 0.7608702
# 5 train loss: 0.3481326 valid loss: 0.39791858
# best loss: 0.39791858
# 6 train loss: 0.378824 valid loss: 0.4261943
# 7 train loss: 0.2931814 valid loss: 0.32401434
# best loss: 0.32401434
# 8 train loss: 0.38828945 valid loss: 0.41805318
# 9 train loss: 0.31651416 valid loss: 0.35044795
# 10 train loss: 0.33644423 valid loss: 0.34842682
# 11 train loss: 0.4209938 valid loss: 0.4933101
# 12 train loss: 0.3648103 valid loss: 0.44876552
# 13 train loss: 0.36613995 valid loss: 0.4188438
# 14 train loss: 0.40467337 valid loss: 0.49869388
# 15 train loss: 0.2754491 valid loss: 0.34776062
# 16 train loss: 0.4004503 valid loss: 0.5567163
# 17 train loss: 0.34531116 valid loss: 0.38890743
# 18 train loss: 0.4552576 valid loss: 0.5905312
# 19 train loss: 0.33155555 valid loss: 0.39718318
# 20 train loss: 0.31367108 valid loss: 0.46101567
# 21 train loss: 0.37563738 valid loss: 0.48610634
# 22 train loss: 0.33337513 valid loss: 0.49194893
# 23 train loss: 0.38136923 valid loss: 0.41860437
# 24 train loss: 0.35777375 valid loss: 0.4735086
# 25 train loss: 0.38932946 valid loss: 0.47059566
# 26 train loss: 0.328046 valid loss: 0.43323374
# 27 train loss: 0.3310831 valid loss: 0.4369231
# 28 train loss: 0.30524525 valid loss: 0.37844676
# 29 train loss: 0.33937007 valid loss: 0.45149937
# 30 train loss: 0.34637487 valid loss: 0.38303205
# 31 train loss: 0.38055557 valid loss: 0.42155683
# 32 train loss: 0.29744437 valid loss: 0.39690018
# 33 train loss: 0.31910396 valid loss: 0.42672542
# 34 train loss: 0.3324955 valid loss: 0.4448029
# 35 train loss: 0.3091475 valid loss: 0.43512523
# 36 train loss: 0.32707882 valid loss: 0.4353424
# 37 train loss: 0.38581264 valid loss: 0.53393006
# 38 train loss: 0.2837011 valid loss: 0.35838223
# 39 train loss: 0.37479413 valid loss: 0.48413527
# 40 train loss: 0.42671147 valid loss: 0.53333634
# 41 train loss: 0.34976804 valid loss: 0.44954744
# 42 train loss: 0.27605376 valid loss: 0.34222594
# 43 train loss: 0.36371428 valid loss: 0.43542972
# 44 train loss: 0.33359325 valid loss: 0.4269881
# 45 train loss: 0.31004113 valid loss: 0.32507855
# 46 train loss: 0.34403676 valid loss: 0.4819438
# 47 train loss: 0.321081 valid loss: 0.45678338
# 48 train loss: 0.3142258 valid loss: 0.3979936
# 49 train loss: 0.33839744 valid loss: 0.38778883
# 50 train loss: 0.33849287 valid loss: 0.46199304
# 51 train loss: 0.28814906 valid loss: 0.42000258
# 52 train loss: 0.27489763 valid loss: 0.34939587
# 53 train loss: 0.29490465 valid loss: 0.39187276
# 54 train loss: 0.3010589 valid loss: 0.39403927
# 55 train loss: 0.35295975 valid loss: 0.4377752
# 56 train loss: 0.291657 valid loss: 0.39471918
# 57 train loss: 0.36403513 valid loss: 0.48020282
# 58 train loss: 0.3641101 valid loss: 0.48375425
# 59 train loss: 0.3032093 valid loss: 0.37296286
# 60 train loss: 0.44069415 valid loss: 0.5939616
# 61 train loss: 0.33636695 valid loss: 0.4774521
# 62 train loss: 0.43454123 valid loss: 0.532611
# 63 train loss: 0.27834263 valid loss: 0.34727
# 64 train loss: 0.32497868 valid loss: 0.4359581
# 65 train loss: 0.3066181 valid loss: 0.40722305
# 66 train loss: 0.2582016 valid loss: 0.32502443
# 67 train loss: 0.35340518 valid loss: 0.46621683
# 68 train loss: 0.28588098 valid loss: 0.3712421
# 69 train loss: 0.32467178 valid loss: 0.4111402
# 70 train loss: 0.31498936 valid loss: 0.39632767
# 71 train loss: 0.2954208 valid loss: 0.39412963
# 72 train loss: 0.36754835 valid loss: 0.4288029
# 73 train loss: 0.40883678 valid loss: 0.5338793
# 74 train loss: 0.29495758 valid loss: 0.41042632
# 75 train loss: 0.34340203 valid loss: 0.46943784
# 76 train loss: 0.3141411 valid loss: 0.3710705
# 77 train loss: 0.30744994 valid loss: 0.44085118
# 78 train loss: 0.36090133 valid loss: 0.43853366
# 79 train loss: 0.37694532 valid loss: 0.5101787
# 80 train loss: 0.33422557 valid loss: 0.43200427
# 81 train loss: 0.26489797 valid loss: 0.2852004
# best loss: 0.2852004
# 82 train loss: 0.28075302 valid loss: 0.3973791
# 83 train loss: 0.28541183 valid loss: 0.3698014
# 84 train loss: 0.31188893 valid loss: 0.401313
# 85 train loss: 0.29889992 valid loss: 0.35007477
# 86 train loss: 0.3357908 valid loss: 0.4764858
# 87 train loss: 0.3701358 valid loss: 0.4447171
# 88 train loss: 0.28600237 valid loss: 0.36309215
# 89 train loss: 0.31731045 valid loss: 0.4267807
# 90 train loss: 0.32312825 valid loss: 0.34249246
# 91 train loss: 0.31160915 valid loss: 0.38793725
# 92 train loss: 0.6261512 valid loss: 0.7531556
# 93 train loss: 0.31297764 valid loss: 0.37966838
# 94 train loss: 0.3129112 valid loss: 0.4065547
# 95 train loss: 0.29358655 valid loss: 0.39862037
# 96 train loss: 0.30592707 valid loss: 0.421322
# 97 train loss: 0.45303667 valid loss: 0.52014613
# 98 train loss: 0.29251808 valid loss: 0.3942664
# 99 train loss: 0.29880294 valid loss: 0.3827083
# 100 train loss: 0.29188603 valid loss: 0.33880123
# 101 train loss: 0.35696983 valid loss: 0.49692178
# 102 train loss: 0.31846952 valid loss: 0.4285854
# 103 train loss: 0.35261226 valid loss: 0.48697543
# 104 train loss: 0.3626135 valid loss: 0.42948362
# 105 train loss: 0.3288662 valid loss: 0.45914227
# 106 train loss: 0.288857 valid loss: 0.39336652
# 107 train loss: 0.35005105 valid loss: 0.43442208
# 108 train loss: 0.28050992 valid loss: 0.37898648
# 109 train loss: 0.30765325 valid loss: 0.3802408
# 110 train loss: 0.2847691 valid loss: 0.3841101
# 111 train loss: 0.38341781 valid loss: 0.537079
# 112 train loss: 0.3061933 valid loss: 0.38964218
# 113 train loss: 0.3045751 valid loss: 0.39250404
# 114 train loss: 0.36007738 valid loss: 0.43529984
# 115 train loss: 0.38722858 valid loss: 0.5204262
# 116 train loss: 0.29910275 valid loss: 0.4098644
# 117 train loss: 0.40575796 valid loss: 0.5776171
# 118 train loss: 0.27661476 valid loss: 0.33457989
# 119 train loss: 0.33431178 valid loss: 0.41359222
# 120 train loss: 0.3723052 valid loss: 0.3994858
# 121 train loss: 0.38353944 valid loss: 0.46131146
# 122 train loss: 0.31085083 valid loss: 0.41564733
# 123 train loss: 0.56788206 valid loss: 0.66943145
# 124 train loss: 0.28190115 valid loss: 0.35628334
# 125 train loss: 0.32517987 valid loss: 0.420532
# 126 train loss: 0.40082747 valid loss: 0.48764825
# 127 train loss: 0.32426903 valid loss: 0.45709145
# 128 train loss: 0.26472616 valid loss: 0.3619051
# 129 train loss: 0.29793298 valid loss: 0.32815412
# 130 train loss: 0.298882 valid loss: 0.4109642
# 131 train loss: 0.34158584 valid loss: 0.4066081
# 132 train loss: 0.31500715 valid loss: 0.4265991
# 133 train loss: 0.4054546 valid loss: 0.50786465
# 134 train loss: 0.29308006 valid loss: 0.37379003
# 135 train loss: 0.35118955 valid loss: 0.4402268
# 136 train loss: 0.29260072 valid loss: 0.40557563
# 137 train loss: 0.3295096 valid loss: 0.4279439
# 138 train loss: 0.25894395 valid loss: 0.3215227
# 139 train loss: 0.30326414 valid loss: 0.35320878
# 140 train loss: 0.27603117 valid loss: 0.33904696
# 141 train loss: 0.30698466 valid loss: 0.4214632
# 142 train loss: 0.28161672 valid loss: 0.345136
# 143 train loss: 0.2611831 valid loss: 0.3640972
# 144 train loss: 0.28774464 valid loss: 0.3670076
# 145 train loss: 0.35226125 valid loss: 0.44476682
# 146 train loss: 0.6677941 valid loss: 0.85127467
# 147 train loss: 0.36287487 valid loss: 0.47477072
# 148 train loss: 0.3259249 valid loss: 0.4294505
# 149 train loss: 0.32137263 valid loss: 0.42679152
# 150 train loss: 0.3065221 valid loss: 0.3779819
# 151 train loss: 0.31551728 valid loss: 0.38789144
# 152 train loss: 0.33459857 valid loss: 0.46874714
# 153 train loss: 0.47054744 valid loss: 0.573073
# 154 train loss: 0.39720383 valid loss: 0.5223317
# 155 train loss: 0.30049068 valid loss: 0.3937294
# 156 train loss: 0.37569892 valid loss: 0.4653448
# 157 train loss: 0.36577308 valid loss: 0.4303546
# 158 train loss: 0.28643197 valid loss: 0.40189195
# 159 train loss: 0.39291638 valid loss: 0.4618644
# 160 train loss: 0.36397773 valid loss: 0.46207502
# 161 train loss: 0.2943169 valid loss: 0.36435694
# 162 train loss: 0.30699313 valid loss: 0.39425677
# 163 train loss: 0.26245034 valid loss: 0.36399674
# 164 train loss: 0.27494848 valid loss: 0.36556938
# 165 train loss: 0.3117262 valid loss: 0.4048118
# 166 train loss: 0.35453898 valid loss: 0.47362489
# 167 train loss: 0.3805334 valid loss: 0.50182056
# 168 train loss: 0.3257392 valid loss: 0.4002992
# 169 train loss: 0.31100184 valid loss: 0.4321708
# 170 train loss: 0.2565297 valid loss: 0.32823116
# 171 train loss: 0.35124785 valid loss: 0.42321008
# 172 train loss: 0.2841468 valid loss: 0.3912253
# 173 train loss: 0.3639944 valid loss: 0.42532733
# 174 train loss: 0.32300752 valid loss: 0.42328697
# 175 train loss: 0.29834795 valid loss: 0.40534317
# 176 train loss: 0.2712711 valid loss: 0.3546358
# 177 train loss: 0.33712485 valid loss: 0.4309094
# 178 train loss: 0.27339756 valid loss: 0.3550641
# 179 train loss: 0.31365418 valid loss: 0.39953732
# 180 train loss: 0.298538 valid loss: 0.35453343
# 181 train loss: 0.33549953 valid loss: 0.44466794
# 182 train loss: 0.30774754 valid loss: 0.3741302
# 183 train loss: 0.3191935 valid loss: 0.4369732
# 184 train loss: 0.27883995 valid loss: 0.3520694
# 185 train loss: 0.27372512 valid loss: 0.3445332
# 186 train loss: 0.4500412 valid loss: 0.5966056
# 187 train loss: 0.29539454 valid loss: 0.38152134
# 188 train loss: 0.32179847 valid loss: 0.39825153
# 189 train loss: 0.26843268 valid loss: 0.35837543
# 190 train loss: 0.30967045 valid loss: 0.39355457
# 191 train loss: 0.48061866 valid loss: 0.69385916
# 192 train loss: 0.3663144 valid loss: 0.46188098
# 193 train loss: 0.37476885 valid loss: 0.44458887
# 194 train loss: 0.3201894 valid loss: 0.37924188
# 195 train loss: 0.33168355 valid loss: 0.41005033
# 196 train loss: 0.30758741 valid loss: 0.44778752
# 197 train loss: 0.3071958 valid loss: 0.39198112
# 198 train loss: 0.25324696 valid loss: 0.33202362
# 199 train loss: 0.32806462 valid loss: 0.4050418
# 200 train loss: 0.35613406 valid loss: 0.4652456
# 201 train loss: 0.31338438 valid loss: 0.36700922
# 202 train loss: 0.37236202 valid loss: 0.4638176
# 203 train loss: 0.33656162 valid loss: 0.40166035
# 204 train loss: 0.33615083 valid loss: 0.36798275
# 205 train loss: 0.2694881 valid loss: 0.3142013
# 206 train loss: 0.23630308 valid loss: 0.28305122
# best loss: 0.28305122
# 207 train loss: 0.28077415 valid loss: 0.36404735
# 208 train loss: 0.2646848 valid loss: 0.3259458
# 209 train loss: 0.2835608 valid loss: 0.353742
# 210 train loss: 0.3242097 valid loss: 0.4395568
# 211 train loss: 0.3301403 valid loss: 0.42813075
# 212 train loss: 0.30160654 valid loss: 0.38237917
# 213 train loss: 0.33625692 valid loss: 0.44060117
# 214 train loss: 0.25933337 valid loss: 0.3336141
# 215 train loss: 0.3488824 valid loss: 0.38788247
# 216 train loss: 0.31761533 valid loss: 0.37636304
# 217 train loss: 0.26762918 valid loss: 0.33640862
# 218 train loss: 0.30264816 valid loss: 0.36325157
# 219 train loss: 0.27174556 valid loss: 0.36146885
# 220 train loss: 0.3719313 valid loss: 0.39284426
# 221 train loss: 0.2593045 valid loss: 0.30888063
# 222 train loss: 0.40706128 valid loss: 0.48004103
# 223 train loss: 0.2951359 valid loss: 0.3829195
# 224 train loss: 0.28948826 valid loss: 0.36139256
# 225 train loss: 0.32008696 valid loss: 0.39065677
# 226 train loss: 0.30343756 valid loss: 0.39896524
# 227 train loss: 0.26882353 valid loss: 0.31463432
# 228 train loss: 0.35151628 valid loss: 0.3906558
# 229 train loss: 0.32572016 valid loss: 0.38021913
# 230 train loss: 0.3299097 valid loss: 0.34480977
# 231 train loss: 0.2826206 valid loss: 0.36095715
# 232 train loss: 0.339455 valid loss: 0.365628
# 233 train loss: 0.3610012 valid loss: 0.42824978
# 234 train loss: 0.26777416 valid loss: 0.3440004
# 235 train loss: 0.3697881 valid loss: 0.4622237
# 236 train loss: 0.26975974 valid loss: 0.32705098
# 237 train loss: 0.2565633 valid loss: 0.27808452
# best loss: 0.27808452
# 238 train loss: 0.31334022 valid loss: 0.41119257
# 239 train loss: 0.2971536 valid loss: 0.3685509
# 240 train loss: 0.31660503 valid loss: 0.38869107
# 241 train loss: 0.30272698 valid loss: 0.3573168
# 242 train loss: 0.39936256 valid loss: 0.43071425
# 243 train loss: 0.27312523 valid loss: 0.32934338
# 244 train loss: 0.34395427 valid loss: 0.38065112
# 245 train loss: 0.30941948 valid loss: 0.40698397
# 246 train loss: 0.253928 valid loss: 0.28432155
# 247 train loss: 0.3183071 valid loss: 0.36783385
# 248 train loss: 0.2782209 valid loss: 0.29793447
# 249 train loss: 0.25696144 valid loss: 0.28586656
# 250 train loss: 0.24836957 valid loss: 0.2933111
# 251 train loss: 0.35851985 valid loss: 0.41827786
# 252 train loss: 0.35091308 valid loss: 0.44317058
# 253 train loss: 0.3049578 valid loss: 0.37937826
# 254 train loss: 0.2584958 valid loss: 0.31932002
# 255 train loss: 0.3026859 valid loss: 0.35552374
# 256 train loss: 0.2961695 valid loss: 0.34778672
# 257 train loss: 0.40986788 valid loss: 0.43940076
# 258 train loss: 0.3091283 valid loss: 0.3626625
# 259 train loss: 0.26256412 valid loss: 0.30219212
# 260 train loss: 0.32147262 valid loss: 0.35432506
# 261 train loss: 0.25441033 valid loss: 0.30122164
# 262 train loss: 0.3364848 valid loss: 0.4069509
# 263 train loss: 0.2739104 valid loss: 0.34043333
# 264 train loss: 0.36332178 valid loss: 0.44759288
# 265 train loss: 0.32034522 valid loss: 0.41174752
# 266 train loss: 0.240331 valid loss: 0.2950406
# 267 train loss: 0.2920111 valid loss: 0.34926465
# 268 train loss: 0.27008945 valid loss: 0.3590383
# 269 train loss: 0.2941756 valid loss: 0.3276711
# 270 train loss: 0.26134962 valid loss: 0.27774772
# best loss: 0.27774772
# 271 train loss: 0.30034935 valid loss: 0.3637396
# 272 train loss: 0.3553901 valid loss: 0.4498418
# 273 train loss: 0.3478116 valid loss: 0.41663164
# 274 train loss: 0.3004416 valid loss: 0.34211022
# 275 train loss: 0.2681768 valid loss: 0.3285852
# 276 train loss: 0.27216136 valid loss: 0.34676784
# 277 train loss: 0.29506838 valid loss: 0.32459486
# 278 train loss: 0.25330353 valid loss: 0.29565126
# 279 train loss: 0.33935955 valid loss: 0.41934624
# 280 train loss: 0.30078763 valid loss: 0.36731184
# 281 train loss: 0.26708665 valid loss: 0.31539702
# 282 train loss: 0.3922303 valid loss: 0.4541028
# 283 train loss: 0.36743703 valid loss: 0.41961622
# 284 train loss: 0.26067924 valid loss: 0.30830976
# 285 train loss: 0.51892436 valid loss: 0.49956685
# 286 train loss: 0.25955996 valid loss: 0.33032015
# 287 train loss: 0.40319884 valid loss: 0.44953603
# 288 train loss: 0.29602236 valid loss: 0.35344726
# 289 train loss: 0.28335583 valid loss: 0.36499786
# 290 train loss: 0.2706402 valid loss: 0.32853258
# 291 train loss: 0.34265175 valid loss: 0.34632215
# 292 train loss: 0.283928 valid loss: 0.32967618
# 293 train loss: 0.30023828 valid loss: 0.36202854
# 294 train loss: 0.250927 valid loss: 0.3109889
# 295 train loss: 0.25577247 valid loss: 0.31480813
# 296 train loss: 0.2734861 valid loss: 0.30401096
# 297 train loss: 0.255388 valid loss: 0.32129222
# 298 train loss: 0.90353835 valid loss: 1.0467064
# 299 train loss: 0.31743288 valid loss: 0.38574865
# 300 train loss: 0.27899545 valid loss: 0.35542732
# 301 train loss: 0.3102319 valid loss: 0.37654826
# 302 train loss: 0.26922297 valid loss: 0.31914693
# 303 train loss: 0.3207841 valid loss: 0.40454787
# 304 train loss: 0.2909342 valid loss: 0.37357408
# 305 train loss: 0.38001603 valid loss: 0.43301857
# 306 train loss: 0.26688844 valid loss: 0.28139096
# 307 train loss: 0.24650542 valid loss: 0.29416353
# 308 train loss: 0.28574705 valid loss: 0.32845658
# 309 train loss: 0.2496727 valid loss: 0.31529918
# 310 train loss: 0.29165047 valid loss: 0.35769725
# 311 train loss: 0.2699128 valid loss: 0.32349235
# 312 train loss: 0.3139699 valid loss: 0.36868954
# 313 train loss: 0.2716463 valid loss: 0.29570726
# 314 train loss: 0.3142377 valid loss: 0.34470874
# 315 train loss: 0.26649952 valid loss: 0.29372862
# 316 train loss: 0.2755085 valid loss: 0.32673305
# 317 train loss: 0.27680722 valid loss: 0.30804494
# 318 train loss: 0.2638395 valid loss: 0.28997225
# 319 train loss: 0.36075896 valid loss: 0.3916898
# 320 train loss: 0.25309372 valid loss: 0.28152102
# 321 train loss: 0.27480745 valid loss: 0.34137273
# 322 train loss: 0.28069112 valid loss: 0.313824
# 323 train loss: 0.28027877 valid loss: 0.3344846
# 324 train loss: 0.30399868 valid loss: 0.37711924
# 325 train loss: 0.31720424 valid loss: 0.3244928
# 326 train loss: 0.31708223 valid loss: 0.39986002
# 327 train loss: 0.2753993 valid loss: 0.34524378
# 328 train loss: 0.2710693 valid loss: 0.3292398
# 329 train loss: 0.258678 valid loss: 0.30214965
# 330 train loss: 0.26802683 valid loss: 0.3372946
# 331 train loss: 0.34057155 valid loss: 0.42513967
# 332 train loss: 0.29107505 valid loss: 0.30894402
# 333 train loss: 0.32721618 valid loss: 0.40800643
# 334 train loss: 0.2594235 valid loss: 0.32969683
# 335 train loss: 0.29575187 valid loss: 0.3872958
# 336 train loss: 0.25411576 valid loss: 0.29222608
# 337 train loss: 0.2454898 valid loss: 0.29930034
# 338 train loss: 0.23973365 valid loss: 0.2600618
# best loss: 0.2600618
# 339 train loss: 0.27809116 valid loss: 0.35164556
# 340 train loss: 0.2684029 valid loss: 0.3129856
# 341 train loss: 0.28059575 valid loss: 0.31187746
# 342 train loss: 0.2753487 valid loss: 0.35280162
# 343 train loss: 0.28192768 valid loss: 0.35708255
# 344 train loss: 0.28013113 valid loss: 0.30877113
# 345 train loss: 0.2458992 valid loss: 0.27858406
# 346 train loss: 0.24544825 valid loss: 0.28663194
# 347 train loss: 0.26734197 valid loss: 0.2922137
# 348 train loss: 0.26151174 valid loss: 0.28178805
# 349 train loss: 0.26670256 valid loss: 0.32366413
# 350 train loss: 0.25791004 valid loss: 0.2824583
# 351 train loss: 0.33451495 valid loss: 0.42458373
# 352 train loss: 0.310498 valid loss: 0.3882081
# 353 train loss: 0.2716824 valid loss: 0.2963339
# 354 train loss: 0.25988525 valid loss: 0.3216759
# 355 train loss: 0.2527151 valid loss: 0.32945782
# 356 train loss: 0.28035128 valid loss: 0.3583078
# 357 train loss: 0.27456623 valid loss: 0.3409812
# 358 train loss: 0.27274778 valid loss: 0.31361002
# 359 train loss: 0.2689577 valid loss: 0.3130712
# 360 train loss: 0.29177064 valid loss: 0.31499362
# 361 train loss: 0.37579277 valid loss: 0.51844895
# 362 train loss: 0.250672 valid loss: 0.2821077
# 363 train loss: 0.32245564 valid loss: 0.3641009
# 364 train loss: 0.26479352 valid loss: 0.32079872
# 365 train loss: 0.2583557 valid loss: 0.30718502
# 366 train loss: 0.25844315 valid loss: 0.27465218
# 367 train loss: 0.2925272 valid loss: 0.3595873
# 368 train loss: 0.26952505 valid loss: 0.29932898
# 369 train loss: 0.48054126 valid loss: 0.6408298
# 370 train loss: 0.2870662 valid loss: 0.3807688
# 371 train loss: 0.28750843 valid loss: 0.3214107
# 372 train loss: 0.2653278 valid loss: 0.30341047
# 373 train loss: 0.27575058 valid loss: 0.33659673
# 374 train loss: 0.34851253 valid loss: 0.37882856
# 375 train loss: 0.26296037 valid loss: 0.34554198
# 376 train loss: 0.2555774 valid loss: 0.28518942
# 377 train loss: 0.24627022 valid loss: 0.27146074
# 378 train loss: 0.2988134 valid loss: 0.27832443
# 379 train loss: 0.2945201 valid loss: 0.37381113
# 380 train loss: 0.28538615 valid loss: 0.3554933
# 381 train loss: 0.30885538 valid loss: 0.31980842
# 382 train loss: 0.25756443 valid loss: 0.2938313
# 383 train loss: 0.25659543 valid loss: 0.30791515
# 384 train loss: 0.25516075 valid loss: 0.29711214
# 385 train loss: 0.45815796 valid loss: 0.58917797
# 386 train loss: 0.372724 valid loss: 0.4935391
# 387 train loss: 0.26071662 valid loss: 0.32266274
# 388 train loss: 0.25226972 valid loss: 0.29021809
# 389 train loss: 0.29553255 valid loss: 0.33846325
# 390 train loss: 0.37926918 valid loss: 0.37493184
# 391 train loss: 0.28663638 valid loss: 0.32357204
# 392 train loss: 0.25933337 valid loss: 0.29544032
# 393 train loss: 0.2475439 valid loss: 0.29212
# 394 train loss: 0.2580041 valid loss: 0.29099688
# 395 train loss: 0.23214644 valid loss: 0.2833554
# 396 train loss: 0.26035687 valid loss: 0.31168988
# 397 train loss: 0.3781818 valid loss: 0.47908717
# 398 train loss: 0.24473171 valid loss: 0.28403562
# 399 train loss: 0.25846156 valid loss: 0.30616906
# 400 train loss: 0.33207226 valid loss: 0.3823179
# 401 train loss: 0.58268625 valid loss: 0.57055604
# 402 train loss: 0.2876286 valid loss: 0.37550688
# 403 train loss: 0.2702279 valid loss: 0.3328488
# 404 train loss: 0.2679043 valid loss: 0.36088866
# 405 train loss: 0.25152585 valid loss: 0.28849518
# 406 train loss: 0.6166389 valid loss: 0.75381947
# 407 train loss: 0.41529006 valid loss: 0.50790274
# 408 train loss: 0.291103 valid loss: 0.35452503
# 409 train loss: 0.30675548 valid loss: 0.3599678
# 410 train loss: 0.28207967 valid loss: 0.36066723
# 411 train loss: 0.2841391 valid loss: 0.3447361
# 412 train loss: 0.26122546 valid loss: 0.3354892
# 413 train loss: 0.28081506 valid loss: 0.3576604
# 414 train loss: 0.282466 valid loss: 0.35895604
# 415 train loss: 0.29523396 valid loss: 0.37576404
# 416 train loss: 0.2586938 valid loss: 0.28567645
# 417 train loss: 0.28831622 valid loss: 0.34058112
# 418 train loss: 0.5647385 valid loss: 0.69765854
# 419 train loss: 0.34123915 valid loss: 0.4004351
# 420 train loss: 0.3048952 valid loss: 0.3484918
# 421 train loss: 0.25991252 valid loss: 0.27690727
# 422 train loss: 0.25865448 valid loss: 0.29751444
# 423 train loss: 0.2888044 valid loss: 0.34497774
# 424 train loss: 0.3098018 valid loss: 0.34391707
# 425 train loss: 0.24858922 valid loss: 0.26908407
# 426 train loss: 0.26211107 valid loss: 0.29576272
# 427 train loss: 0.24662125 valid loss: 0.28168702
# 428 train loss: 0.27303234 valid loss: 0.35491642
# 429 train loss: 0.25061837 valid loss: 0.30808404
# 430 train loss: 0.2771897 valid loss: 0.3335507
# 431 train loss: 0.26075608 valid loss: 0.2767936
# 432 train loss: 0.24619596 valid loss: 0.2617397
# 433 train loss: 0.29672274 valid loss: 0.34508184
# 434 train loss: 0.26231024 valid loss: 0.24682686
# best loss: 0.24682686
# 435 train loss: 0.2515626 valid loss: 0.25340176
# 436 train loss: 0.3476193 valid loss: 0.42244744
# 437 train loss: 0.27479243 valid loss: 0.3366604
# 438 train loss: 0.26954144 valid loss: 0.3252958
# 439 train loss: 0.27205974 valid loss: 0.3150038
# 440 train loss: 0.25309008 valid loss: 0.3023718
# 441 train loss: 0.25307652 valid loss: 0.29591835
# 442 train loss: 0.25452483 valid loss: 0.30872902
# 443 train loss: 0.27449661 valid loss: 0.31844267
# 444 train loss: 0.28064588 valid loss: 0.34856975
# 445 train loss: 0.2623123 valid loss: 0.31251886
# 446 train loss: 0.23319268 valid loss: 0.27149186
# 447 train loss: 0.26430315 valid loss: 0.28275153
# 448 train loss: 0.30357444 valid loss: 0.37471503
# 449 train loss: 0.27381384 valid loss: 0.27728894
# 450 train loss: 0.26154527 valid loss: 0.3027292
# 451 train loss: 0.26191774 valid loss: 0.33932298
# 452 train loss: 0.24207751 valid loss: 0.28321305
# 453 train loss: 0.24438432 valid loss: 0.25324136
# 454 train loss: 0.25373083 valid loss: 0.2967458
# 455 train loss: 0.30276737 valid loss: 0.3696921
# 456 train loss: 0.27045587 valid loss: 0.34768626
# 457 train loss: 0.31298256 valid loss: 0.40205252
# 458 train loss: 0.26048386 valid loss: 0.3034082
# 459 train loss: 0.435144 valid loss: 0.5225996
# 460 train loss: 0.31791225 valid loss: 0.34022158
# 461 train loss: 0.26365775 valid loss: 0.27652216
# 462 train loss: 0.26133615 valid loss: 0.31488228
# 463 train loss: 0.2654184 valid loss: 0.29392493
# 464 train loss: 0.24696067 valid loss: 0.29033345
# 465 train loss: 0.27039528 valid loss: 0.3114531
# 466 train loss: 0.2628988 valid loss: 0.31857297
# 467 train loss: 0.37522525 valid loss: 0.37633777
# 468 train loss: 0.29071987 valid loss: 0.38184822
# 469 train loss: 0.23655424 valid loss: 0.2806699
# 470 train loss: 0.2421504 valid loss: 0.31280994
# 471 train loss: 0.2738724 valid loss: 0.36692673
# 472 train loss: 0.25932908 valid loss: 0.31734973
# 473 train loss: 0.3168007 valid loss: 0.40943438
# 474 train loss: 0.27490723 valid loss: 0.36146185
# 475 train loss: 0.2476847 valid loss: 0.29759356
# 476 train loss: 0.25865877 valid loss: 0.28717446
# 477 train loss: 0.24762115 valid loss: 0.30706736
# 478 train loss: 0.2950036 valid loss: 0.33639723
# 479 train loss: 0.25953805 valid loss: 0.29005924
# 480 train loss: 0.25166816 valid loss: 0.27536172
# 481 train loss: 0.245812 valid loss: 0.28230998
# 482 train loss: 0.24307449 valid loss: 0.22264563
# best loss: 0.22264563
# 483 train loss: 0.23514283 valid loss: 0.2588804
# 484 train loss: 0.29017588 valid loss: 0.38475823
# 485 train loss: 0.24429706 valid loss: 0.28156602
# 486 train loss: 0.3063016 valid loss: 0.3832817
# 487 train loss: 0.35337502 valid loss: 0.3808978
# 488 train loss: 0.43217003 valid loss: 0.5580244
# 489 train loss: 0.29244304 valid loss: 0.32869077
# 490 train loss: 0.28124726 valid loss: 0.3322587
# 491 train loss: 0.30567545 valid loss: 0.41595042
# 492 train loss: 0.24697916 valid loss: 0.29059124
# 493 train loss: 0.26911747 valid loss: 0.30707252
# 494 train loss: 0.24594997 valid loss: 0.27916017
# 495 train loss: 0.25255284 valid loss: 0.31109142
# 496 train loss: 0.3270005 valid loss: 0.33117172
# 497 train loss: 0.27088687 valid loss: 0.32230178
# 498 train loss: 0.25660476 valid loss: 0.28256613
# 499 train loss: 0.2789106 valid loss: 0.35138986
# 500 train loss: 0.4261306 valid loss: 0.342696
# 501 train loss: 0.26262906 valid loss: 0.28929895
# 502 train loss: 0.2504286 valid loss: 0.31210268
# 503 train loss: 0.43607157 valid loss: 0.35741308
# 504 train loss: 0.2553212 valid loss: 0.255453
# 505 train loss: 0.33166924 valid loss: 0.32828882
# 506 train loss: 0.26150692 valid loss: 0.3270856
# 507 train loss: 0.2503763 valid loss: 0.31089467
# 508 train loss: 0.2430298 valid loss: 0.2742366
# 509 train loss: 0.27570632 valid loss: 0.31297594
# 510 train loss: 0.29043418 valid loss: 0.36947
# 511 train loss: 0.24779274 valid loss: 0.2728564
# 512 train loss: 0.26373395 valid loss: 0.3294583
# 513 train loss: 0.30343217 valid loss: 0.34573323
# 514 train loss: 0.27467942 valid loss: 0.36153138
# 515 train loss: 0.27528682 valid loss: 0.30979875
# 516 train loss: 0.2568777 valid loss: 0.31867298
# 517 train loss: 0.25907207 valid loss: 0.3482739
# 518 train loss: 0.23718974 valid loss: 0.29614675
# 519 train loss: 0.2535315 valid loss: 0.26116532
# 520 train loss: 0.25798187 valid loss: 0.2691219
# 521 train loss: 0.2645811 valid loss: 0.31749946
# 522 train loss: 0.3052559 valid loss: 0.3505293
# 523 train loss: 0.2555697 valid loss: 0.30900708
# 524 train loss: 0.23378319 valid loss: 0.2751652
# 525 train loss: 0.27482235 valid loss: 0.33912724
# 526 train loss: 0.26543412 valid loss: 0.31623784
# 527 train loss: 0.26533645 valid loss: 0.30344996
# 528 train loss: 0.33606675 valid loss: 0.42099896
# 529 train loss: 0.33979154 valid loss: 0.34574988
# 530 train loss: 0.3533495 valid loss: 0.36368895
# 531 train loss: 0.23768891 valid loss: 0.30154648
# 532 train loss: 0.28961715 valid loss: 0.39434958
# 533 train loss: 0.27044588 valid loss: 0.2967057
# 534 train loss: 0.23007861 valid loss: 0.24607459
# 535 train loss: 0.26318288 valid loss: 0.34350726
# 536 train loss: 0.2841474 valid loss: 0.322779
# 537 train loss: 0.29564968 valid loss: 0.324736
# 538 train loss: 0.30314112 valid loss: 0.35660142
# 539 train loss: 0.2732329 valid loss: 0.31743565
# 540 train loss: 0.23977692 valid loss: 0.27184922
# 541 train loss: 0.26543328 valid loss: 0.2977618
# 542 train loss: 0.29247132 valid loss: 0.2847261
# 543 train loss: 0.23892103 valid loss: 0.2753051
# 544 train loss: 0.24514073 valid loss: 0.30009478
# 545 train loss: 0.26632607 valid loss: 0.3392654
# 546 train loss: 0.2685291 valid loss: 0.30491585
# 547 train loss: 0.24059302 valid loss: 0.29953656
# 548 train loss: 0.24145761 valid loss: 0.2856372
# 549 train loss: 0.29098392 valid loss: 0.3348564
# 550 train loss: 0.23284656 valid loss: 0.26139042
# 551 train loss: 0.2607312 valid loss: 0.32636204
# 552 train loss: 0.24486813 valid loss: 0.23946169
# 553 train loss: 0.2693411 valid loss: 0.3347388
# 554 train loss: 0.2549333 valid loss: 0.27513188
# 555 train loss: 0.3075431 valid loss: 0.3629061
# 556 train loss: 0.2957975 valid loss: 0.31418407
# 557 train loss: 0.25077757 valid loss: 0.29926613
# 558 train loss: 0.256579 valid loss: 0.31694007
# 559 train loss: 0.26026574 valid loss: 0.3122199
# 560 train loss: 0.2320654 valid loss: 0.2503556
# 561 train loss: 0.26145878 valid loss: 0.3289205
# 562 train loss: 0.2314001 valid loss: 0.2647684
# 563 train loss: 0.3677581 valid loss: 0.3745262
# 564 train loss: 0.30255118 valid loss: 0.33746818
# 565 train loss: 0.2735432 valid loss: 0.31003657
# 566 train loss: 0.2605391 valid loss: 0.31386122
# 567 train loss: 0.2353398 valid loss: 0.29058677
# 568 train loss: 0.29473963 valid loss: 0.35590377
# 569 train loss: 0.23069467 valid loss: 0.29637644
# 570 train loss: 0.26692185 valid loss: 0.30423856
# 571 train loss: 0.25561872 valid loss: 0.28634936
# 572 train loss: 0.23411912 valid loss: 0.27706385
# 573 train loss: 0.28669497 valid loss: 0.34985894
# 574 train loss: 0.24471204 valid loss: 0.31501347
# 575 train loss: 0.24853215 valid loss: 0.29942602
# 576 train loss: 0.250799 valid loss: 0.34058854
# 577 train loss: 0.24607056 valid loss: 0.2750619
# 578 train loss: 0.24030152 valid loss: 0.26550916
# 579 train loss: 0.28944957 valid loss: 0.33844614
# 580 train loss: 0.30743948 valid loss: 0.4211643
# 581 train loss: 0.24758619 valid loss: 0.2733122
# 582 train loss: 0.28955486 valid loss: 0.29107416
# 583 train loss: 0.2635064 valid loss: 0.29833964
# 584 train loss: 0.243808 valid loss: 0.31594902
# 585 train loss: 0.245538 valid loss: 0.2963608
# 586 train loss: 0.22703563 valid loss: 0.23709656
# 587 train loss: 0.2626367 valid loss: 0.31790262
# 588 train loss: 0.2364054 valid loss: 0.2666843
# 589 train loss: 0.23985775 valid loss: 0.2909165
# 590 train loss: 0.25718322 valid loss: 0.31939858
# 591 train loss: 0.25045258 valid loss: 0.30949494
# 592 train loss: 0.29280967 valid loss: 0.36095178
# 593 train loss: 0.25432098 valid loss: 0.32604712
# 594 train loss: 0.2538578 valid loss: 0.30871892
# 595 train loss: 0.27224916 valid loss: 0.29854894
# 596 train loss: 0.23492907 valid loss: 0.27077788
# 597 train loss: 0.23339635 valid loss: 0.29087412
# 598 train loss: 0.23982549 valid loss: 0.2818458
# 599 train loss: 0.3501 valid loss: 0.43538052
# 600 train loss: 0.26631236 valid loss: 0.3286687
# 601 train loss: 0.28053477 valid loss: 0.3485526
# 602 train loss: 0.24749444 valid loss: 0.28288382
# 603 train loss: 0.24701567 valid loss: 0.30431798
# 604 train loss: 0.2371056 valid loss: 0.28531992
# 605 train loss: 0.28525534 valid loss: 0.3001601
# 606 train loss: 0.23800756 valid loss: 0.25366774
# 607 train loss: 0.26540995 valid loss: 0.3164724
# 608 train loss: 0.24204196 valid loss: 0.25835836
# 609 train loss: 0.32219538 valid loss: 0.2669353
# 610 train loss: 0.28247252 valid loss: 0.30187017
# 611 train loss: 0.24664944 valid loss: 0.3176095
# 612 train loss: 0.29351205 valid loss: 0.33534482
# 613 train loss: 0.2562021 valid loss: 0.30300087
# 614 train loss: 0.25145766 valid loss: 0.28530902
# 615 train loss: 0.5501332 valid loss: 0.482165
# 616 train loss: 0.29095346 valid loss: 0.31942856
# 617 train loss: 0.2703777 valid loss: 0.3097205
# 618 train loss: 0.2554307 valid loss: 0.32532793
# 619 train loss: 0.24207698 valid loss: 0.3260231
# 620 train loss: 0.278034 valid loss: 0.34923363
# 621 train loss: 0.2496863 valid loss: 0.31345606
# 622 train loss: 0.27133223 valid loss: 0.34386042
# 623 train loss: 0.28622752 valid loss: 0.3879247
# 624 train loss: 0.25232753 valid loss: 0.30344772
# 625 train loss: 0.28509685 valid loss: 0.38181898
# 626 train loss: 0.24398908 valid loss: 0.28588614
# 627 train loss: 0.24118909 valid loss: 0.29253063
# 628 train loss: 0.23209323 valid loss: 0.28720328
# 629 train loss: 0.24632198 valid loss: 0.28347075
# 630 train loss: 0.29176873 valid loss: 0.32232803
# 631 train loss: 0.27922818 valid loss: 0.38869348
# 632 train loss: 0.23549274 valid loss: 0.29471442
# 633 train loss: 0.25182232 valid loss: 0.29388157
# 634 train loss: 0.23923886 valid loss: 0.30629212
# 635 train loss: 0.2693078 valid loss: 0.26597926
# 636 train loss: 0.30304998 valid loss: 0.32842022
# 637 train loss: 0.27704436 valid loss: 0.2914178
# 638 train loss: 0.24409796 valid loss: 0.255031
# 639 train loss: 0.26314566 valid loss: 0.35778493
# 640 train loss: 0.26815563 valid loss: 0.26960343
# 641 train loss: 0.25188538 valid loss: 0.2981231
# 642 train loss: 0.23997317 valid loss: 0.2839062
# 643 train loss: 0.2529326 valid loss: 0.29569054
# 644 train loss: 0.4007515 valid loss: 0.55890155
# 645 train loss: 0.2646555 valid loss: 0.29240012
# 646 train loss: 0.25562373 valid loss: 0.29397747
# 647 train loss: 0.35201928 valid loss: 0.449219
# 648 train loss: 0.25728372 valid loss: 0.26585904
# 649 train loss: 0.2763268 valid loss: 0.32840818
# 650 train loss: 0.24854372 valid loss: 0.29106823
# 651 train loss: 0.23998763 valid loss: 0.28462592
# 652 train loss: 0.2419819 valid loss: 0.29083124
# 653 train loss: 0.23140582 valid loss: 0.27747184
# 654 train loss: 0.25106436 valid loss: 0.27989978
# 655 train loss: 0.24651802 valid loss: 0.2840169
# 656 train loss: 0.26769593 valid loss: 0.34909475
# 657 train loss: 0.28670907 valid loss: 0.37449086
# 658 train loss: 0.23171917 valid loss: 0.2763474
# 659 train loss: 0.31539342 valid loss: 0.34083492
# 660 train loss: 0.25884864 valid loss: 0.32821253
# 661 train loss: 0.2509139 valid loss: 0.3107044
# 662 train loss: 0.25859144 valid loss: 0.3656793
# 663 train loss: 0.27684116 valid loss: 0.30878514
# 664 train loss: 0.24255693 valid loss: 0.2696249
# 665 train loss: 0.23572789 valid loss: 0.25842535
# 666 train loss: 0.27232128 valid loss: 0.29173106
# 667 train loss: 0.27555925 valid loss: 0.31698185
# 668 train loss: 0.22566761 valid loss: 0.26793453
# 669 train loss: 0.25965327 valid loss: 0.32078266
# 670 train loss: 0.234879 valid loss: 0.2527753
# 671 train loss: 0.26040417 valid loss: 0.30328155
# 672 train loss: 0.2329186 valid loss: 0.26038125
# 673 train loss: 0.23204367 valid loss: 0.29227734
# 674 train loss: 0.24887556 valid loss: 0.27676782
# 675 train loss: 0.24377868 valid loss: 0.27983934
# 676 train loss: 0.23228313 valid loss: 0.2707762
# 677 train loss: 0.2586682 valid loss: 0.30856347
# 678 train loss: 0.25920293 valid loss: 0.311947
# 679 train loss: 0.23084709 valid loss: 0.29512423
# 680 train loss: 0.22519442 valid loss: 0.26693648
# 681 train loss: 0.33084166 valid loss: 0.33175287
# 682 train loss: 0.27366593 valid loss: 0.29677075
# 683 train loss: 0.29001173 valid loss: 0.2963729
# 684 train loss: 0.23041126 valid loss: 0.28264692
# 685 train loss: 0.24900728 valid loss: 0.29231277
# 686 train loss: 0.4109924 valid loss: 0.46848664
# 687 train loss: 0.33642027 valid loss: 0.4366747
# 688 train loss: 0.2418343 valid loss: 0.2599785
# 689 train loss: 0.27582392 valid loss: 0.31819406
# 690 train loss: 0.2458859 valid loss: 0.2747142
# 691 train loss: 0.24940054 valid loss: 0.28701496
# 692 train loss: 0.25613278 valid loss: 0.30987406
# 693 train loss: 0.23251328 valid loss: 0.28018397
# 694 train loss: 0.24061091 valid loss: 0.2517879
# 695 train loss: 0.29838976 valid loss: 0.37203616
# 696 train loss: 0.2698766 valid loss: 0.3332339
# 697 train loss: 0.23014112 valid loss: 0.29740465
# 698 train loss: 0.25053194 valid loss: 0.3049165
# 699 train loss: 0.25236458 valid loss: 0.315176
# 700 train loss: 0.26077834 valid loss: 0.29985693
# 701 train loss: 0.31436273 valid loss: 0.41750973
# 702 train loss: 0.3154691 valid loss: 0.3883208
# 703 train loss: 0.2945636 valid loss: 0.33227766
# 704 train loss: 0.2377752 valid loss: 0.2706645
# 705 train loss: 0.24754828 valid loss: 0.2872812
# 706 train loss: 0.23714104 valid loss: 0.2731795
# 707 train loss: 0.30431226 valid loss: 0.28902385
# 708 train loss: 0.27121517 valid loss: 0.33045334
# 709 train loss: 0.2524201 valid loss: 0.25754774
# 710 train loss: 0.23298714 valid loss: 0.30259204
# 711 train loss: 0.24505748 valid loss: 0.28900582
# 712 train loss: 0.23273 valid loss: 0.27091637
# 713 train loss: 0.27735683 valid loss: 0.34384573
# 714 train loss: 0.34040344 valid loss: 0.36248684
# 715 train loss: 0.25014505 valid loss: 0.29836142
# 716 train loss: 0.2613575 valid loss: 0.26991856
# 717 train loss: 0.24746756 valid loss: 0.28772897
# 718 train loss: 0.28985426 valid loss: 0.3115971
# 719 train loss: 0.34460115 valid loss: 0.44489753
# 720 train loss: 0.25933066 valid loss: 0.28048065
# 721 train loss: 0.24692042 valid loss: 0.2974188
# 722 train loss: 0.27570933 valid loss: 0.23066887
# 723 train loss: 0.23374406 valid loss: 0.26736426
# 724 train loss: 0.2609309 valid loss: 0.2624306
# 725 train loss: 0.24132112 valid loss: 0.26129454
# 726 train loss: 0.23740828 valid loss: 0.27494317
# 727 train loss: 0.24210085 valid loss: 0.2797405
# 728 train loss: 0.2621808 valid loss: 0.25988913
# 729 train loss: 0.227963 valid loss: 0.28687283
# 730 train loss: 0.24045947 valid loss: 0.29137462
# 731 train loss: 0.22566876 valid loss: 0.26413226
# 732 train loss: 0.22738768 valid loss: 0.2574484
# 733 train loss: 0.2736296 valid loss: 0.28093216
# 734 train loss: 0.2327081 valid loss: 0.2900283
# 735 train loss: 0.2528574 valid loss: 0.30212912
# 736 train loss: 0.33757454 valid loss: 0.36648065
# 737 train loss: 0.22889206 valid loss: 0.2505165
# 738 train loss: 0.26134765 valid loss: 0.32011542
# 739 train loss: 0.2611825 valid loss: 0.30278814
# 740 train loss: 0.32058865 valid loss: 0.39256996
# 741 train loss: 0.2455406 valid loss: 0.27033415
# 742 train loss: 0.28881633 valid loss: 0.34614456
# 743 train loss: 0.33568037 valid loss: 0.36585623
# 744 train loss: 0.25312272 valid loss: 0.29850674
# 745 train loss: 0.22731586 valid loss: 0.28572705
# 746 train loss: 0.24245475 valid loss: 0.30272853
# 747 train loss: 0.2588804 valid loss: 0.25990373
# 748 train loss: 0.29700467 valid loss: 0.3024048
# 749 train loss: 0.2350798 valid loss: 0.2927708
# 750 train loss: 0.25374964 valid loss: 0.31064072
# 751 train loss: 0.24144371 valid loss: 0.31508794
# 752 train loss: 0.25564086 valid loss: 0.34362075
# 753 train loss: 0.22767559 valid loss: 0.2635627
# 754 train loss: 0.21813682 valid loss: 0.23195252
# 755 train loss: 0.24625939 valid loss: 0.30723584
# 756 train loss: 0.23370554 valid loss: 0.28204262
# 757 train loss: 0.24929145 valid loss: 0.3306393
# 758 train loss: 0.22361442 valid loss: 0.25519454
# 759 train loss: 0.22816963 valid loss: 0.2911477
# 760 train loss: 0.23726757 valid loss: 0.28447488
# 761 train loss: 0.24551083 valid loss: 0.28977725
# 762 train loss: 0.2747889 valid loss: 0.31917906
# 763 train loss: 0.249225 valid loss: 0.30343905
# 764 train loss: 0.24034178 valid loss: 0.28657016
# 765 train loss: 0.22877614 valid loss: 0.2491185
# 766 train loss: 0.34039223 valid loss: 0.3274994
# 767 train loss: 0.3071188 valid loss: 0.33838543
# 768 train loss: 0.26504165 valid loss: 0.32901633
# 769 train loss: 0.24464586 valid loss: 0.28987965
# 770 train loss: 0.28397405 valid loss: 0.34876573
# 771 train loss: 0.27601486 valid loss: 0.3034006
# 772 train loss: 0.23923299 valid loss: 0.29160526
# 773 train loss: 0.3387429 valid loss: 0.37099004
# 774 train loss: 0.2875094 valid loss: 0.35982704
# 775 train loss: 0.25041845 valid loss: 0.31372365
# 776 train loss: 0.24497072 valid loss: 0.26936287
# 777 train loss: 0.22576976 valid loss: 0.26696217
# 778 train loss: 0.27573428 valid loss: 0.30227405
# 779 train loss: 0.21770403 valid loss: 0.25639766
# 780 train loss: 0.29993892 valid loss: 0.38889164
# 781 train loss: 0.3249054 valid loss: 0.36704525
# 782 train loss: 0.2648502 valid loss: 0.23694585
# 783 train loss: 0.2268424 valid loss: 0.26342526
# 784 train loss: 0.34037176 valid loss: 0.29948482
# 785 train loss: 0.23857577 valid loss: 0.29321545
# 786 train loss: 0.22534826 valid loss: 0.25508428
# 787 train loss: 0.2272649 valid loss: 0.26076508
# 788 train loss: 0.21758367 valid loss: 0.24262752
# 789 train loss: 0.24982437 valid loss: 0.27645963
# 790 train loss: 0.26737216 valid loss: 0.27826792
# 791 train loss: 0.2995457 valid loss: 0.3030219
# 792 train loss: 0.227205 valid loss: 0.27720422
# 793 train loss: 0.22776672 valid loss: 0.2812206
# 794 train loss: 0.2481082 valid loss: 0.2812329
# 795 train loss: 0.2566379 valid loss: 0.26204833
# 796 train loss: 0.24558327 valid loss: 0.27079916
# 797 train loss: 0.2596037 valid loss: 0.30489764
# 798 train loss: 0.2398073 valid loss: 0.27680948
# 799 train loss: 0.22547056 valid loss: 0.24282447
# 800 train loss: 0.6764764 valid loss: 0.83680767
# 801 train loss: 0.40231436 valid loss: 0.557374
# 802 train loss: 0.27403224 valid loss: 0.32692215
# 803 train loss: 0.26955146 valid loss: 0.32904965
# 804 train loss: 0.25560573 valid loss: 0.34396005
# 805 train loss: 0.23346919 valid loss: 0.28763676
# 806 train loss: 0.23810777 valid loss: 0.30005243
# 807 train loss: 0.26327327 valid loss: 0.28212023
# 808 train loss: 0.2658733 valid loss: 0.28634846
# 809 train loss: 0.26693422 valid loss: 0.32686707
# 810 train loss: 0.27519184 valid loss: 0.2790949
# 811 train loss: 0.32457998 valid loss: 0.38499802
# 812 train loss: 0.27289286 valid loss: 0.3443498
# 813 train loss: 0.23126775 valid loss: 0.24275908
# 814 train loss: 0.24441305 valid loss: 0.2935811
# 815 train loss: 0.26748163 valid loss: 0.35351482
# 816 train loss: 0.26419938 valid loss: 0.29967842
# 817 train loss: 0.3968053 valid loss: 0.46882913
# 818 train loss: 0.2565734 valid loss: 0.2879746
# 819 train loss: 0.24442977 valid loss: 0.25863153
# 820 train loss: 0.2908118 valid loss: 0.36665526
# 821 train loss: 0.23438561 valid loss: 0.2717739
# 822 train loss: 0.23608978 valid loss: 0.26704875
# 823 train loss: 0.25047633 valid loss: 0.29093543
# 824 train loss: 0.2727434 valid loss: 0.30572224
# 825 train loss: 0.23749578 valid loss: 0.28407693
# 826 train loss: 0.24004343 valid loss: 0.2758981
# 827 train loss: 0.2992432 valid loss: 0.28387985
# 828 train loss: 0.23440266 valid loss: 0.27394807
# 829 train loss: 0.25992733 valid loss: 0.29943758
# 830 train loss: 0.22368589 valid loss: 0.25275457
# 831 train loss: 0.31651205 valid loss: 0.3319895
# 832 train loss: 0.32255033 valid loss: 0.30372882
# 833 train loss: 0.30639988 valid loss: 0.33751667
# 834 train loss: 0.2636037 valid loss: 0.29691738
# 835 train loss: 0.3081588 valid loss: 0.379049
# 836 train loss: 0.24449755 valid loss: 0.29600382
# 837 train loss: 0.25767258 valid loss: 0.34163815
# 838 train loss: 0.25758183 valid loss: 0.3025108
# 839 train loss: 0.23922671 valid loss: 0.30944723
# 840 train loss: 0.23303586 valid loss: 0.26162097
# 841 train loss: 0.23958828 valid loss: 0.2838581
# 842 train loss: 0.23769087 valid loss: 0.30144376
# 843 train loss: 0.26523843 valid loss: 0.34356695
# 844 train loss: 0.2568613 valid loss: 0.33170938
# 845 train loss: 0.23504394 valid loss: 0.26788312
# 846 train loss: 0.26495394 valid loss: 0.28096473
# 847 train loss: 0.24579993 valid loss: 0.29794046
# 848 train loss: 0.24910355 valid loss: 0.326364
# 849 train loss: 0.21695273 valid loss: 0.24994539
# 850 train loss: 0.25359437 valid loss: 0.305841
# 851 train loss: 0.24588878 valid loss: 0.28506482
# 852 train loss: 0.24040185 valid loss: 0.27926117
# 853 train loss: 0.23885898 valid loss: 0.315014
# 854 train loss: 0.24176028 valid loss: 0.29695624
# 855 train loss: 0.24023077 valid loss: 0.313536
# 856 train loss: 0.23413512 valid loss: 0.26879138
# 857 train loss: 0.23310174 valid loss: 0.25418076
# 858 train loss: 0.29398096 valid loss: 0.36739704
# 859 train loss: 0.2334133 valid loss: 0.2597061
# 860 train loss: 0.23960643 valid loss: 0.25235587
# 861 train loss: 0.24701265 valid loss: 0.29588935
# 862 train loss: 0.24366465 valid loss: 0.31698644
# 863 train loss: 0.2675543 valid loss: 0.28552023
# 864 train loss: 0.493914 valid loss: 0.46184886
# 865 train loss: 0.25487533 valid loss: 0.28209826
# 866 train loss: 0.22902389 valid loss: 0.2913447
# 867 train loss: 0.22619404 valid loss: 0.25407502
# 868 train loss: 0.22083032 valid loss: 0.21867353
# best loss: 0.21867353
# 869 train loss: 0.23285249 valid loss: 0.23815152
# 870 train loss: 0.24490699 valid loss: 0.29084596
# 871 train loss: 0.32949 valid loss: 0.3122563
# 872 train loss: 0.24652979 valid loss: 0.28067267
# 873 train loss: 0.24319544 valid loss: 0.3025037
# 874 train loss: 0.36246574 valid loss: 0.33449876
# 875 train loss: 0.22404912 valid loss: 0.24071361
# 876 train loss: 0.23462936 valid loss: 0.2715079
# 877 train loss: 0.2367648 valid loss: 0.2387626
# 878 train loss: 0.3273034 valid loss: 0.34092867
# 879 train loss: 0.2485861 valid loss: 0.29122168
# 880 train loss: 0.23811036 valid loss: 0.29462653
# 881 train loss: 0.22984003 valid loss: 0.25061068
# 882 train loss: 0.23550744 valid loss: 0.28349012
# 883 train loss: 0.27395838 valid loss: 0.34385464
# 884 train loss: 0.22656393 valid loss: 0.2560777
# 885 train loss: 0.2540325 valid loss: 0.27551255
# 886 train loss: 0.22169524 valid loss: 0.25333384
# 887 train loss: 0.2189517 valid loss: 0.24881099
# 888 train loss: 0.22663207 valid loss: 0.25343558
# 889 train loss: 0.2619446 valid loss: 0.30947864
# 890 train loss: 0.29503298 valid loss: 0.30126417
# 891 train loss: 0.24244566 valid loss: 0.30930346
# 892 train loss: 0.2861298 valid loss: 0.3103097
# 893 train loss: 0.24338405 valid loss: 0.2738224
# 894 train loss: 0.32113633 valid loss: 0.38094872
# 895 train loss: 0.24774805 valid loss: 0.2752695
# 896 train loss: 0.2444252 valid loss: 0.2547474
# 897 train loss: 0.262955 valid loss: 0.2978768
# 898 train loss: 0.22675711 valid loss: 0.25358415
# 899 train loss: 0.2527567 valid loss: 0.28084552
# 900 train loss: 0.24023865 valid loss: 0.30155912
# 901 train loss: 0.28748548 valid loss: 0.33104283
# 902 train loss: 0.2666206 valid loss: 0.33093414
# 903 train loss: 0.25241435 valid loss: 0.33128098
# 904 train loss: 0.2483412 valid loss: 0.30846357
# 905 train loss: 0.26099598 valid loss: 0.28018832
# 906 train loss: 0.22493722 valid loss: 0.2471551
# 907 train loss: 0.24355756 valid loss: 0.2579268
# 908 train loss: 0.26830316 valid loss: 0.3286605
# 909 train loss: 0.23922804 valid loss: 0.2336779
# 910 train loss: 0.39542687 valid loss: 0.54296124
# 911 train loss: 0.22420675 valid loss: 0.25793898
# 912 train loss: 0.2569817 valid loss: 0.36152405
# 913 train loss: 0.2868954 valid loss: 0.35330868
# 914 train loss: 0.27440295 valid loss: 0.32405406
# 915 train loss: 0.25943753 valid loss: 0.319843
# 916 train loss: 0.22264121 valid loss: 0.24520048
# 917 train loss: 0.24032444 valid loss: 0.31759277
# 918 train loss: 0.24757345 valid loss: 0.29824138
# 919 train loss: 0.31694502 valid loss: 0.35156214
# 920 train loss: 0.22975513 valid loss: 0.28551635
# 921 train loss: 0.2264845 valid loss: 0.27512696
# 922 train loss: 0.22515324 valid loss: 0.28049302
# 923 train loss: 0.24169841 valid loss: 0.28891742
# 924 train loss: 0.23947491 valid loss: 0.2981007
# 925 train loss: 0.23321012 valid loss: 0.27921388
# 926 train loss: 0.2973439 valid loss: 0.36800355
# 927 train loss: 0.22570656 valid loss: 0.27875662
# 928 train loss: 0.23010248 valid loss: 0.25726727
# 929 train loss: 0.2831635 valid loss: 0.36123273
# 930 train loss: 0.2452924 valid loss: 0.2922234
# 931 train loss: 0.28397876 valid loss: 0.3087982
# 932 train loss: 0.25740492 valid loss: 0.30579168
# 933 train loss: 0.23121232 valid loss: 0.23812391
# 934 train loss: 0.25098875 valid loss: 0.28718194
# 935 train loss: 0.26290497 valid loss: 0.3167652
# 936 train loss: 0.24414968 valid loss: 0.30494112
# 937 train loss: 0.26333877 valid loss: 0.23436362
# 938 train loss: 0.25630137 valid loss: 0.30547726
# 939 train loss: 0.23905286 valid loss: 0.28117904
# 940 train loss: 0.28718218 valid loss: 0.33281198
# 941 train loss: 0.34192252 valid loss: 0.379171
# 942 train loss: 0.25084335 valid loss: 0.28710306
# 943 train loss: 0.24501637 valid loss: 0.31542578
# 944 train loss: 0.22593765 valid loss: 0.2619965
# 945 train loss: 0.2617053 valid loss: 0.30056414
# 946 train loss: 0.27409804 valid loss: 0.31283554
# 947 train loss: 0.23522674 valid loss: 0.28381962
# 948 train loss: 0.23115931 valid loss: 0.2854011
# 949 train loss: 0.23251107 valid loss: 0.26841304
# 950 train loss: 0.2622199 valid loss: 0.31793073
# 951 train loss: 0.23142572 valid loss: 0.27469134
# 952 train loss: 0.34532338 valid loss: 0.43578297
# 953 train loss: 0.2681771 valid loss: 0.316379
# 954 train loss: 0.23403771 valid loss: 0.30613187
# 955 train loss: 0.21811563 valid loss: 0.26114532
# 956 train loss: 0.22042291 valid loss: 0.26201078
# 957 train loss: 0.2421878 valid loss: 0.3048531
# 958 train loss: 0.2754869 valid loss: 0.30967513
# 959 train loss: 0.26757976 valid loss: 0.33481926
# 960 train loss: 0.22420728 valid loss: 0.27951595
# 961 train loss: 0.24125831 valid loss: 0.31343913
# 962 train loss: 0.374018 valid loss: 0.3422175
# 963 train loss: 0.2614704 valid loss: 0.32238144
# 964 train loss: 0.25495565 valid loss: 0.29613394
# 965 train loss: 0.28004837 valid loss: 0.3239655
# 966 train loss: 0.26204097 valid loss: 0.2751621
# 967 train loss: 0.23303744 valid loss: 0.28872746
# 968 train loss: 0.32177436 valid loss: 0.34126955
# 969 train loss: 0.2954374 valid loss: 0.32239455
# ...
# 1684 train loss: 0.24012467 valid loss: 0.2709767
# 1685 train loss: 0.2477147 valid loss: 0.32615715
# 1686 train loss: 0.22110437 valid loss: 0.2416389
# 1687 train loss: 0.2610759 valid loss: 0.27736086
# 1688 train loss: 0.27493227 valid loss: 0.31644914
# 1689 train loss: 0.21500602 valid loss: 0.25594935
# 1690 train loss: 0.21618487 valid loss: 0.22057346
# 1691 train loss: 0.26040304 valid loss: 0.30752537
# 1692 train loss: 0.2650876 valid loss: 0.2841906
# 1693 train loss: 0.22067331 valid loss: 0.20530835
# best loss: 0.20530835
# 1694 train loss: 0.23410067 valid loss: 0.2522976
# 1695 train loss: 0.2183129 valid loss: 0.24597487
# 1696 train loss: 0.22386125 valid loss: 0.27139065
# 1697 train loss: 0.21093363 valid loss: 0.24542724
# 1698 train loss: 0.27919576 valid loss: 0.29815593
# 1699 train loss: 0.26394552 valid loss: 0.28424484
# 1700 train loss: 0.23461474 valid loss: 0.2947158
# 1701 train loss: 0.22251758 valid loss: 0.25186914
# 1702 train loss: 0.20888409 valid loss: 0.25093842
# 1703 train loss: 0.23180853 valid loss: 0.25813186
# 1704 train loss: 0.22150013 valid loss: 0.24281335
# 1705 train loss: 0.21395169 valid loss: 0.24120258
# 1706 train loss: 0.23236158 valid loss: 0.28729108
# 1707 train loss: 0.22929597 valid loss: 0.2587774
# 1708 train loss: 0.23779035 valid loss: 0.28839847
# 1709 train loss: 0.21874905 valid loss: 0.25182217
# 1710 train loss: 0.22574605 valid loss: 0.28076673
# 1711 train loss: 0.23018105 valid loss: 0.27641863
# 1712 train loss: 0.22333638 valid loss: 0.27207333
# 1713 train loss: 0.24218231 valid loss: 0.2562524
# 1714 train loss: 0.23567471 valid loss: 0.2856527
# 1715 train loss: 0.22848599 valid loss: 0.21298909
# 1716 train loss: 0.26273757 valid loss: 0.29648203
# 1717 train loss: 0.23521335 valid loss: 0.24041444
# 1718 train loss: 0.22350156 valid loss: 0.25981683
# 1719 train loss: 0.21481998 valid loss: 0.25250512
# 1720 train loss: 0.24917784 valid loss: 0.29555762
# 1721 train loss: 0.2225726 valid loss: 0.26291654
# 1722 train loss: 0.22932765 valid loss: 0.28007245
# 1723 train loss: 0.30821413 valid loss: 0.33350646
# 1724 train loss: 0.25876102 valid loss: 0.29158017
# 1725 train loss: 0.2297805 valid loss: 0.27590013
# 1726 train loss: 0.2599557 valid loss: 0.3005992
# 1727 train loss: 0.2217747 valid loss: 0.24917242
# 1728 train loss: 0.35113478 valid loss: 0.34539324
# 1729 train loss: 0.26889873 valid loss: 0.32403362
# 1730 train loss: 0.24517143 valid loss: 0.26498008
# 1731 train loss: 0.22148085 valid loss: 0.25531054
# 1732 train loss: 0.2370739 valid loss: 0.22896343
# 1733 train loss: 0.2144484 valid loss: 0.23423511
# 1734 train loss: 0.27081326 valid loss: 0.31531286
# 1735 train loss: 0.23100847 valid loss: 0.28204477
# 1736 train loss: 0.23381239 valid loss: 0.26946458
# 1737 train loss: 0.21884531 valid loss: 0.2450374
# 1738 train loss: 0.2195863 valid loss: 0.23419428
# 1739 train loss: 0.23046163 valid loss: 0.26834026
# 1740 train loss: 0.35136333 valid loss: 0.36315688
# 1741 train loss: 0.26349673 valid loss: 0.28779024
# 1742 train loss: 0.22501872 valid loss: 0.28768674
# 1743 train loss: 0.21908264 valid loss: 0.25280726
# 1744 train loss: 0.2253728 valid loss: 0.27173644
# 1745 train loss: 0.2287823 valid loss: 0.25146317
# 1746 train loss: 0.21550286 valid loss: 0.2465319
# 1747 train loss: 0.24453878 valid loss: 0.32259583
# 1748 train loss: 0.22579053 valid loss: 0.24904647
# 1749 train loss: 0.24694127 valid loss: 0.3151297
# 1750 train loss: 0.2124113 valid loss: 0.23974365
# 1751 train loss: 0.21643664 valid loss: 0.26815313
# 1752 train loss: 0.22292334 valid loss: 0.25024295
# 1753 train loss: 0.2651679 valid loss: 0.35836837
# 1754 train loss: 0.27144265 valid loss: 0.33138478
# 1755 train loss: 0.3719492 valid loss: 0.30726108
# 1756 train loss: 0.29100677 valid loss: 0.33950788
# 1757 train loss: 0.24861106 valid loss: 0.29227048
# 1758 train loss: 0.30421203 valid loss: 0.3176934
# 1759 train loss: 0.23286676 valid loss: 0.3000048
# 1760 train loss: 0.29391044 valid loss: 0.34353262
# 1761 train loss: 0.31263968 valid loss: 0.3652997
# 1762 train loss: 0.22114924 valid loss: 0.23853904
# 1763 train loss: 0.2598347 valid loss: 0.3384941
# 1764 train loss: 0.2290146 valid loss: 0.2584755
# 1765 train loss: 0.23763466 valid loss: 0.27789
# 1766 train loss: 0.23231101 valid loss: 0.25476688
# 1767 train loss: 0.22047767 valid loss: 0.23963274
# 1768 train loss: 0.24314365 valid loss: 0.2864796
# 1769 train loss: 0.23020068 valid loss: 0.29569873
# 1770 train loss: 0.22277018 valid loss: 0.25772983
# 1771 train loss: 0.24044925 valid loss: 0.28664958
# 1772 train loss: 0.21470658 valid loss: 0.25154272
# 1773 train loss: 0.32079315 valid loss: 0.3401193
# 1774 train loss: 0.23034373 valid loss: 0.2520668
# 1775 train loss: 0.21869132 valid loss: 0.21379808
# 1776 train loss: 0.26119474 valid loss: 0.30505234
# 1777 train loss: 0.24376935 valid loss: 0.28681913
# 1778 train loss: 0.2139244 valid loss: 0.24246304
# 1779 train loss: 0.27824926 valid loss: 0.3506235
# 1780 train loss: 0.23816767 valid loss: 0.26496267
# 1781 train loss: 0.24675637 valid loss: 0.27386987
# 1782 train loss: 0.24925695 valid loss: 0.26382148
# 1783 train loss: 0.21596849 valid loss: 0.23593761
# 1784 train loss: 0.22018951 valid loss: 0.23467503
# 1785 train loss: 0.22631958 valid loss: 0.258802
# 1786 train loss: 0.27871996 valid loss: 0.3146257
# 1787 train loss: 0.24247551 valid loss: 0.24392252
# 1788 train loss: 0.22703964 valid loss: 0.24141705
# 1789 train loss: 0.21888842 valid loss: 0.25047338
# 1790 train loss: 0.214582 valid loss: 0.22136243
# 1791 train loss: 0.30055934 valid loss: 0.31667146
# 1792 train loss: 0.2255842 valid loss: 0.21266712
# 1793 train loss: 0.23496562 valid loss: 0.26556188
# 1794 train loss: 0.24487326 valid loss: 0.26308972
# 1795 train loss: 0.23374763 valid loss: 0.26818246
# 1796 train loss: 0.22328463 valid loss: 0.22858362
# 1797 train loss: 0.23182207 valid loss: 0.26317698
# 1798 train loss: 0.24143946 valid loss: 0.2606664
# 1799 train loss: 0.23359565 valid loss: 0.26654804
# 1800 train loss: 0.23938504 valid loss: 0.26363957
# 1801 train loss: 0.28133133 valid loss: 0.3128615
# 1802 train loss: 0.22633675 valid loss: 0.25547683
# 1803 train loss: 0.22073638 valid loss: 0.26220056
# 1804 train loss: 0.21389568 valid loss: 0.25989562
# 1805 train loss: 0.21253745 valid loss: 0.2565301
# 1806 train loss: 0.33460814 valid loss: 0.33555737
# 1807 train loss: 0.21977784 valid loss: 0.24104121
# 1808 train loss: 0.21768856 valid loss: 0.24211645
# 1809 train loss: 0.2082286 valid loss: 0.24664289
# 1810 train loss: 0.2813902 valid loss: 0.35044682
# 1811 train loss: 0.21996655 valid loss: 0.24243654
# 1812 train loss: 0.21883503 valid loss: 0.2398625
# 1813 train loss: 0.24629194 valid loss: 0.2802272
# 1814 train loss: 0.22627406 valid loss: 0.27792636
# 1815 train loss: 0.22501376 valid loss: 0.24158432
# 1816 train loss: 0.25439015 valid loss: 0.25756204
# 1817 train loss: 0.2776979 valid loss: 0.23772065
# 1818 train loss: 0.23232044 valid loss: 0.2929999
# 1819 train loss: 0.22089525 valid loss: 0.25016826
# 1820 train loss: 0.24208471 valid loss: 0.33809748
# 1821 train loss: 0.20814693 valid loss: 0.23805624
# 1822 train loss: 0.22792819 valid loss: 0.28628987
# 1823 train loss: 0.2624668 valid loss: 0.25890094
# 1824 train loss: 0.22396803 valid loss: 0.23046973
# 1825 train loss: 0.2139273 valid loss: 0.24153748
# 1826 train loss: 0.22113623 valid loss: 0.23264082
# 1827 train loss: 0.22687274 valid loss: 0.26756763
# 1828 train loss: 0.24415845 valid loss: 0.27259916
# 1829 train loss: 0.22083093 valid loss: 0.23407838
# 1830 train loss: 0.3333413 valid loss: 0.32781494
# 1831 train loss: 0.230578 valid loss: 0.23664276
# 1832 train loss: 0.22668698 valid loss: 0.2512018
# 1833 train loss: 0.22298472 valid loss: 0.25369704
# 1834 train loss: 0.22972739 valid loss: 0.22976069
# 1835 train loss: 0.22185948 valid loss: 0.24746501
# 1836 train loss: 0.2856993 valid loss: 0.33642387
# 1837 train loss: 0.22179455 valid loss: 0.2656942
# 1838 train loss: 0.22506018 valid loss: 0.25540742
# 1839 train loss: 0.21698818 valid loss: 0.22845557
# 1840 train loss: 0.23300844 valid loss: 0.265939
# 1841 train loss: 0.25370982 valid loss: 0.27680707
# 1842 train loss: 0.23626009 valid loss: 0.26787922
# 1843 train loss: 0.3562789 valid loss: 0.35840088
# 1844 train loss: 0.24287923 valid loss: 0.29678094
# 1845 train loss: 0.21230008 valid loss: 0.23620595
# 1846 train loss: 0.2196397 valid loss: 0.2774025
# 1847 train loss: 0.22324795 valid loss: 0.23092037
# 1848 train loss: 0.24696192 valid loss: 0.29514816
# 1849 train loss: 0.25569785 valid loss: 0.24506766
# 1850 train loss: 0.22935358 valid loss: 0.2472029
# 1851 train loss: 0.23874933 valid loss: 0.26782688
# 1852 train loss: 0.23990077 valid loss: 0.30319318
# 1853 train loss: 0.2505824 valid loss: 0.30088687
# 1854 train loss: 0.22066252 valid loss: 0.24809381
# 1855 train loss: 0.22289601 valid loss: 0.2777535
# 1856 train loss: 0.28247064 valid loss: 0.29388785
# 1857 train loss: 0.23982796 valid loss: 0.28501004
# 1858 train loss: 0.23737794 valid loss: 0.24508195
# 1859 train loss: 0.22106044 valid loss: 0.25152388
# 1860 train loss: 0.24051414 valid loss: 0.30269197
# 1861 train loss: 0.25557047 valid loss: 0.27384064
# 1862 train loss: 0.26109707 valid loss: 0.3176198
# 1863 train loss: 0.22553876 valid loss: 0.24599409
# 1864 train loss: 0.22113106 valid loss: 0.24047293
# 1865 train loss: 0.23569337 valid loss: 0.25413808
# 1866 train loss: 0.29988712 valid loss: 0.3038148
# 1867 train loss: 0.24584857 valid loss: 0.2775818
# 1868 train loss: 0.23281401 valid loss: 0.2577259
# 1869 train loss: 0.23409839 valid loss: 0.24285543
# 1870 train loss: 0.2459084 valid loss: 0.26700875
# 1871 train loss: 0.25172213 valid loss: 0.23428594
# 1872 train loss: 0.21507475 valid loss: 0.23942637
# 1873 train loss: 0.20970498 valid loss: 0.2316252
# 1874 train loss: 0.24225457 valid loss: 0.27094346
# 1875 train loss: 0.28992617 valid loss: 0.2980733
# 1876 train loss: 0.28692228 valid loss: 0.3902108
# 1877 train loss: 0.21535452 valid loss: 0.2277633
# 1878 train loss: 0.22608313 valid loss: 0.2846291
# 1879 train loss: 0.2389504 valid loss: 0.24263607
# 1880 train loss: 0.23778541 valid loss: 0.25985473
# 1881 train loss: 0.22791536 valid loss: 0.2797172
# 1882 train loss: 0.22514682 valid loss: 0.25102228
# 1883 train loss: 0.23787384 valid loss: 0.29691133
# 1884 train loss: 0.2180229 valid loss: 0.26575977
# 1885 train loss: 0.2426366 valid loss: 0.24521038
# 1886 train loss: 0.22677091 valid loss: 0.26640493
# 1887 train loss: 0.21496722 valid loss: 0.23002388
# 1888 train loss: 0.34422427 valid loss: 0.34282407
# 1889 train loss: 0.23222975 valid loss: 0.2337463
# 1890 train loss: 0.23173936 valid loss: 0.25185513
# 1891 train loss: 0.22146694 valid loss: 0.2813185
# 1892 train loss: 0.21838412 valid loss: 0.2368548
# 1893 train loss: 0.22612458 valid loss: 0.27396405
# 1894 train loss: 0.22781803 valid loss: 0.2461007
# 1895 train loss: 0.23038921 valid loss: 0.27800596
# 1896 train loss: 0.24416699 valid loss: 0.2627774
# 1897 train loss: 0.22865228 valid loss: 0.2522893
# 1898 train loss: 0.23146614 valid loss: 0.27256817
# 1899 train loss: 0.24651676 valid loss: 0.2596824
# 1900 train loss: 0.2175034 valid loss: 0.25202322
# 1901 train loss: 0.22450009 valid loss: 0.2637474
# 1902 train loss: 0.2440199 valid loss: 0.274918
# 1903 train loss: 0.24085903 valid loss: 0.28617913
# 1904 train loss: 0.23288457 valid loss: 0.2858132
# 1905 train loss: 0.23414794 valid loss: 0.2491199
# 1906 train loss: 0.21069516 valid loss: 0.2427385
# 1907 train loss: 0.2165874 valid loss: 0.23871976
# 1908 train loss: 0.22076142 valid loss: 0.2519371
# 1909 train loss: 0.23158765 valid loss: 0.26207528
# 1910 train loss: 0.26784736 valid loss: 0.3006473
# 1911 train loss: 0.26240736 valid loss: 0.32793683
# 1912 train loss: 0.27595457 valid loss: 0.31368488
# 1913 train loss: 0.31726435 valid loss: 0.3314935
# 1914 train loss: 0.24725422 valid loss: 0.2886792
# 1915 train loss: 0.23793954 valid loss: 0.2640726
# 1916 train loss: 0.22465163 valid loss: 0.25170946
# 1917 train loss: 0.22768015 valid loss: 0.27678028
# 1918 train loss: 0.22456266 valid loss: 0.2790373
# 1919 train loss: 0.2838735 valid loss: 0.28209037
# 1920 train loss: 0.22350828 valid loss: 0.2854519
# 1921 train loss: 0.27283514 valid loss: 0.34250566
# 1922 train loss: 0.21712956 valid loss: 0.24212082
# 1923 train loss: 0.21904732 valid loss: 0.25014326
# 1924 train loss: 0.22252722 valid loss: 0.23439184
# 1925 train loss: 0.2187507 valid loss: 0.24810612
# 1926 train loss: 0.2242682 valid loss: 0.26370528
# 1927 train loss: 0.26595262 valid loss: 0.28659412
# 1928 train loss: 0.23572773 valid loss: 0.23577905
# 1929 train loss: 0.238053 valid loss: 0.25413385
# 1930 train loss: 0.2280618 valid loss: 0.2707865
# 1931 train loss: 0.34945905 valid loss: 0.36549205
# 1932 train loss: 0.26155895 valid loss: 0.294732
# 1933 train loss: 0.22324885 valid loss: 0.24649599
# 1934 train loss: 0.23403728 valid loss: 0.2620213
# 1935 train loss: 0.21108139 valid loss: 0.22877243
# 1936 train loss: 0.21606326 valid loss: 0.26966646
# 1937 train loss: 0.21426104 valid loss: 0.2529271
# 1938 train loss: 0.22291814 valid loss: 0.26688698
# 1939 train loss: 0.2624749 valid loss: 0.30488843
# 1940 train loss: 0.22092658 valid loss: 0.25776097
# 1941 train loss: 0.24983428 valid loss: 0.31689703
# 1942 train loss: 0.22970694 valid loss: 0.29464138
# 1943 train loss: 0.2269446 valid loss: 0.22824423
# 1944 train loss: 0.29292774 valid loss: 0.2573708
# 1945 train loss: 0.23484239 valid loss: 0.21443316
# 1946 train loss: 0.24860747 valid loss: 0.29013616
# 1947 train loss: 0.21483402 valid loss: 0.24380487
# 1948 train loss: 0.21986744 valid loss: 0.23671031
# 1949 train loss: 0.28021008 valid loss: 0.31729454
# 1950 train loss: 0.23299754 valid loss: 0.27345547
# 1951 train loss: 0.264468 valid loss: 0.28307694
# 1952 train loss: 0.21873838 valid loss: 0.24518542
# 1953 train loss: 0.3089825 valid loss: 0.30719262
# 1954 train loss: 0.23455957 valid loss: 0.26272008
# 1955 train loss: 0.26608995 valid loss: 0.29855216
# 1956 train loss: 0.23551391 valid loss: 0.22154143
# 1957 train loss: 0.2162077 valid loss: 0.2233606
# 1958 train loss: 0.21392983 valid loss: 0.25616613
# 1959 train loss: 0.33979845 valid loss: 0.35844263
# 1960 train loss: 0.26770693 valid loss: 0.33323377
# 1961 train loss: 0.25995135 valid loss: 0.34372282
# 1962 train loss: 0.28038087 valid loss: 0.32229102
# 1963 train loss: 0.22698203 valid loss: 0.2617489
# 1964 train loss: 0.22981834 valid loss: 0.2430555
# 1965 train loss: 0.26082584 valid loss: 0.34095496
# 1966 train loss: 0.22904016 valid loss: 0.25091314
# 1967 train loss: 0.22831716 valid loss: 0.26448724
# 1968 train loss: 0.2792168 valid loss: 0.2741688
# 1969 train loss: 0.23821414 valid loss: 0.23289168
# 1970 train loss: 0.23382662 valid loss: 0.2399356
# 1971 train loss: 0.22097845 valid loss: 0.26840138
# 1972 train loss: 0.24147971 valid loss: 0.29132017
# 1973 train loss: 0.29593307 valid loss: 0.2848998
# 1974 train loss: 0.22904271 valid loss: 0.27898055
# 1975 train loss: 0.22275205 valid loss: 0.21952328
# 1976 train loss: 0.2679509 valid loss: 0.23571748
# 1977 train loss: 0.23932397 valid loss: 0.27115867
# 1978 train loss: 0.22176038 valid loss: 0.2510834
# 1979 train loss: 0.2441154 valid loss: 0.30933854
# 1980 train loss: 0.21452616 valid loss: 0.27144077
# 1981 train loss: 0.20802836 valid loss: 0.22929977
# 1982 train loss: 0.2162261 valid loss: 0.26349062
# 1983 train loss: 0.23438737 valid loss: 0.26965782
# 1984 train loss: 0.2523835 valid loss: 0.29533434
# 1985 train loss: 0.23969784 valid loss: 0.26463857
# 1986 train loss: 0.22459577 valid loss: 0.25008735
# 1987 train loss: 0.25428206 valid loss: 0.26193437
# 1988 train loss: 0.21754208 valid loss: 0.24542376
# 1989 train loss: 0.23031285 valid loss: 0.27865586
# 1990 train loss: 0.31728643 valid loss: 0.34389445
# 1991 train loss: 0.21966466 valid loss: 0.23097047
# 1992 train loss: 0.23638006 valid loss: 0.2554892
# 1993 train loss: 0.22492251 valid loss: 0.2556309
# 1994 train loss: 0.24782628 valid loss: 0.25435147
# 1995 train loss: 0.23725805 valid loss: 0.2875643
# 1996 train loss: 0.2753803 valid loss: 0.3179164
# 1997 train loss: 0.22487976 valid loss: 0.272655
# 1998 train loss: 0.21218872 valid loss: 0.233719
# 1999 train loss: 0.22398339 valid loss: 0.27669224

# %%
os.remove(checkpoint_epoch_path)

# %% [markdown]
# # Predictions

# %%
with tf.Session() as sess:
    saver.restore(sess, final_model_path)
    test_mse = mse.eval(feed_dict={X_node: X_test, y_node: y_test})
    predictions = y_pred.eval(feed_dict={X_node: X_test, y_node: y_test})
    
    
print(test_mse)
# Out:
# W0819 14:24:43.203574 26740 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 0.28868294

# %%
predictions.shape
# Out:
# (468, 2)

# %% [markdown]
# # Plot  _first (0th)_ output column of _predictions_

# %%
y_new_inverse = y_scaler.inverse_transform(predictions)
x_test_inverse = x_scaler.inverse_transform(X_test)

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = y_new_inverse[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
y_test_o.shape[0]
# Out:
# 468

# %%
plt.scatter(range(y_new_inverse.shape[0]), y_new_inverse[:,0], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot _first 0th_ column of TEST set

# %%
plt.scatter(range(y_test_o.shape[0]), y_test_o[:,0], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = X_test_o[:,0]
ys = X_test_o[:,1]
zs = y_test_o[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Plot second column of Predictions

# %%
y_new_inverse = y_scaler.inverse_transform(predictions)
x_test_inverse = x_scaler.inverse_transform(X_test)

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = y_new_inverse[:,1]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
plt.scatter(range(y_new_inverse.shape[0]), y_new_inverse[:,1], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot second column of TEST set

# %%
plt.scatter(range(y_test_o.shape[0]), y_test_o[:,1], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = X_test_o[:,0]
ys = X_test_o[:,1]
zs = y_test_o[:,1]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Calculate _diff_ and _diff_abs_ (no distinction for columns)

# %%
#diff = np.square((y_new_inverse - y_test_o) / y_test_o)
substraction = y_new_inverse - y_test_o
diff = np.divide( substraction , y_test_o, out = substraction, where = y_test_o != 0)
diff_abs = y_new_inverse - y_test_o

# %%
diff_df = pd.DataFrame(data={'rel diff mass': diff[:,0],
                            'rel diff sep': diff[:,1],
                            'abs diff mass' : diff_abs[:,0],
                             'abs diff sep' : diff_abs[:,1],
                            })
diff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 4 columns):
# rel diff mass    468 non-null float64
# rel diff sep     468 non-null float64
# abs diff mass    468 non-null float64
# abs diff sep     468 non-null float64
# dtypes: float64(4)
# memory usage: 14.7 KB

# %% [markdown]
# # Replace inf and -inf with Nan, then drop the nans

# %%
diff_df = diff_df.replace([np.inf, -np.inf], np.nan)

# %%
print(diff_df.isnull().values.any())
print(diff_df.isnull().sum())
diff_df = diff_df.dropna()
# Out:
# False
# rel diff mass    0
# rel diff sep     0
# abs diff mass    0
# abs diff sep     0
# dtype: int64

# %%
diff_df.describe()
# Out:
#        rel diff mass  rel diff sep  abs diff mass  abs diff sep
# count     468.000000    468.000000     468.000000    468.000000
# mean       -0.533974      0.079853       0.056432      0.318131
# std         9.246207      0.429311       0.154517      1.456446
# min      -189.990101     -4.571787      -1.145523     -8.847145
# 25%        -0.155490     -0.083526       0.016957     -0.753065
# 50%        -0.060600      0.064854       0.043628      0.391631
# 75%         0.013587      0.190908       0.064449      1.332260
# max        13.610100      5.498065       2.295234      9.151749

# %% [markdown]
# # Plot the relative diff of the first column

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = diff_df['rel diff mass']# diff[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.5)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
#%matplotlib notebook

# %%
vals = diff_df['rel diff mass'].to_numpy()
print(vals.shape)
print(vals.shape[0])
# Out:
# (468,)
# 468

# %%
#plt.scatter(iterate_x, diff[:,0], s=5)

plt.scatter(range(vals.shape[0]),vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot the relative diff of the second column

# %%
vals = diff_df['rel diff sep'].to_numpy()
print(vals.shape)
print(vals.shape[0])
# Out:
# (468,)
# 468

# %%
plt.scatter(range(vals.shape[0]), vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Diff ABSOLUTE of first column

# %%
vals = diff_df['abs diff mass'].to_numpy()
print(vals.shape)
range_x = range(vals.shape[0])
# Out:
# (468,)

# %%
plt.scatter(range_x,vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Diff ABSOLUTE of second column

# %%
vals = diff_df['abs diff sep'].to_numpy()
print(vals.shape)
range_x = range(vals.shape[0])
# Out:
# (468,)

# %%
plt.scatter(range_x,vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()
