# %% [markdown]
# # 4 imputs (N,Z, uq,dq) and two outputs (Mass excess, seperation energey) in forked ANN

# %% [markdown]
# # Imports

# %%
import numpy as np
import tensorflow as tf
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
from utils import shuffle_batch, variable_summaries
import os

# %matplotlib notebook

dir_path = os.getcwd()

now = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)
print(dir_path)
print(now)
# Out:
# C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-2-outputs-forked
# 2019-08-19-16-31-53

# %%
#%matplotlib notebook

# %% [markdown]
# # Read the data set

# %%
df = pd.read_csv("better-nuclei-19-08.csv")
print(df.info())
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436 entries, 0 to 3435
# Data columns (total 10 columns):
# Z                                  3436 non-null int64
# N                                  3436 non-null int64
# UQ                                 3436 non-null int64
# DQ                                 3436 non-null int64
# Mass Excess [MeV]                  3436 non-null float64
# Mass Error                         3436 non-null float64
# Mass Estimated                     3436 non-null int64
# Neutron separation energy [MeV]    3318 non-null float64
# Separation Error                   3318 non-null float64
# Separation Estimated               3318 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 268.5 KB
# None
# Index(['Z', 'N', 'UQ', 'DQ', 'Mass Excess [MeV]', 'Mass Error',
#        'Mass Estimated', 'Neutron separation energy [MeV]', 'Separation Error',
#        'Separation Estimated'],
#       dtype='object')

# %%
df = df.rename(columns=
               {"Mass Excess [MeV]": "d",
                "Z":'z',
                'N':'n',
                'UQ':"uq",
                'DQ':"dq",
                "Mass Error":"mass error",
                "Mass Estimated":"mass estimated",
                "Neutron separation energy [MeV]":"d2",
                "Separation Error":"separation error",
                "Separation Estimated":"separation estimated"               
               })
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436 entries, 0 to 3435
# Data columns (total 10 columns):
# z                       3436 non-null int64
# n                       3436 non-null int64
# uq                      3436 non-null int64
# dq                      3436 non-null int64
# d                       3436 non-null float64
# mass error              3436 non-null float64
# mass estimated          3436 non-null int64
# d2                      3318 non-null float64
# separation error        3318 non-null float64
# separation estimated    3318 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 268.5 KB
# None

# %%
df.describe()
# Out:
#                  z            n           uq           dq            d  \
# count  3436.000000  3436.000000  3436.000000  3436.000000  3436.000000
# mean     57.857392    82.034051   197.748836   221.925495   -24.144121
# std      27.809406    43.293558    98.188326   113.771063    56.200706
# min       0.000000     0.000000     1.000000     1.000000   -91.652853
# 25%      36.000000    47.000000   120.750000   131.000000   -65.400443
# 50%      58.000000    81.000000   197.000000   219.000000   -39.335024
# 75%      80.000000   114.000000   273.000000   308.000000     1.172301
# max     118.000000   177.000000   413.000000   472.000000   201.512000
#
#         mass error  mass estimated           d2  separation error  \
# count  3436.000000     3436.000000  3318.000000       3318.000000
# mean      0.123589        0.272992     7.755557          0.164216
# std       0.197548        0.445562     3.631747          0.254378
# min       0.000000        0.000000    -2.488000          0.000000
# 25%       0.003006        0.000000     5.414787          0.005140
# 50%       0.014474        0.000000     7.249960          0.025005
# 75%       0.196000        1.000000     9.654658          0.269058
# max       2.003000        1.000000    27.715000          2.011000
#
#        separation estimated
# count           3318.000000
# mean               0.295660
# std                0.456408
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                1.000000
# max                1.000000

# %% [markdown]
# # Remove estimated Excess and estimated Seperation

# %%
not_estimated_filter = (df["mass estimated"] == 0)
df = df[not_estimated_filter]

not_estimated_filter = (df["separation estimated"] == 0)
df = df[not_estimated_filter]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 10 columns):
# z                       2337 non-null int64
# n                       2337 non-null int64
# uq                      2337 non-null int64
# dq                      2337 non-null int64
# d                       2337 non-null float64
# mass error              2337 non-null float64
# mass estimated          2337 non-null int64
# d2                      2337 non-null float64
# separation error        2337 non-null float64
# separation estimated    2337 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 200.8 KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['z'].shape
# Out:
# (2337,)

# %%
df.count()
# Out:
# z                       2337
# n                       2337
# uq                      2337
# dq                      2337
# d                       2337
# mass error              2337
# mass estimated          2337
# d2                      2337
# separation error        2337
# separation estimated    2337
# dtype: int64

# %%
df.head()
# Out:
#    z  n  uq  dq          d    mass error  mass estimated       d2  \
# 0  0  1   1   2   8.071317  4.000000e-07               0  0.00000
# 2  1  1   3   3  13.135722  1.000000e-07               0  2.22457
# 3  1  2   4   5  14.949810  2.000000e-07               0  6.25723
# 4  1  3   5   7  24.621127  1.000000e-01               0 -1.60000
# 5  1  4   6   9  32.892444  8.944300e-02               0 -0.20000
#
#    separation error  separation estimated
# 0           0.00000                   0.0
# 2           0.00000                   0.0
# 3           0.00000                   0.0
# 4           0.10000                   0.0
# 5           0.13416                   0.0

# %% [markdown]
# # Plot seperation energy column

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = df['n']
ys = df['z']
zs = df['d2']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D2')


plt.show()

# %%
df['d2'].to_numpy().shape
# Out:
# (2337,)

# %%
plt.scatter(range(df['d2'].count()), df['d2'].to_numpy(), s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Dividing Mass Excess by A = Z + N

# %%
zes = df['z'].to_numpy()
ns = df['n'].to_numpy()
a = zes + ns

des = df['d'].to_numpy() / a
df['d'] = des

# %% [markdown]
# # Plot Mass excess output column

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = df['n']
ys = df['z']
zs = df['d']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Tripcolor

# %%
zs = df['d']

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

#yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.05)


fig, (ax)=plt.subplots(ncols=1)
ax.tripcolor(df["n"], df["z"], df["d"])
cb = fig.colorbar(colmap)

plt.show()

# %% [markdown]
# # Set X inputs

# %%
x = df[['z','n','dq','uq']]
print(x.info())
x = x.to_numpy()
print(x.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 2 columns):
# z    2337 non-null int64
# n    2337 non-null int64
# dtypes: int64(2)
# memory usage: 54.8 KB
# None
# (2337, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 3369
# Data columns (total 10 columns):
# z                       2337 non-null int64
# n                       2337 non-null int64
# uq                      2337 non-null int64
# dq                      2337 non-null int64
# d                       2337 non-null float64
# mass error              2337 non-null float64
# mass estimated          2337 non-null int64
# d2                      2337 non-null float64
# separation error        2337 non-null float64
# separation estimated    2337 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 200.8 KB

# %% [markdown]
# # Set Y inputs _(HERE CHANGE NUMBER OF INPUTS AND RESHAPE)

# %%
y = df[['d','d2']].to_numpy() #HERE
y.shape
# Out:
# (2337, 2)

# %%
y = y.reshape(-1,2) #HERE
y.shape
# Out:
# (2337, 2)

# %%
y[0:5]
# Out:
# array([[ 8.07131713,  0.        ],
#        [ 6.56786088,  2.22457   ],
#        [ 4.98326998,  6.25723   ],
#        [ 6.15528175, -1.6       ],
#        [ 6.5784888 , -0.2       ]])

# %% [markdown]
# # Prepare X_train_o, Y_train_o etc

# %%
X_train_o, X_test_o, y_train_o, y_test_o = train_test_split(x, y, test_size=0.2, random_state=1)
X_train_o, X_val_o, y_train_o, y_val_o  = train_test_split(X_train_o, y_train_o, test_size=0.2, random_state=1)
n_inputs = X_train_o.shape[1]
n_outputs = y_train_o.shape[1]
print(n_inputs)
print(n_outputs)
print(X_train_o.shape, X_test_o.shape,X_val_o.shape)
# Out:
# 2
# 2
# (1495, 2) (468, 2) (374, 2)

# %% [markdown]
# # Scaling

# %%
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train_o.reshape(-1, n_inputs))
X_test = x_scaler.transform(X_test_o.reshape(-1, n_inputs))
X_val = x_scaler.transform(X_val_o.reshape(-1, n_inputs))

y_train = y_scaler.fit_transform(y_train_o.reshape(-1, n_outputs))
y_test = y_scaler.transform(y_test_o.reshape(-1, n_outputs))
y_val = y_scaler.transform(y_val_o.reshape(-1, n_outputs))

n_inputs = X_train.shape[1]
n_outputs = y_train.shape[1]
print(n_inputs)
print(n_outputs)
# Out:
# 2
# 2

# %% [markdown]
# # ANN TOPOLOGY

# %%
def cust_layer(inputs,number_of_neurons, name, activation=None, dropout=False):
    init = tf.initializers.he_normal(seed=None)
    hidden = tf.keras.layers.Dense(number_of_neurons,
                                   name=name,
                                    kernel_initializer=init,
                                   activation = activation
                                )(inputs)    
    batch_norm = tf.keras.layers.BatchNormalization()(hidden, training=True)    
    if dropout:
        dropout_layer = tf.keras.layers.Dropout(0.5)(batch_norm)
        return dropout_layer
    else:
        return batch_norm
    
    
tf.reset_default_graph()
with tf.name_scope("dnn"):
    with tf.name_scope("inputs"):
        X_node = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
        y_node = tf.placeholder(tf.float32, shape=(None, n_outputs), name="y")
        
    n_shared_neurons = 150
    n_diff_neurons = 70
    n_shared_layers= 5
    n_layers = 5
    
    shared_layer = cust_layer(X_node,50,"hidden1")        
    
    for i in range(n_shared_layers):
        shared_layer = cust_layer(shared_layer,n_shared_neurons,f"hidden_shared_{i}",activation=tf.nn.elu,dropout=True)
    
    left_layers = cust_layer(shared_layer,n_diff_neurons,f"hidden_left_0",activation=tf.nn.elu,dropout=True)
    right_layers = cust_layer(shared_layer,n_diff_neurons,f"hidden_right_0",activation=tf.nn.elu,dropout=True)
    
    for j in range(n_layers):
        left_layers = cust_layer(left_layers,n_diff_neurons,f"hidden_left_{j+1}",activation=tf.nn.elu,dropout=True)
        right_layers = cust_layer(right_layers,n_diff_neurons,f"hidden_right_{j+1}",activation=tf.nn.elu,dropout=True)
    
    init = tf.initializers.he_normal()
    init2= tf.initializers.he_normal()
    y_pred_left = tf.keras.layers.Dense(1, name="output_left", kernel_initializer=init)(left_layers)
    y_pred_right = tf.keras.layers.Dense(1, name="output_right", kernel_initializer=init2)(right_layers)

    
with tf.name_scope('MSE_first_output'):
    
    error_f = tf.reshape(y_pred_left, [-1,]) - y_node[:,0]
    square_f = tf.square(error_f)
    mse_f = tf.reduce_mean(square_f, name="mse_first")
    variable_summaries(mse_f)
    print(y_node[:,0].get_shape())
    print(tf.reshape(y_pred_left, [-1,]).get_shape())

with tf.name_scope('MSE_second_output'):    
    error_s =tf.reshape(y_pred_right, [-1,])  - y_node[:,1]
    square_s = tf.square(error_s)
    mse_s = tf.reduce_mean(square_s, name="mse_second")
    variable_summaries(mse_s)

with tf.name_scope('MSE_combined'):    
    mse = mse_f + mse_s
    variable_summaries(mse)

with tf.name_scope('optimiser'):
    optimiser = tf.train.AdamOptimizer(0.001)
    training_op = optimiser.minimize(mse)

for var in tf.trainable_variables():
    tf.summary.histogram(var.name, var)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 16:31:57.965113 28564 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-2-outputs-forked\utils.py:16: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0819 16:31:57.978990 28564 deprecation_wrapper.py:119] From C:\Users\kicjo\Desktop\my-anns\nuclei\nuclei-updated-2-inputs-2-outputs-forked\utils.py:22: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
# (?,)
# (?,)

# %% [markdown]
# # File writers

# %%
merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
test_writer = tf.summary.FileWriter(logdir + '/test')
valid_writer = tf.summary.FileWriter(logdir + '/valid')
init = tf.global_variables_initializer()

saver = tf.train.Saver()

checkpoint_path = os.path.join(dir_path, "sinus_tmp","sinus_full_model.ckpt")
checkpoint_epoch_path = checkpoint_path + ".epoch"
final_model_path = os.path.join(dir_path, "model", "my_sinus_full_model")

# %% [markdown]
# # Number of epochs and batches

# %%
n_epochs = 2000
n_batches = 50

best_loss = np.infty
epochs_without_progress = 0
max_epochs_without_progress = n_epochs * 0.2
print(max_epochs_without_progress)
# Out:
# 400.0

# %% [markdown]
# # Training

# %%
with tf.Session() as sess:
    if os.path.isfile(checkpoint_epoch_path):
        # if the checkpoint file exists, restore the model and load the epoch number
        with open(checkpoint_epoch_path, "rb") as f:
            start_epoch = int(f.read())
        print("Training was interrupted. Continuing at epoch", start_epoch)
        saver.restore(sess, checkpoint_path)
    else:
        start_epoch = 0
        sess.run(init)

    for epoch in range(start_epoch, n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, n_batches):
            summary, _ = sess.run([merged, training_op],
                                  feed_dict={X_node: X_batch, y_node: y_batch})

        train_summary, _ = sess.run([merged, training_op],feed_dict={X_node: X_train, y_node: y_train})
        test_summary, _ =sess.run([merged, training_op],feed_dict={X_node: X_test, y_node: y_test})
        validation_summary, _ = sess.run([merged, training_op], feed_dict={X_node: X_val, y_node: y_val})

        train_writer.add_summary(train_summary, epoch)
        test_writer.add_summary(test_summary, epoch)
        valid_writer.add_summary(validation_summary,epoch)
        
        loss_train = mse.eval(feed_dict={X_node: X_train, y_node: y_train})
        loss_val = mse.eval(feed_dict={X_node: X_val, y_node: y_val})
        print(epoch, "train loss:", loss_train, "valid loss:", loss_val)

        iteration_skip = 10
        if epoch % iteration_skip == 0:
            saver.save(sess, checkpoint_path)
            with open(checkpoint_epoch_path, "wb") as f:
                f.write(b"%d" % (epoch + 1))

        if loss_val < best_loss:
            saver.save(sess, final_model_path)
            best_loss = loss_val
            print("best loss:", best_loss)
            epochs_without_progress = 0
        else:
            epochs_without_progress += 1
            if epochs_without_progress > max_epochs_without_progress:
                print("Early stopping")
                break


train_writer.close()
test_writer.close()
valid_writer.close()
# Out:
# 0 train loss: 0.5997523 valid loss: 0.6996895
# best loss: 0.6996895
# 1 train loss: 0.4380229 valid loss: 0.5569192
# best loss: 0.5569192
# 2 train loss: 0.5529915 valid loss: 0.6792377
# 3 train loss: 0.47221127 valid loss: 0.60183704
# 4 train loss: 0.36256215 valid loss: 0.3957104
# best loss: 0.3957104
# 5 train loss: 0.35581806 valid loss: 0.37923387
# best loss: 0.37923387
# 6 train loss: 0.33959478 valid loss: 0.43560496
# 7 train loss: 0.34320047 valid loss: 0.4225728
# 8 train loss: 0.38051164 valid loss: 0.49321097
# 9 train loss: 0.35783195 valid loss: 0.4020608
# 10 train loss: 0.35835233 valid loss: 0.44642723
# 11 train loss: 0.38090423 valid loss: 0.47918218
# 12 train loss: 0.28733468 valid loss: 0.35089794
# best loss: 0.35089794
# 13 train loss: 0.31621945 valid loss: 0.357996
# 14 train loss: 0.2785297 valid loss: 0.314381
# best loss: 0.314381
# 15 train loss: 0.47374663 valid loss: 0.5118046
# 16 train loss: 0.29865545 valid loss: 0.32844657
# 17 train loss: 0.31157082 valid loss: 0.32735717
# 18 train loss: 0.33419266 valid loss: 0.4127908
# 19 train loss: 0.31970978 valid loss: 0.44058543
# 20 train loss: 0.33595186 valid loss: 0.4567731
# 21 train loss: 0.36256796 valid loss: 0.48781183
# 22 train loss: 0.37676698 valid loss: 0.45487332
# 23 train loss: 0.33910647 valid loss: 0.43016243
# 24 train loss: 0.2559307 valid loss: 0.32181156
# 25 train loss: 0.31753626 valid loss: 0.4175016
# 26 train loss: 0.2674104 valid loss: 0.2827655
# best loss: 0.2827655
# 27 train loss: 0.36750558 valid loss: 0.4024976
# 28 train loss: 0.31808916 valid loss: 0.34220216
# 29 train loss: 0.46981874 valid loss: 0.5929904
# 30 train loss: 0.36101073 valid loss: 0.44135797
# 31 train loss: 0.30579653 valid loss: 0.38033736
# 32 train loss: 0.3720982 valid loss: 0.4271124
# 33 train loss: 0.33786684 valid loss: 0.38729674
# 34 train loss: 0.3072887 valid loss: 0.41460365
# 35 train loss: 0.32318044 valid loss: 0.37293375
# 36 train loss: 0.27485216 valid loss: 0.3403593
# 37 train loss: 0.3040565 valid loss: 0.30794746
# 38 train loss: 0.3184734 valid loss: 0.380349
# 39 train loss: 0.30390817 valid loss: 0.33867577
# 40 train loss: 0.36987022 valid loss: 0.45091593
# 41 train loss: 0.3318815 valid loss: 0.39919853
# 42 train loss: 0.36548758 valid loss: 0.42399338
# 43 train loss: 0.2779115 valid loss: 0.3608808
# 44 train loss: 0.29430097 valid loss: 0.3319013
# 45 train loss: 0.3936941 valid loss: 0.41367766
# 46 train loss: 0.3325283 valid loss: 0.42721754
# 47 train loss: 0.25977942 valid loss: 0.27677673
# best loss: 0.27677673
# 48 train loss: 0.30162686 valid loss: 0.36302316
# 49 train loss: 0.30229166 valid loss: 0.3802263
# 50 train loss: 0.25767395 valid loss: 0.3313392
# 51 train loss: 0.2648993 valid loss: 0.3085894
# 52 train loss: 0.2957885 valid loss: 0.381212
# 53 train loss: 0.29487395 valid loss: 0.3676302
# 54 train loss: 0.37802586 valid loss: 0.469189
# 55 train loss: 0.2656661 valid loss: 0.28352457
# 56 train loss: 0.2453605 valid loss: 0.25581726
# best loss: 0.25581726
# 57 train loss: 0.36732423 valid loss: 0.43884623
# 58 train loss: 0.30752468 valid loss: 0.38866132
# 59 train loss: 0.29903826 valid loss: 0.37659812
# 60 train loss: 0.25942248 valid loss: 0.34216264
# 61 train loss: 0.3254336 valid loss: 0.39822814
# 62 train loss: 0.26720232 valid loss: 0.34448653
# 63 train loss: 0.2527148 valid loss: 0.2873016
# 64 train loss: 0.26224083 valid loss: 0.32427543
# 65 train loss: 0.296874 valid loss: 0.402115
# 66 train loss: 0.28223604 valid loss: 0.33791247
# 67 train loss: 0.24587488 valid loss: 0.30378202
# 68 train loss: 0.2535141 valid loss: 0.28198302
# 69 train loss: 0.26717174 valid loss: 0.27669755
# 70 train loss: 0.29019338 valid loss: 0.31251925
# 71 train loss: 0.3360011 valid loss: 0.378624
# 72 train loss: 0.2679101 valid loss: 0.3169039
# 73 train loss: 0.36314595 valid loss: 0.41822684
# 74 train loss: 0.31075424 valid loss: 0.34928566
# 75 train loss: 0.31684297 valid loss: 0.33837968
# 76 train loss: 0.33581448 valid loss: 0.4046073
# 77 train loss: 0.27324316 valid loss: 0.36104408
# 78 train loss: 0.30659792 valid loss: 0.37810612
# 79 train loss: 0.26444665 valid loss: 0.31770703
# 80 train loss: 0.25019804 valid loss: 0.29391184
# 81 train loss: 0.27369395 valid loss: 0.31740442
# 82 train loss: 0.2753753 valid loss: 0.33479458
# 83 train loss: 0.25454387 valid loss: 0.30423737
# 84 train loss: 0.2896086 valid loss: 0.31909564
# 85 train loss: 0.31502298 valid loss: 0.35922173
# 86 train loss: 0.3360076 valid loss: 0.35812467
# 87 train loss: 0.27883524 valid loss: 0.31820154
# 88 train loss: 0.24031737 valid loss: 0.25150838
# best loss: 0.25150838
# 89 train loss: 0.3029508 valid loss: 0.3953532
# 90 train loss: 0.37875217 valid loss: 0.35522294
# 91 train loss: 0.3780428 valid loss: 0.40515918
# 92 train loss: 0.278818 valid loss: 0.36533344
# 93 train loss: 0.26548374 valid loss: 0.35850883
# 94 train loss: 0.2616038 valid loss: 0.325295
# 95 train loss: 0.25064236 valid loss: 0.30300036
# 96 train loss: 0.25664267 valid loss: 0.30499005
# 97 train loss: 0.30377877 valid loss: 0.36363235
# 98 train loss: 0.24734564 valid loss: 0.30450007
# 99 train loss: 0.3127498 valid loss: 0.35981774
# 100 train loss: 0.2605239 valid loss: 0.28013864
# 101 train loss: 0.31029147 valid loss: 0.36019665
# 102 train loss: 0.24974382 valid loss: 0.2397861
# best loss: 0.2397861
# 103 train loss: 0.24417055 valid loss: 0.28135884
# 104 train loss: 0.39594585 valid loss: 0.4594102
# 105 train loss: 0.30909508 valid loss: 0.3879403
# 106 train loss: 0.24254958 valid loss: 0.27733827
# 107 train loss: 0.27219462 valid loss: 0.35434306
# 108 train loss: 0.23962268 valid loss: 0.2721601
# 109 train loss: 0.29582918 valid loss: 0.36671466
# 110 train loss: 0.27978724 valid loss: 0.32309473
# 111 train loss: 0.2782382 valid loss: 0.31505665
# 112 train loss: 0.32220894 valid loss: 0.33996752
# 113 train loss: 0.27653646 valid loss: 0.33001608
# 114 train loss: 0.3224733 valid loss: 0.39717776
# 115 train loss: 0.29651952 valid loss: 0.3229851
# 116 train loss: 0.28306082 valid loss: 0.36357087
# 117 train loss: 0.27325282 valid loss: 0.3116104
# 118 train loss: 0.3938396 valid loss: 0.47811902
# 119 train loss: 0.27082 valid loss: 0.3058767
# 120 train loss: 0.39098704 valid loss: 0.47471744
# 121 train loss: 0.2555583 valid loss: 0.299403
# 122 train loss: 0.26851153 valid loss: 0.32593322
# 123 train loss: 0.32547262 valid loss: 0.36544648
# 124 train loss: 0.2977649 valid loss: 0.36511043
# 125 train loss: 0.28759074 valid loss: 0.2795375
# 126 train loss: 0.2767493 valid loss: 0.34300113
# 127 train loss: 0.28498542 valid loss: 0.30427623
# 128 train loss: 0.35761568 valid loss: 0.4102912
# 129 train loss: 0.26680937 valid loss: 0.28825012
# 130 train loss: 0.32639235 valid loss: 0.38265982
# 131 train loss: 0.27198777 valid loss: 0.31757373
# 132 train loss: 0.27732396 valid loss: 0.3010813
# 133 train loss: 0.22933687 valid loss: 0.2590046
# 134 train loss: 0.27422106 valid loss: 0.32934278
# 135 train loss: 0.2734734 valid loss: 0.30193472
# 136 train loss: 0.26362395 valid loss: 0.3037609
# 137 train loss: 0.27410695 valid loss: 0.34109166
# 138 train loss: 0.27627984 valid loss: 0.3112274
# 139 train loss: 0.30217803 valid loss: 0.34194323
# 140 train loss: 0.3654158 valid loss: 0.43281212
# 141 train loss: 0.3338161 valid loss: 0.3399791
# 142 train loss: 0.23196961 valid loss: 0.26204306
# 143 train loss: 0.31806505 valid loss: 0.400725
# 144 train loss: 0.2738575 valid loss: 0.30460358
# 145 train loss: 0.2467999 valid loss: 0.26775524
# 146 train loss: 0.2344718 valid loss: 0.24794637
# 147 train loss: 0.34160298 valid loss: 0.3865382
# 148 train loss: 0.2594261 valid loss: 0.32378888
# 149 train loss: 0.30128527 valid loss: 0.37181348
# 150 train loss: 0.2385214 valid loss: 0.3154827
# 151 train loss: 0.24839717 valid loss: 0.27156734
# 152 train loss: 0.26660907 valid loss: 0.31686202
# 153 train loss: 0.26592556 valid loss: 0.29739496
# 154 train loss: 0.33288914 valid loss: 0.34078726
# 155 train loss: 0.34527302 valid loss: 0.3284789
# 156 train loss: 0.24209866 valid loss: 0.24063754
# 157 train loss: 0.35571453 valid loss: 0.38484937
# 158 train loss: 0.2621843 valid loss: 0.27684993
# 159 train loss: 0.30894485 valid loss: 0.38782057
# 160 train loss: 0.30800155 valid loss: 0.34794798
# 161 train loss: 0.32612896 valid loss: 0.3353421
# 162 train loss: 0.22755705 valid loss: 0.25673866
# 163 train loss: 0.26896527 valid loss: 0.28417692
# 164 train loss: 0.25528774 valid loss: 0.28334695
# 165 train loss: 0.263695 valid loss: 0.27533507
# 166 train loss: 0.28915626 valid loss: 0.28957134
# 167 train loss: 0.26256067 valid loss: 0.30944777
# 168 train loss: 0.32765713 valid loss: 0.36099023
# 169 train loss: 0.24903904 valid loss: 0.30309772
# 170 train loss: 0.23453534 valid loss: 0.2498891
# 171 train loss: 0.22677703 valid loss: 0.27445856
# 172 train loss: 0.32586116 valid loss: 0.34695506
# 173 train loss: 0.29260758 valid loss: 0.33796588
# 174 train loss: 0.24200065 valid loss: 0.283023
# 175 train loss: 0.2567858 valid loss: 0.27318615
# 176 train loss: 0.29894084 valid loss: 0.30038407
# 177 train loss: 0.2929919 valid loss: 0.3660999
# 178 train loss: 0.2633926 valid loss: 0.2889756
# 179 train loss: 0.24410841 valid loss: 0.2787379
# 180 train loss: 0.31537578 valid loss: 0.36378434
# 181 train loss: 0.34936133 valid loss: 0.4092922
# 182 train loss: 0.232476 valid loss: 0.25837356
# 183 train loss: 0.28925434 valid loss: 0.34620816
# 184 train loss: 0.25781336 valid loss: 0.26986435
# 185 train loss: 0.2834786 valid loss: 0.30409476
# 186 train loss: 0.22792864 valid loss: 0.22717915
# best loss: 0.22717915
# 187 train loss: 0.2669425 valid loss: 0.27822712
# 188 train loss: 0.295503 valid loss: 0.31979287
# 189 train loss: 0.27795076 valid loss: 0.32372326
# 190 train loss: 0.24269322 valid loss: 0.24240896
# 191 train loss: 0.24043323 valid loss: 0.25624087
# 192 train loss: 0.30613533 valid loss: 0.319188
# 193 train loss: 0.24399357 valid loss: 0.3014422
# 194 train loss: 0.26615945 valid loss: 0.26408947
# 195 train loss: 0.25434682 valid loss: 0.27728537
# 196 train loss: 0.234238 valid loss: 0.26518863
# 197 train loss: 0.24215083 valid loss: 0.2709937
# 198 train loss: 0.23569977 valid loss: 0.26317906
# 199 train loss: 0.23771492 valid loss: 0.23771833
# 200 train loss: 0.26635504 valid loss: 0.31842786
# 201 train loss: 0.3055368 valid loss: 0.34467852
# 202 train loss: 0.27166033 valid loss: 0.28901207
# 203 train loss: 0.31693783 valid loss: 0.35579205
# 204 train loss: 0.23368862 valid loss: 0.28099915
# 205 train loss: 0.2570864 valid loss: 0.2851713
# 206 train loss: 0.2477192 valid loss: 0.26580417
# 207 train loss: 0.29772943 valid loss: 0.32194483
# 208 train loss: 0.31493288 valid loss: 0.29680747
# 209 train loss: 0.24314141 valid loss: 0.27396742
# 210 train loss: 0.2712407 valid loss: 0.28771123
# 211 train loss: 0.25880045 valid loss: 0.29911953
# 212 train loss: 0.24175976 valid loss: 0.26259476
# 213 train loss: 0.31550163 valid loss: 0.3482742
# 214 train loss: 0.25632405 valid loss: 0.2929137
# 215 train loss: 0.24143818 valid loss: 0.28426698
# 216 train loss: 0.2530925 valid loss: 0.27208298
# 217 train loss: 0.3137749 valid loss: 0.29761258
# 218 train loss: 0.2795761 valid loss: 0.3731601
# 219 train loss: 0.2716377 valid loss: 0.2759012
# 220 train loss: 0.25634447 valid loss: 0.3146142
# 221 train loss: 0.35012674 valid loss: 0.32574436
# 222 train loss: 0.2922614 valid loss: 0.28009766
# 223 train loss: 0.2911529 valid loss: 0.34525663
# 224 train loss: 0.21808316 valid loss: 0.24341531
# 225 train loss: 0.22719714 valid loss: 0.26565185
# 226 train loss: 0.23156603 valid loss: 0.24016584
# 227 train loss: 0.34621376 valid loss: 0.4338763
# 228 train loss: 0.24485639 valid loss: 0.25949594
# 229 train loss: 0.24151492 valid loss: 0.27315784
# 230 train loss: 0.23556568 valid loss: 0.27494508
# 231 train loss: 0.26261732 valid loss: 0.26513407
# 232 train loss: 0.25370997 valid loss: 0.27096662
# 233 train loss: 0.26030207 valid loss: 0.27860937
# 234 train loss: 0.2214345 valid loss: 0.25642163
# 235 train loss: 0.22116871 valid loss: 0.24440193
# 236 train loss: 0.23645881 valid loss: 0.25549322
# 237 train loss: 0.25080782 valid loss: 0.26951644
# 238 train loss: 0.23933464 valid loss: 0.24425808
# 239 train loss: 0.2386387 valid loss: 0.27069017
# 240 train loss: 0.25453895 valid loss: 0.26017067
# 241 train loss: 0.24076177 valid loss: 0.2621281
# 242 train loss: 0.35571098 valid loss: 0.33757713
# 243 train loss: 0.2357491 valid loss: 0.2600005
# 244 train loss: 0.31578356 valid loss: 0.36443824
# 245 train loss: 0.29651564 valid loss: 0.3209011
# 246 train loss: 0.25326702 valid loss: 0.3082692
# 247 train loss: 0.24807428 valid loss: 0.30341887
# 248 train loss: 0.22434817 valid loss: 0.23235208
# 249 train loss: 0.23973878 valid loss: 0.2387674
# 250 train loss: 0.24620004 valid loss: 0.2648007
# 251 train loss: 0.31469142 valid loss: 0.35349375
# 252 train loss: 0.25404683 valid loss: 0.31013027
# 253 train loss: 0.25625008 valid loss: 0.24167645
# 254 train loss: 0.3994037 valid loss: 0.3109798
# 255 train loss: 0.39567614 valid loss: 0.43521595
# 256 train loss: 0.28127185 valid loss: 0.32408613
# 257 train loss: 0.2719099 valid loss: 0.2872173
# 258 train loss: 0.22410865 valid loss: 0.25748563
# 259 train loss: 0.24071789 valid loss: 0.27147382
# 260 train loss: 0.25272295 valid loss: 0.2869745
# 261 train loss: 0.26944965 valid loss: 0.29204202
# 262 train loss: 0.2733232 valid loss: 0.3078682
# 263 train loss: 0.26327994 valid loss: 0.27302855
# 264 train loss: 0.25347903 valid loss: 0.28026444
# 265 train loss: 0.27017573 valid loss: 0.29502007
# 266 train loss: 0.25610822 valid loss: 0.30003148
# 267 train loss: 0.23693101 valid loss: 0.25614437
# 268 train loss: 0.26805037 valid loss: 0.28924704
# 269 train loss: 0.27910247 valid loss: 0.3344208
# 270 train loss: 0.23860276 valid loss: 0.29026645
# 271 train loss: 0.24102235 valid loss: 0.2761555
# 272 train loss: 0.3348038 valid loss: 0.36608773
# 273 train loss: 0.29799777 valid loss: 0.38229024
# 274 train loss: 0.24348189 valid loss: 0.28903356
# 275 train loss: 0.29020253 valid loss: 0.32916743
# 276 train loss: 0.22794895 valid loss: 0.26502052
# 277 train loss: 0.22988333 valid loss: 0.2636325
# 278 train loss: 0.22590704 valid loss: 0.24691595
# 279 train loss: 0.23251241 valid loss: 0.24641396
# 280 train loss: 0.22405182 valid loss: 0.2483736
# 281 train loss: 0.25579834 valid loss: 0.2602705
# 282 train loss: 0.2379452 valid loss: 0.24015903
# 283 train loss: 0.24998374 valid loss: 0.2768173
# 284 train loss: 0.26952064 valid loss: 0.2956063
# 285 train loss: 0.23771466 valid loss: 0.24630478
# 286 train loss: 0.2295352 valid loss: 0.26132753
# 287 train loss: 0.23677823 valid loss: 0.2422191
# 288 train loss: 0.3166252 valid loss: 0.32382262
# 289 train loss: 0.28396273 valid loss: 0.31979424
# 290 train loss: 0.24220516 valid loss: 0.27957028
# 291 train loss: 0.26857948 valid loss: 0.28138638
# 292 train loss: 0.25367 valid loss: 0.2556807
# 293 train loss: 0.24443027 valid loss: 0.24989267
# 294 train loss: 0.28348657 valid loss: 0.29130867
# 295 train loss: 0.24508467 valid loss: 0.2343103
# 296 train loss: 0.23955715 valid loss: 0.287623
# 297 train loss: 0.24154477 valid loss: 0.2524869
# 298 train loss: 0.22776061 valid loss: 0.24159008
# 299 train loss: 0.23627828 valid loss: 0.24136853
# 300 train loss: 0.24022034 valid loss: 0.26992452
# 301 train loss: 0.2399599 valid loss: 0.26320925
# 302 train loss: 0.22538677 valid loss: 0.23955953
# 303 train loss: 0.25006753 valid loss: 0.2648834
# 304 train loss: 0.29130682 valid loss: 0.27948296
# 305 train loss: 0.26208365 valid loss: 0.27579108
# 306 train loss: 0.23780312 valid loss: 0.26004606
# 307 train loss: 0.22986896 valid loss: 0.23173304
# 308 train loss: 0.21742895 valid loss: 0.24971639
# 309 train loss: 0.23724303 valid loss: 0.26022756
# 310 train loss: 0.24404234 valid loss: 0.29478988
# 311 train loss: 0.24674565 valid loss: 0.32374704
# 312 train loss: 0.24123202 valid loss: 0.2910161
# 313 train loss: 0.23066369 valid loss: 0.24784999
# 314 train loss: 0.25772896 valid loss: 0.27347714
# 315 train loss: 0.24992687 valid loss: 0.26724944
# 316 train loss: 0.41584486 valid loss: 0.42334333
# 317 train loss: 0.26822075 valid loss: 0.26382926
# 318 train loss: 0.21829534 valid loss: 0.23449937
# 319 train loss: 0.22525625 valid loss: 0.25304207
# 320 train loss: 0.23533031 valid loss: 0.26618695
# 321 train loss: 0.22664475 valid loss: 0.2520439
# 322 train loss: 0.323769 valid loss: 0.3533297
# 323 train loss: 0.2305007 valid loss: 0.24192406
# 324 train loss: 0.25372592 valid loss: 0.26628083
# 325 train loss: 0.23006842 valid loss: 0.21821263
# best loss: 0.21821263
# 326 train loss: 0.2446877 valid loss: 0.23581299
# 327 train loss: 0.2518458 valid loss: 0.22930288
# 328 train loss: 0.26917344 valid loss: 0.3031832
# 329 train loss: 0.22558092 valid loss: 0.24351417
# 330 train loss: 0.32035384 valid loss: 0.27165222
# 331 train loss: 0.21921329 valid loss: 0.23116514
# 332 train loss: 0.23558244 valid loss: 0.2454805
# 333 train loss: 0.22400297 valid loss: 0.24800201
# 334 train loss: 0.26590842 valid loss: 0.26002213
# 335 train loss: 0.2177196 valid loss: 0.22312538
# 336 train loss: 0.26908523 valid loss: 0.30775684
# 337 train loss: 0.29059517 valid loss: 0.2478803
# 338 train loss: 0.26958048 valid loss: 0.26488954
# 339 train loss: 0.25710544 valid loss: 0.3023311
# 340 train loss: 0.23117782 valid loss: 0.24141267
# 341 train loss: 0.21912953 valid loss: 0.241399
# 342 train loss: 0.27768666 valid loss: 0.28136867
# 343 train loss: 0.24325535 valid loss: 0.26493353
# 344 train loss: 0.24755004 valid loss: 0.25557858
# 345 train loss: 0.22975184 valid loss: 0.2290023
# 346 train loss: 0.2680245 valid loss: 0.26865643
# 347 train loss: 0.25081858 valid loss: 0.2745176
# 348 train loss: 0.23710205 valid loss: 0.27612993
# 349 train loss: 0.24419637 valid loss: 0.2575006
# 350 train loss: 0.21634933 valid loss: 0.24026966
# 351 train loss: 0.24976242 valid loss: 0.2626956
# 352 train loss: 0.23753363 valid loss: 0.23982915
# 353 train loss: 0.22855827 valid loss: 0.26255313
# 354 train loss: 0.24868865 valid loss: 0.23826444
# 355 train loss: 0.27124423 valid loss: 0.27369222
# 356 train loss: 0.30757096 valid loss: 0.3272683
# 357 train loss: 0.25243255 valid loss: 0.29737127
# 358 train loss: 0.22618839 valid loss: 0.2510801
# 359 train loss: 0.21853511 valid loss: 0.24689668
# 360 train loss: 0.24970087 valid loss: 0.22546981
# 361 train loss: 0.2457242 valid loss: 0.2422575
# 362 train loss: 0.21593125 valid loss: 0.21751495
# best loss: 0.21751495
# 363 train loss: 0.37110555 valid loss: 0.34507528
# 364 train loss: 0.24813902 valid loss: 0.24763009
# 365 train loss: 0.27061495 valid loss: 0.26503143
# 366 train loss: 0.29380834 valid loss: 0.29870343
# 367 train loss: 0.22995853 valid loss: 0.24239835
# 368 train loss: 0.21944073 valid loss: 0.21982758
# 369 train loss: 0.21776468 valid loss: 0.22382265
# 370 train loss: 0.23251861 valid loss: 0.2553887
# 371 train loss: 0.22526863 valid loss: 0.23482975
# 372 train loss: 0.22518006 valid loss: 0.23941258
# 373 train loss: 0.24603976 valid loss: 0.23088332
# 374 train loss: 0.22238219 valid loss: 0.23814104
# 375 train loss: 0.2268943 valid loss: 0.2570874
# 376 train loss: 0.26198205 valid loss: 0.28034836
# 377 train loss: 0.26003423 valid loss: 0.27998906
# 378 train loss: 0.22915342 valid loss: 0.24604848
# 379 train loss: 0.24335669 valid loss: 0.28884184
# 380 train loss: 0.22607368 valid loss: 0.24864492
# 381 train loss: 0.22744253 valid loss: 0.26539025
# 382 train loss: 0.23161021 valid loss: 0.24864668
# 383 train loss: 0.22401409 valid loss: 0.22638947
# 384 train loss: 0.26157075 valid loss: 0.26821643
# 385 train loss: 0.28411922 valid loss: 0.31694466
# 386 train loss: 0.22477078 valid loss: 0.24819167
# 387 train loss: 0.25553074 valid loss: 0.30452207
# 388 train loss: 0.25331852 valid loss: 0.26429388
# 389 train loss: 0.23093739 valid loss: 0.26141357
# 390 train loss: 0.2202966 valid loss: 0.24043047
# 391 train loss: 0.22603758 valid loss: 0.25545052
# 392 train loss: 0.2720418 valid loss: 0.29280764
# 393 train loss: 0.21392815 valid loss: 0.22054514
# 394 train loss: 0.27218714 valid loss: 0.27719438
# 395 train loss: 0.21594428 valid loss: 0.240163
# 396 train loss: 0.22298113 valid loss: 0.2310728
# 397 train loss: 0.26477793 valid loss: 0.26178178
# 398 train loss: 0.22701575 valid loss: 0.22637805
# 399 train loss: 0.24522144 valid loss: 0.2538175
# 400 train loss: 0.22149004 valid loss: 0.2398605
# 401 train loss: 0.24456772 valid loss: 0.25034618
# 402 train loss: 0.23373196 valid loss: 0.24347654
# 403 train loss: 0.2451486 valid loss: 0.25404432
# 404 train loss: 0.23526014 valid loss: 0.23718247
# 405 train loss: 0.23255306 valid loss: 0.2475591
# 406 train loss: 0.22247598 valid loss: 0.24016622
# 407 train loss: 0.29702374 valid loss: 0.29736024
# 408 train loss: 0.29024005 valid loss: 0.29205897
# 409 train loss: 0.28868657 valid loss: 0.3326845
# 410 train loss: 0.25996447 valid loss: 0.2630006
# 411 train loss: 0.22825298 valid loss: 0.2299855
# 412 train loss: 0.22778329 valid loss: 0.23539084
# 413 train loss: 0.244799 valid loss: 0.2559781
# 414 train loss: 0.2145345 valid loss: 0.22520232
# 415 train loss: 0.27128255 valid loss: 0.29312593
# 416 train loss: 0.23868418 valid loss: 0.28108096
# 417 train loss: 0.342615 valid loss: 0.36224067
# 418 train loss: 0.23410434 valid loss: 0.26932067
# 419 train loss: 0.22450584 valid loss: 0.23751876
# 420 train loss: 0.34284312 valid loss: 0.3278927
# 421 train loss: 0.24839126 valid loss: 0.27446783
# 422 train loss: 0.2412072 valid loss: 0.28120723
# 423 train loss: 0.26183835 valid loss: 0.2831961
# 424 train loss: 0.22429422 valid loss: 0.23325962
# 425 train loss: 0.23809867 valid loss: 0.24012305
# 426 train loss: 0.22184247 valid loss: 0.23614217
# 427 train loss: 0.21864828 valid loss: 0.23513325
# 428 train loss: 0.22723761 valid loss: 0.24859947
# 429 train loss: 0.23558317 valid loss: 0.27022374
# 430 train loss: 0.2603398 valid loss: 0.26896632
# 431 train loss: 0.21427241 valid loss: 0.23020843
# 432 train loss: 0.33587468 valid loss: 0.3048725
# 433 train loss: 0.23282984 valid loss: 0.23683652
# 434 train loss: 0.25146303 valid loss: 0.26013473
# 435 train loss: 0.25450855 valid loss: 0.31709647
# 436 train loss: 0.22848064 valid loss: 0.26759428
# 437 train loss: 0.2378202 valid loss: 0.25852582
# 438 train loss: 0.21627529 valid loss: 0.23784156
# 439 train loss: 0.22519958 valid loss: 0.22561741
# 440 train loss: 0.22249232 valid loss: 0.24743998
# 441 train loss: 0.22357157 valid loss: 0.22812155
# 442 train loss: 0.24152362 valid loss: 0.28412598
# 443 train loss: 0.2189258 valid loss: 0.21979637
# 444 train loss: 0.30863327 valid loss: 0.2945779
# 445 train loss: 0.2697957 valid loss: 0.2604379
# 446 train loss: 0.24851276 valid loss: 0.2695898
# 447 train loss: 0.23430082 valid loss: 0.2539504
# 448 train loss: 0.25955924 valid loss: 0.24230608
# 449 train loss: 0.29523325 valid loss: 0.29120937
# 450 train loss: 0.22003546 valid loss: 0.24267754
# 451 train loss: 0.23516394 valid loss: 0.24332775
# 452 train loss: 0.25376898 valid loss: 0.30415267
# 453 train loss: 0.26482 valid loss: 0.27972096
# 454 train loss: 0.24343708 valid loss: 0.24822044
# 455 train loss: 0.286567 valid loss: 0.34954283
# 456 train loss: 0.23543385 valid loss: 0.2554543
# 457 train loss: 0.2256175 valid loss: 0.25051132
# 458 train loss: 0.20887324 valid loss: 0.22970185
# 459 train loss: 0.22597948 valid loss: 0.2213658
# 460 train loss: 0.25650474 valid loss: 0.24618529
# 461 train loss: 0.21801169 valid loss: 0.24871922
# 462 train loss: 0.20901774 valid loss: 0.22948536
# 463 train loss: 0.22394936 valid loss: 0.22724554
# 464 train loss: 0.23584497 valid loss: 0.257705
# 465 train loss: 0.21820441 valid loss: 0.22866188
# 466 train loss: 0.23107451 valid loss: 0.2484417
# 467 train loss: 0.2187412 valid loss: 0.24334607
# 468 train loss: 0.22386344 valid loss: 0.24727856
# 469 train loss: 0.22029488 valid loss: 0.259902
# 470 train loss: 0.26791176 valid loss: 0.3012073
# 471 train loss: 0.2680314 valid loss: 0.29171097
# 472 train loss: 0.22331056 valid loss: 0.22127266
# 473 train loss: 0.23855743 valid loss: 0.25643474
# 474 train loss: 0.2124601 valid loss: 0.23609883
# 475 train loss: 0.21900438 valid loss: 0.21769498
# 476 train loss: 0.27374122 valid loss: 0.3404651
# 477 train loss: 0.319812 valid loss: 0.313818
# 478 train loss: 0.22875912 valid loss: 0.2585531
# 479 train loss: 0.23103249 valid loss: 0.2350515
# 480 train loss: 0.2086575 valid loss: 0.22404376
# 481 train loss: 0.22291711 valid loss: 0.24352574
# 482 train loss: 0.26499066 valid loss: 0.258929
# 483 train loss: 0.23578385 valid loss: 0.25328395
# 484 train loss: 0.22716932 valid loss: 0.23500381
# 485 train loss: 0.22766846 valid loss: 0.23950419
# 486 train loss: 0.21520509 valid loss: 0.22314894
# 487 train loss: 0.21718019 valid loss: 0.20659105
# best loss: 0.20659105
# 488 train loss: 0.2612971 valid loss: 0.27443123
# 489 train loss: 0.24866283 valid loss: 0.23140825
# 490 train loss: 0.2244547 valid loss: 0.22004648
# 491 train loss: 0.25589722 valid loss: 0.26266947
# 492 train loss: 0.23484142 valid loss: 0.2539258
# 493 train loss: 0.22211294 valid loss: 0.23175348
# 494 train loss: 0.21807088 valid loss: 0.24500379
# 495 train loss: 0.207596 valid loss: 0.23022157
# 496 train loss: 0.37684643 valid loss: 0.48845178
# 497 train loss: 0.22390616 valid loss: 0.25920004
# 498 train loss: 0.20757401 valid loss: 0.22168104
# 499 train loss: 0.20891589 valid loss: 0.22375655
# 500 train loss: 0.229702 valid loss: 0.24334319
# 501 train loss: 0.20579427 valid loss: 0.21445394
# 502 train loss: 0.21042065 valid loss: 0.21515861
# 503 train loss: 0.27152723 valid loss: 0.28834188
# 504 train loss: 0.23958716 valid loss: 0.24794464
# 505 train loss: 0.23662673 valid loss: 0.25633374
# 506 train loss: 0.33442646 valid loss: 0.33590555
# 507 train loss: 0.25212342 valid loss: 0.26131332
# 508 train loss: 0.2652996 valid loss: 0.26219568
# 509 train loss: 0.21727341 valid loss: 0.24202968
# 510 train loss: 0.2581426 valid loss: 0.30833966
# 511 train loss: 0.27367973 valid loss: 0.31895652
# 512 train loss: 0.21954651 valid loss: 0.24404237
# 513 train loss: 0.20626135 valid loss: 0.19895989
# best loss: 0.19895989
# 514 train loss: 0.20567377 valid loss: 0.22616002
# 515 train loss: 0.20965122 valid loss: 0.21747269
# 516 train loss: 0.26271838 valid loss: 0.25208116
# 517 train loss: 0.2302633 valid loss: 0.23919478
# 518 train loss: 0.34909427 valid loss: 0.38470963
# 519 train loss: 0.28045386 valid loss: 0.37342787
# 520 train loss: 0.22862425 valid loss: 0.2617691
# 521 train loss: 0.21845599 valid loss: 0.26024303
# 522 train loss: 0.26978576 valid loss: 0.31263286
# 523 train loss: 0.21138382 valid loss: 0.22115886
# 524 train loss: 0.2397685 valid loss: 0.26290667
# 525 train loss: 0.21314803 valid loss: 0.21591616
# 526 train loss: 0.26299205 valid loss: 0.31457728
# 527 train loss: 0.23562331 valid loss: 0.25411868
# 528 train loss: 0.22394654 valid loss: 0.23311815
# 529 train loss: 0.23445404 valid loss: 0.23524827
# 530 train loss: 0.20719954 valid loss: 0.20646179
# 531 train loss: 0.21107768 valid loss: 0.23321928
# 532 train loss: 0.22686717 valid loss: 0.26544833
# 533 train loss: 0.26113144 valid loss: 0.2855952
# 534 train loss: 0.22526477 valid loss: 0.2153869
# 535 train loss: 0.23677397 valid loss: 0.2623816
# 536 train loss: 0.20667233 valid loss: 0.21825373
# 537 train loss: 0.22564432 valid loss: 0.24553291
# 538 train loss: 0.2635415 valid loss: 0.25181207
# 539 train loss: 0.22339024 valid loss: 0.21302253
# 540 train loss: 0.23073 valid loss: 0.2129642
# 541 train loss: 0.34234917 valid loss: 0.42969328
# 542 train loss: 0.25227827 valid loss: 0.2978544
# 543 train loss: 0.20962591 valid loss: 0.24687877
# 544 train loss: 0.21457191 valid loss: 0.2524089
# 545 train loss: 0.21449357 valid loss: 0.23880436
# 546 train loss: 0.20930706 valid loss: 0.22725523
# 547 train loss: 0.20817082 valid loss: 0.23522484
# 548 train loss: 0.21484515 valid loss: 0.21283844
# 549 train loss: 0.23052748 valid loss: 0.24812551
# 550 train loss: 0.25286412 valid loss: 0.23487289
# 551 train loss: 0.33200902 valid loss: 0.35315204
# 552 train loss: 0.2164861 valid loss: 0.2121629
# 553 train loss: 0.23032974 valid loss: 0.23040716
# 554 train loss: 0.2059947 valid loss: 0.22150218
# 555 train loss: 0.22573642 valid loss: 0.23877388
# 556 train loss: 0.21437326 valid loss: 0.23429753
# 557 train loss: 0.2486973 valid loss: 0.26929274
# 558 train loss: 0.24709354 valid loss: 0.24209958
# 559 train loss: 0.2748216 valid loss: 0.29069415
# 560 train loss: 0.2385121 valid loss: 0.24554369
# 561 train loss: 0.24914125 valid loss: 0.2659127
# 562 train loss: 0.25946414 valid loss: 0.28050783
# 563 train loss: 0.22185789 valid loss: 0.24093865
# 564 train loss: 0.20971347 valid loss: 0.21980569
# 565 train loss: 0.22799341 valid loss: 0.22274005
# 566 train loss: 0.22318333 valid loss: 0.23552525
# 567 train loss: 0.21454634 valid loss: 0.22205405
# 568 train loss: 0.22317189 valid loss: 0.22469893
# 569 train loss: 0.21464248 valid loss: 0.21773386
# 570 train loss: 0.21005668 valid loss: 0.21665964
# 571 train loss: 0.22653234 valid loss: 0.22950068
# 572 train loss: 0.2873999 valid loss: 0.28151774
# 573 train loss: 0.21798202 valid loss: 0.24286395
# 574 train loss: 0.22830059 valid loss: 0.23324768
# 575 train loss: 0.29152256 valid loss: 0.3065357
# 576 train loss: 0.2364423 valid loss: 0.24731497
# 577 train loss: 0.22103818 valid loss: 0.23275577
# 578 train loss: 0.23517814 valid loss: 0.24718376
# 579 train loss: 0.21706411 valid loss: 0.208245
# 580 train loss: 0.23335023 valid loss: 0.2670935
# 581 train loss: 0.24527676 valid loss: 0.25826487
# 582 train loss: 0.20335236 valid loss: 0.19859964
# best loss: 0.19859964
# 583 train loss: 0.22476208 valid loss: 0.22370547
# 584 train loss: 0.22140262 valid loss: 0.22395499
# 585 train loss: 0.22357546 valid loss: 0.21547501
# 586 train loss: 0.25841448 valid loss: 0.2815485
# 587 train loss: 0.3140816 valid loss: 0.32245317
# 588 train loss: 0.21647543 valid loss: 0.21103814
# 589 train loss: 0.23147456 valid loss: 0.21962495
# 590 train loss: 0.24481371 valid loss: 0.2341595
# 591 train loss: 0.21571913 valid loss: 0.22576271
# 592 train loss: 0.20881562 valid loss: 0.22057599
# 593 train loss: 0.21199836 valid loss: 0.22971706
# 594 train loss: 0.21649836 valid loss: 0.23868927
# 595 train loss: 0.23164329 valid loss: 0.2584139
# 596 train loss: 0.2017076 valid loss: 0.20664066
# 597 train loss: 0.2069586 valid loss: 0.23779158
# 598 train loss: 0.20842159 valid loss: 0.22908823
# 599 train loss: 0.21687034 valid loss: 0.2501028
# 600 train loss: 0.2076188 valid loss: 0.22607991
# 601 train loss: 0.20859453 valid loss: 0.20507549
# 602 train loss: 0.21326563 valid loss: 0.2180386
# 603 train loss: 0.22927234 valid loss: 0.24418783
# 604 train loss: 0.22712182 valid loss: 0.21840705
# 605 train loss: 0.28639793 valid loss: 0.2699129
# 606 train loss: 0.20958324 valid loss: 0.22257979
# 607 train loss: 0.22498342 valid loss: 0.22919731
# 608 train loss: 0.23061717 valid loss: 0.23412047
# 609 train loss: 0.2312631 valid loss: 0.25050068
# 610 train loss: 0.21367432 valid loss: 0.22560397
# 611 train loss: 0.22490816 valid loss: 0.22656396
# 612 train loss: 0.25692707 valid loss: 0.26633635
# 613 train loss: 0.26838243 valid loss: 0.3055062
# 614 train loss: 0.23384246 valid loss: 0.26747337
# 615 train loss: 0.22148514 valid loss: 0.24923784
# 616 train loss: 0.22699323 valid loss: 0.23162675
# 617 train loss: 0.24495272 valid loss: 0.2532939
# 618 train loss: 0.21352988 valid loss: 0.23785461
# 619 train loss: 0.2308515 valid loss: 0.2504336
# 620 train loss: 0.2116897 valid loss: 0.20993672
# 621 train loss: 0.25188613 valid loss: 0.27268285
# 622 train loss: 0.2262285 valid loss: 0.25590783
# 623 train loss: 0.2864128 valid loss: 0.30325726
# 624 train loss: 0.25349915 valid loss: 0.23268369
# 625 train loss: 0.22838679 valid loss: 0.23942605
# 626 train loss: 0.29717433 valid loss: 0.2934838
# 627 train loss: 0.24577577 valid loss: 0.24211307
# 628 train loss: 0.23641412 valid loss: 0.23402502
# 629 train loss: 0.2627117 valid loss: 0.29490474
# 630 train loss: 0.21871933 valid loss: 0.23445523
# 631 train loss: 0.2055314 valid loss: 0.2140091
# 632 train loss: 0.21099976 valid loss: 0.2068196
# 633 train loss: 0.284352 valid loss: 0.25504273
# 634 train loss: 0.25370657 valid loss: 0.26113594
# 635 train loss: 0.22111356 valid loss: 0.22898309
# 636 train loss: 0.20686978 valid loss: 0.22429775
# 637 train loss: 0.26572388 valid loss: 0.2710808
# 638 train loss: 0.22794949 valid loss: 0.23732287
# 639 train loss: 0.22248532 valid loss: 0.23931488
# 640 train loss: 0.21171121 valid loss: 0.23293744
# 641 train loss: 0.23678653 valid loss: 0.26690522
# 642 train loss: 0.21257502 valid loss: 0.223834
# 643 train loss: 0.20418508 valid loss: 0.20743099
# 644 train loss: 0.20934512 valid loss: 0.20481609
# 645 train loss: 0.2228369 valid loss: 0.22383721
# 646 train loss: 0.2615846 valid loss: 0.29816377
# 647 train loss: 0.24557553 valid loss: 0.27792814
# 648 train loss: 0.22334021 valid loss: 0.24481583
# 649 train loss: 0.28029248 valid loss: 0.27001423
# 650 train loss: 0.2970746 valid loss: 0.34915915
# 651 train loss: 0.26860178 valid loss: 0.2855585
# 652 train loss: 0.23856226 valid loss: 0.26130286
# 653 train loss: 0.33852822 valid loss: 0.32450524
# 654 train loss: 0.22148113 valid loss: 0.23468298
# 655 train loss: 0.24865212 valid loss: 0.23295693
# 656 train loss: 0.2096712 valid loss: 0.22301273
# 657 train loss: 0.2239904 valid loss: 0.23399541
# 658 train loss: 0.21792185 valid loss: 0.22140613
# 659 train loss: 0.21460678 valid loss: 0.21191753
# 660 train loss: 0.2790649 valid loss: 0.2811571
# 661 train loss: 0.26560968 valid loss: 0.29803658
# 662 train loss: 0.2434873 valid loss: 0.2363411
# 663 train loss: 0.22709905 valid loss: 0.25435787
# 664 train loss: 0.22323313 valid loss: 0.25119415
# 665 train loss: 0.21672095 valid loss: 0.2325778
# 666 train loss: 0.20931292 valid loss: 0.20765755
# 667 train loss: 0.20473212 valid loss: 0.22254908
# 668 train loss: 0.23153538 valid loss: 0.24579346
# 669 train loss: 0.21958363 valid loss: 0.25048023
# 670 train loss: 0.23187348 valid loss: 0.25620925
# 671 train loss: 0.27249897 valid loss: 0.30518216
# 672 train loss: 0.21549699 valid loss: 0.23502408
# 673 train loss: 0.21036294 valid loss: 0.22185133
# 674 train loss: 0.21043357 valid loss: 0.20313466
# 675 train loss: 0.28509438 valid loss: 0.32724446
# 676 train loss: 0.2129808 valid loss: 0.22131279
# 677 train loss: 0.21309762 valid loss: 0.21049497
# 678 train loss: 0.20458928 valid loss: 0.21943904
# 679 train loss: 0.25599563 valid loss: 0.2590558
# 680 train loss: 0.23149171 valid loss: 0.24168284
# 681 train loss: 0.28065974 valid loss: 0.29447496
# 682 train loss: 0.22306065 valid loss: 0.23615071
# 683 train loss: 0.21923277 valid loss: 0.24377522
# 684 train loss: 0.20577239 valid loss: 0.20718545
# 685 train loss: 0.24257077 valid loss: 0.2518822
# 686 train loss: 0.3437268 valid loss: 0.3276496
# 687 train loss: 0.21574175 valid loss: 0.2406148
# 688 train loss: 0.2275027 valid loss: 0.23633298
# 689 train loss: 0.2752993 valid loss: 0.2568724
# 690 train loss: 0.20839104 valid loss: 0.20616497
# 691 train loss: 0.22509125 valid loss: 0.24313602
# 692 train loss: 0.21443003 valid loss: 0.21692576
# 693 train loss: 0.20951414 valid loss: 0.21656333
# 694 train loss: 0.23869693 valid loss: 0.23713934
# 695 train loss: 0.26432794 valid loss: 0.26103383
# 696 train loss: 0.24336882 valid loss: 0.2744246
# 697 train loss: 0.21344219 valid loss: 0.21482228
# 698 train loss: 0.26450923 valid loss: 0.32188118
# 699 train loss: 0.24073614 valid loss: 0.25099072
# 700 train loss: 0.21588567 valid loss: 0.25440755
# 701 train loss: 0.2092738 valid loss: 0.22288083
# 702 train loss: 0.21672104 valid loss: 0.25274047
# 703 train loss: 0.23926243 valid loss: 0.24660593
# 704 train loss: 0.26120043 valid loss: 0.23525798
# 705 train loss: 0.20677994 valid loss: 0.23795052
# 706 train loss: 0.21901411 valid loss: 0.22843479
# 707 train loss: 0.24737963 valid loss: 0.25026292
# 708 train loss: 0.2058439 valid loss: 0.23605336
# 709 train loss: 0.20903765 valid loss: 0.20747167
# 710 train loss: 0.23993255 valid loss: 0.23356113
# 711 train loss: 0.20473965 valid loss: 0.20513429
# 712 train loss: 0.22936232 valid loss: 0.24653052
# 713 train loss: 0.20820296 valid loss: 0.21129613
# 714 train loss: 0.256382 valid loss: 0.26659018
# 715 train loss: 0.23867041 valid loss: 0.23225735
# 716 train loss: 0.27079582 valid loss: 0.24566041
# 717 train loss: 0.2221134 valid loss: 0.21854457
# 718 train loss: 0.24561848 valid loss: 0.23838495
# 719 train loss: 0.21269496 valid loss: 0.2064197
# 720 train loss: 0.2103439 valid loss: 0.22651538
# 721 train loss: 0.22923182 valid loss: 0.23079498
# 722 train loss: 0.21208438 valid loss: 0.20387305
# 723 train loss: 0.22627962 valid loss: 0.21839844
# 724 train loss: 0.2884573 valid loss: 0.3213783
# 725 train loss: 0.21095848 valid loss: 0.22951187
# 726 train loss: 0.21707168 valid loss: 0.22822705
# 727 train loss: 0.2257755 valid loss: 0.25737286
# 728 train loss: 0.21302466 valid loss: 0.2330831
# 729 train loss: 0.3137732 valid loss: 0.3343712
# 730 train loss: 0.27064526 valid loss: 0.3163117
# 731 train loss: 0.23090552 valid loss: 0.2598319
# 732 train loss: 0.24245042 valid loss: 0.24733625
# 733 train loss: 0.22060537 valid loss: 0.23920357
# 734 train loss: 0.22099864 valid loss: 0.20877911
# 735 train loss: 0.3504275 valid loss: 0.41588557
# 736 train loss: 0.2115644 valid loss: 0.21174528
# 737 train loss: 0.21327192 valid loss: 0.2073436
# 738 train loss: 0.2673848 valid loss: 0.26572648
# 739 train loss: 0.22281495 valid loss: 0.24378747
# 740 train loss: 0.21840616 valid loss: 0.23959759
# 741 train loss: 0.20436427 valid loss: 0.20979011
# 742 train loss: 0.24174033 valid loss: 0.25293556
# 743 train loss: 0.20771335 valid loss: 0.2053623
# 744 train loss: 0.21586248 valid loss: 0.21704563
# 745 train loss: 0.20201974 valid loss: 0.21013078
# 746 train loss: 0.22037235 valid loss: 0.21150258
# 747 train loss: 0.2020251 valid loss: 0.21403047
# 748 train loss: 0.22995098 valid loss: 0.22003546
# 749 train loss: 0.31009415 valid loss: 0.31519014
# 750 train loss: 0.2066088 valid loss: 0.21987623
# 751 train loss: 0.20179315 valid loss: 0.21283582
# 752 train loss: 0.22422557 valid loss: 0.2424869
# 753 train loss: 0.23446424 valid loss: 0.26595622
# 754 train loss: 0.24784952 valid loss: 0.21941179
# 755 train loss: 0.24320036 valid loss: 0.26950008
# 756 train loss: 0.24649715 valid loss: 0.24635762
# 757 train loss: 0.21543708 valid loss: 0.22989194
# 758 train loss: 0.22341762 valid loss: 0.24299452
# 759 train loss: 0.24849758 valid loss: 0.24592814
# 760 train loss: 0.21456592 valid loss: 0.23610082
# 761 train loss: 0.20825997 valid loss: 0.22271197
# 762 train loss: 0.22702645 valid loss: 0.25397506
# 763 train loss: 0.24158321 valid loss: 0.27672714
# 764 train loss: 0.20948975 valid loss: 0.24292082
# 765 train loss: 0.22048403 valid loss: 0.2246643
# 766 train loss: 0.21992527 valid loss: 0.23852715
# 767 train loss: 0.22662747 valid loss: 0.24184379
# 768 train loss: 0.25055227 valid loss: 0.2404024
# 769 train loss: 0.21157509 valid loss: 0.22787637
# 770 train loss: 0.230862 valid loss: 0.24274683
# 771 train loss: 0.23867813 valid loss: 0.23830406
# 772 train loss: 0.21049023 valid loss: 0.21787784
# 773 train loss: 0.21306184 valid loss: 0.22274029
# 774 train loss: 0.22828463 valid loss: 0.239061
# 775 train loss: 0.20887786 valid loss: 0.22898945
# 776 train loss: 0.25755262 valid loss: 0.24381274
# 777 train loss: 0.24560477 valid loss: 0.2285882
# 778 train loss: 0.29059243 valid loss: 0.2434431
# 779 train loss: 0.37626022 valid loss: 0.36390084
# 780 train loss: 0.2070034 valid loss: 0.20793205
# 781 train loss: 0.22109875 valid loss: 0.2152133
# 782 train loss: 0.22437178 valid loss: 0.23786408
# 783 train loss: 0.25071162 valid loss: 0.24764031
# 784 train loss: 0.21992004 valid loss: 0.20254034
# 785 train loss: 0.23388907 valid loss: 0.22066149
# 786 train loss: 0.2326989 valid loss: 0.243283
# 787 train loss: 0.20292264 valid loss: 0.21086736
# 788 train loss: 0.21408062 valid loss: 0.23078637
# 789 train loss: 0.2057039 valid loss: 0.2296985
# 790 train loss: 0.22625959 valid loss: 0.21871671
# 791 train loss: 0.21592644 valid loss: 0.20888533
# 792 train loss: 0.22513297 valid loss: 0.24341662
# 793 train loss: 0.20674798 valid loss: 0.21917804
# 794 train loss: 0.2133259 valid loss: 0.21949817
# 795 train loss: 0.2159256 valid loss: 0.21673241
# 796 train loss: 0.23301174 valid loss: 0.24176712
# 797 train loss: 0.21264769 valid loss: 0.21568021
# 798 train loss: 0.2059257 valid loss: 0.24028745
# 799 train loss: 0.21848582 valid loss: 0.23415647
# 800 train loss: 0.2118181 valid loss: 0.21761748
# 801 train loss: 0.21869348 valid loss: 0.21488598
# 802 train loss: 0.23495473 valid loss: 0.23149839
# 803 train loss: 0.21270084 valid loss: 0.22578809
# 804 train loss: 0.21444897 valid loss: 0.2310413
# 805 train loss: 0.2188552 valid loss: 0.19535361
# best loss: 0.19535361
# 806 train loss: 0.25928882 valid loss: 0.24943063
# 807 train loss: 0.21370488 valid loss: 0.22524475
# 808 train loss: 0.2400847 valid loss: 0.24064444
# 809 train loss: 0.26421413 valid loss: 0.30622905
# 810 train loss: 0.20205045 valid loss: 0.22017595
# 811 train loss: 0.22377987 valid loss: 0.21340235
# 812 train loss: 0.22616902 valid loss: 0.24714874
# 813 train loss: 0.20401524 valid loss: 0.20743467
# 814 train loss: 0.21062359 valid loss: 0.21068026
# 815 train loss: 0.21495761 valid loss: 0.21577454
# 816 train loss: 0.23906367 valid loss: 0.22212622
# 817 train loss: 0.21522872 valid loss: 0.2596863
# 818 train loss: 0.21366432 valid loss: 0.23955166
# 819 train loss: 0.21628919 valid loss: 0.23693086
# 820 train loss: 0.24404833 valid loss: 0.23256943
# 821 train loss: 0.24120763 valid loss: 0.23149231
# 822 train loss: 0.19897786 valid loss: 0.2095474
# 823 train loss: 0.2120512 valid loss: 0.20792283
# 824 train loss: 0.217842 valid loss: 0.21483694
# 825 train loss: 0.2198665 valid loss: 0.22873025
# 826 train loss: 0.23806754 valid loss: 0.22282216
# 827 train loss: 0.23252408 valid loss: 0.23166506
# 828 train loss: 0.22465414 valid loss: 0.21777384
# 829 train loss: 0.20598838 valid loss: 0.21479431
# 830 train loss: 0.2193604 valid loss: 0.23314439
# 831 train loss: 0.21925765 valid loss: 0.23747995
# 832 train loss: 0.20855501 valid loss: 0.21768683
# 833 train loss: 0.22125338 valid loss: 0.21013024
# 834 train loss: 0.21344209 valid loss: 0.21245745
# 835 train loss: 0.20575985 valid loss: 0.19997346
# 836 train loss: 0.22634803 valid loss: 0.24680099
# 837 train loss: 0.2071803 valid loss: 0.22204983
# 838 train loss: 0.21712333 valid loss: 0.21158493
# 839 train loss: 0.20807315 valid loss: 0.1976429
# 840 train loss: 0.21624932 valid loss: 0.2142399
# 841 train loss: 0.23380256 valid loss: 0.26411563
# 842 train loss: 0.34567165 valid loss: 0.41256475
# 843 train loss: 0.25660366 valid loss: 0.27137548
# 844 train loss: 0.21887034 valid loss: 0.21809174
# 845 train loss: 0.21636876 valid loss: 0.21939111
# 846 train loss: 0.22606769 valid loss: 0.22426152
# 847 train loss: 0.21903166 valid loss: 0.23620108
# 848 train loss: 0.25224313 valid loss: 0.22543529
# 849 train loss: 0.22117695 valid loss: 0.22831453
# 850 train loss: 0.21922588 valid loss: 0.21123151
# 851 train loss: 0.21629517 valid loss: 0.21326636
# 852 train loss: 0.20513533 valid loss: 0.21551016
# 853 train loss: 0.24850683 valid loss: 0.28367078
# 854 train loss: 0.22230805 valid loss: 0.2330097
# 855 train loss: 0.22405168 valid loss: 0.22894183
# 856 train loss: 0.21100152 valid loss: 0.2005311
# 857 train loss: 0.20766392 valid loss: 0.22146353
# 858 train loss: 0.30961257 valid loss: 0.33893675
# 859 train loss: 0.20464714 valid loss: 0.20569375
# 860 train loss: 0.25661823 valid loss: 0.2774198
# 861 train loss: 0.25873524 valid loss: 0.27309376
# 862 train loss: 0.22077754 valid loss: 0.23101883
# 863 train loss: 0.23343642 valid loss: 0.2571498
# 864 train loss: 0.20266426 valid loss: 0.22127223
# 865 train loss: 0.22151476 valid loss: 0.22936104
# 866 train loss: 0.20468892 valid loss: 0.20683712
# 867 train loss: 0.21438801 valid loss: 0.22996901
# 868 train loss: 0.24012093 valid loss: 0.2554
# 869 train loss: 0.206981 valid loss: 0.24405332
# 870 train loss: 0.20574726 valid loss: 0.22015588
# 871 train loss: 0.23145466 valid loss: 0.21806623
# 872 train loss: 0.20844008 valid loss: 0.20915794
# 873 train loss: 0.20645916 valid loss: 0.23627165
# 874 train loss: 0.22866161 valid loss: 0.2360897
# 875 train loss: 0.23817141 valid loss: 0.25743008
# 876 train loss: 0.21403913 valid loss: 0.220425
# 877 train loss: 0.2177087 valid loss: 0.20485234
# 878 train loss: 0.2034414 valid loss: 0.21423706
# 879 train loss: 0.2712513 valid loss: 0.31073487
# 880 train loss: 0.21298699 valid loss: 0.24829386
# 881 train loss: 0.20634946 valid loss: 0.20580135
# 882 train loss: 0.3494204 valid loss: 0.43793416
# 883 train loss: 0.23226553 valid loss: 0.2712363
# 884 train loss: 0.21092562 valid loss: 0.22887869
# 885 train loss: 0.23488216 valid loss: 0.23473814
# 886 train loss: 0.20796108 valid loss: 0.21377319
# 887 train loss: 0.21033162 valid loss: 0.23019505
# 888 train loss: 0.19667101 valid loss: 0.20915931
# 889 train loss: 0.24298124 valid loss: 0.23219085
# 890 train loss: 0.33273464 valid loss: 0.26432675
# 891 train loss: 0.2071405 valid loss: 0.21190086
# 892 train loss: 0.21847178 valid loss: 0.25753158
# 893 train loss: 0.2112371 valid loss: 0.2218939
# 894 train loss: 0.20206736 valid loss: 0.19805215
# 895 train loss: 0.20194708 valid loss: 0.21689393
# 896 train loss: 0.20650002 valid loss: 0.20716952
# 897 train loss: 0.22446616 valid loss: 0.20034462
# 898 train loss: 0.21525882 valid loss: 0.22197561
# 899 train loss: 0.20107886 valid loss: 0.21439782
# 900 train loss: 0.21548644 valid loss: 0.22737706
# 901 train loss: 0.22418526 valid loss: 0.23204936
# 902 train loss: 0.20178895 valid loss: 0.20370793
# 903 train loss: 0.21562651 valid loss: 0.22580454
# 904 train loss: 0.20549822 valid loss: 0.20624216
# 905 train loss: 0.21312869 valid loss: 0.22844687
# 906 train loss: 0.21245755 valid loss: 0.21665394
# 907 train loss: 0.22950134 valid loss: 0.24921595
# 908 train loss: 0.2503095 valid loss: 0.26806468
# 909 train loss: 0.20738496 valid loss: 0.21697128
# 910 train loss: 0.21029294 valid loss: 0.20445405
# 911 train loss: 0.2050193 valid loss: 0.21559452
# 912 train loss: 0.22545037 valid loss: 0.22722149
# 913 train loss: 0.23891337 valid loss: 0.24829128
# 914 train loss: 0.30775976 valid loss: 0.28025538
# 915 train loss: 0.21533689 valid loss: 0.22310485
# 916 train loss: 0.21309082 valid loss: 0.20875448
# 917 train loss: 0.2035759 valid loss: 0.20761144
# 918 train loss: 0.20533724 valid loss: 0.20264372
# 919 train loss: 0.20613141 valid loss: 0.2114132
# 920 train loss: 0.21398735 valid loss: 0.22748668
# 921 train loss: 0.2725141 valid loss: 0.29385135
# 922 train loss: 0.20243812 valid loss: 0.20558451
# 923 train loss: 0.21038704 valid loss: 0.20455869
# 924 train loss: 0.2327763 valid loss: 0.22714192
# 925 train loss: 0.2013331 valid loss: 0.20106249
# 926 train loss: 0.20880584 valid loss: 0.20946106
# 927 train loss: 0.21593744 valid loss: 0.21196927
# 928 train loss: 0.23887254 valid loss: 0.22239007
# 929 train loss: 0.22861719 valid loss: 0.2383769
# 930 train loss: 0.2012296 valid loss: 0.21922933
# 931 train loss: 0.22529641 valid loss: 0.23616245
# 932 train loss: 0.2589394 valid loss: 0.24918172
# 933 train loss: 0.21235022 valid loss: 0.21889909
# 934 train loss: 0.2092844 valid loss: 0.20243563
# 935 train loss: 0.1965807 valid loss: 0.20035689
# 936 train loss: 0.20936434 valid loss: 0.2237697
# 937 train loss: 0.2123334 valid loss: 0.21137173
# 938 train loss: 0.22753814 valid loss: 0.2272166
# 939 train loss: 0.20583019 valid loss: 0.21067396
# 940 train loss: 0.3016014 valid loss: 0.26868272
# 941 train loss: 0.2126585 valid loss: 0.22050145
# 942 train loss: 0.2032182 valid loss: 0.20622227
# 943 train loss: 0.23681794 valid loss: 0.26353833
# 944 train loss: 0.23157787 valid loss: 0.24226697
# 945 train loss: 0.20888713 valid loss: 0.1991224
# 946 train loss: 0.21929152 valid loss: 0.22011915
# 947 train loss: 0.21764402 valid loss: 0.23641449
# 948 train loss: 0.23039092 valid loss: 0.26988322
# 949 train loss: 0.20065822 valid loss: 0.20564274
# 950 train loss: 0.22682266 valid loss: 0.23326048
# 951 train loss: 0.21789546 valid loss: 0.2263331
# 952 train loss: 0.20638506 valid loss: 0.2168252
# 953 train loss: 0.22043806 valid loss: 0.23536274
# 954 train loss: 0.22857901 valid loss: 0.23030815
# 955 train loss: 0.212991 valid loss: 0.22885488
# 956 train loss: 0.20251848 valid loss: 0.2259606
# 957 train loss: 0.20026153 valid loss: 0.20289627
# 958 train loss: 0.20624226 valid loss: 0.2256694
# 959 train loss: 0.21343818 valid loss: 0.24787784
# 960 train loss: 0.36633968 valid loss: 0.35110205
# 961 train loss: 0.20736311 valid loss: 0.21488354
# 962 train loss: 0.21979289 valid loss: 0.21100216
# ...
# 1685 train loss: 0.19288783 valid loss: 0.19256783
# 1686 train loss: 0.2233356 valid loss: 0.23293643
# 1687 train loss: 0.24330752 valid loss: 0.2170612
# 1688 train loss: 0.1975315 valid loss: 0.19796245
# 1689 train loss: 0.20602569 valid loss: 0.2109966
# 1690 train loss: 0.20016463 valid loss: 0.21166818
# 1691 train loss: 0.19642627 valid loss: 0.20917967
# 1692 train loss: 0.23372935 valid loss: 0.27417323
# 1693 train loss: 0.21271291 valid loss: 0.21351744
# 1694 train loss: 0.2006807 valid loss: 0.1941669
# 1695 train loss: 0.2283906 valid loss: 0.23103914
# 1696 train loss: 0.21106379 valid loss: 0.21183208
# 1697 train loss: 0.1970817 valid loss: 0.19785562
# 1698 train loss: 0.220829 valid loss: 0.20493457
# 1699 train loss: 0.19885635 valid loss: 0.19678375
# 1700 train loss: 0.19621901 valid loss: 0.18665023
# 1701 train loss: 0.2088445 valid loss: 0.21764132
# 1702 train loss: 0.19679962 valid loss: 0.19593416
# 1703 train loss: 0.21186943 valid loss: 0.20706506
# 1704 train loss: 0.21834107 valid loss: 0.22195211
# 1705 train loss: 0.20780797 valid loss: 0.21383284
# 1706 train loss: 0.21821964 valid loss: 0.20342557
# 1707 train loss: 0.19616635 valid loss: 0.19429862
# 1708 train loss: 0.19598614 valid loss: 0.20005676
# 1709 train loss: 0.19353624 valid loss: 0.19717813
# 1710 train loss: 0.21373326 valid loss: 0.21942168
# 1711 train loss: 0.19321018 valid loss: 0.19145136
# 1712 train loss: 0.21908681 valid loss: 0.21555229
# 1713 train loss: 0.19602078 valid loss: 0.19782802
# 1714 train loss: 0.21689656 valid loss: 0.22375973
# 1715 train loss: 0.19253032 valid loss: 0.19283353
# 1716 train loss: 0.22788396 valid loss: 0.22757827
# 1717 train loss: 0.2080817 valid loss: 0.20971438
# 1718 train loss: 0.1989899 valid loss: 0.20456593
# 1719 train loss: 0.19495904 valid loss: 0.2052611
# 1720 train loss: 0.2750108 valid loss: 0.28112304
# 1721 train loss: 0.20017129 valid loss: 0.20066816
# 1722 train loss: 0.19451334 valid loss: 0.18477006
# 1723 train loss: 0.18946552 valid loss: 0.18495643
# 1724 train loss: 0.2001903 valid loss: 0.20137873
# 1725 train loss: 0.20512013 valid loss: 0.19360188
# 1726 train loss: 0.21342301 valid loss: 0.21806136
# 1727 train loss: 0.19916913 valid loss: 0.20915109
# 1728 train loss: 0.1995805 valid loss: 0.2077853
# 1729 train loss: 0.22167057 valid loss: 0.24430057
# 1730 train loss: 0.19762836 valid loss: 0.20884553
# 1731 train loss: 0.27757204 valid loss: 0.25936753
# 1732 train loss: 0.1951633 valid loss: 0.20057565
# 1733 train loss: 0.2085124 valid loss: 0.20581272
# 1734 train loss: 0.20458159 valid loss: 0.21738504
# 1735 train loss: 0.19440494 valid loss: 0.19554965
# 1736 train loss: 0.20936294 valid loss: 0.21451928
# 1737 train loss: 0.18959638 valid loss: 0.18562807
# 1738 train loss: 0.22599867 valid loss: 0.22535032
# 1739 train loss: 0.22341691 valid loss: 0.24118444
# 1740 train loss: 0.19709085 valid loss: 0.18697365
# 1741 train loss: 0.20120218 valid loss: 0.18831968
# 1742 train loss: 0.23289894 valid loss: 0.25312498
# 1743 train loss: 0.21720362 valid loss: 0.2234878
# 1744 train loss: 0.22441927 valid loss: 0.20228045
# 1745 train loss: 0.19692284 valid loss: 0.1964377
# 1746 train loss: 0.20097466 valid loss: 0.21244812
# 1747 train loss: 0.1909041 valid loss: 0.18730092
# 1748 train loss: 0.19906427 valid loss: 0.20832932
# 1749 train loss: 0.1991077 valid loss: 0.19302304
# 1750 train loss: 0.19753607 valid loss: 0.1970138
# 1751 train loss: 0.22826228 valid loss: 0.25577965
# 1752 train loss: 0.21155222 valid loss: 0.20793977
# 1753 train loss: 0.19959144 valid loss: 0.20703897
# 1754 train loss: 0.20653015 valid loss: 0.21354948
# 1755 train loss: 0.20584007 valid loss: 0.2106145
# 1756 train loss: 0.19267634 valid loss: 0.19653757
# 1757 train loss: 0.22010499 valid loss: 0.20962128
# 1758 train loss: 0.19968513 valid loss: 0.19883129
# 1759 train loss: 0.19524838 valid loss: 0.201154
# 1760 train loss: 0.20926304 valid loss: 0.22040333
# 1761 train loss: 0.19758354 valid loss: 0.2049457
# 1762 train loss: 0.21591416 valid loss: 0.22636077
# 1763 train loss: 0.22329614 valid loss: 0.20321609
# 1764 train loss: 0.20575845 valid loss: 0.20436187
# 1765 train loss: 0.2000416 valid loss: 0.20490296
# 1766 train loss: 0.19035819 valid loss: 0.1991879
# 1767 train loss: 0.2002582 valid loss: 0.20933099
# 1768 train loss: 0.20905028 valid loss: 0.21167609
# 1769 train loss: 0.19836287 valid loss: 0.19382545
# 1770 train loss: 0.21480362 valid loss: 0.22575952
# 1771 train loss: 0.23813233 valid loss: 0.20677401
# 1772 train loss: 0.18862905 valid loss: 0.1949548
# 1773 train loss: 0.21563399 valid loss: 0.22530916
# 1774 train loss: 0.24749318 valid loss: 0.23467034
# 1775 train loss: 0.19285144 valid loss: 0.19075343
# 1776 train loss: 0.20017734 valid loss: 0.19257243
# 1777 train loss: 0.19516614 valid loss: 0.19638109
# 1778 train loss: 0.19908525 valid loss: 0.20336998
# 1779 train loss: 0.26365542 valid loss: 0.22018647
# 1780 train loss: 0.21463645 valid loss: 0.22220804
# 1781 train loss: 0.22685492 valid loss: 0.19934303
# 1782 train loss: 0.19869944 valid loss: 0.21015626
# 1783 train loss: 0.20555519 valid loss: 0.21541055
# 1784 train loss: 0.19272491 valid loss: 0.19973947
# 1785 train loss: 0.19099115 valid loss: 0.19622937
# 1786 train loss: 0.21080731 valid loss: 0.21967927
# 1787 train loss: 0.21236016 valid loss: 0.21563785
# 1788 train loss: 0.21480577 valid loss: 0.21022429
# 1789 train loss: 0.19477476 valid loss: 0.19683409
# 1790 train loss: 0.18968332 valid loss: 0.19648787
# 1791 train loss: 0.19064519 valid loss: 0.20313261
# 1792 train loss: 0.20152171 valid loss: 0.20154952
# 1793 train loss: 0.20226882 valid loss: 0.21308601
# 1794 train loss: 0.19193618 valid loss: 0.19540535
# 1795 train loss: 0.19627297 valid loss: 0.20504507
# 1796 train loss: 0.19198263 valid loss: 0.19491759
# 1797 train loss: 0.19211558 valid loss: 0.1992087
# 1798 train loss: 0.23850378 valid loss: 0.22581281
# 1799 train loss: 0.1959432 valid loss: 0.19273157
# 1800 train loss: 0.21184985 valid loss: 0.19562516
# 1801 train loss: 0.19121686 valid loss: 0.1912942
# 1802 train loss: 0.1961855 valid loss: 0.20156993
# 1803 train loss: 0.21322326 valid loss: 0.20363778
# 1804 train loss: 0.20858686 valid loss: 0.2048645
# 1805 train loss: 0.20986074 valid loss: 0.20565645
# 1806 train loss: 0.1997126 valid loss: 0.20792449
# 1807 train loss: 0.20288596 valid loss: 0.20808794
# 1808 train loss: 0.22923605 valid loss: 0.21925077
# 1809 train loss: 0.1987032 valid loss: 0.19981882
# 1810 train loss: 0.20614766 valid loss: 0.21709181
# 1811 train loss: 0.19553594 valid loss: 0.19443448
# 1812 train loss: 0.2050883 valid loss: 0.22447908
# 1813 train loss: 0.22476877 valid loss: 0.22626497
# 1814 train loss: 0.19946201 valid loss: 0.19165725
# 1815 train loss: 0.1954385 valid loss: 0.19247857
# 1816 train loss: 0.20544054 valid loss: 0.1864253
# 1817 train loss: 0.20683706 valid loss: 0.20295678
# 1818 train loss: 0.20408228 valid loss: 0.2116457
# 1819 train loss: 0.21667804 valid loss: 0.21571618
# 1820 train loss: 0.21232496 valid loss: 0.21863018
# 1821 train loss: 0.20268278 valid loss: 0.19713615
# 1822 train loss: 0.22293594 valid loss: 0.219472
# 1823 train loss: 0.19697103 valid loss: 0.19105129
# 1824 train loss: 0.21749157 valid loss: 0.21634373
# 1825 train loss: 0.22948337 valid loss: 0.22988974
# 1826 train loss: 0.1911628 valid loss: 0.18948182
# 1827 train loss: 0.2140483 valid loss: 0.21198073
# 1828 train loss: 0.19177678 valid loss: 0.20027119
# 1829 train loss: 0.21951325 valid loss: 0.20947266
# 1830 train loss: 0.19544813 valid loss: 0.19241862
# 1831 train loss: 0.19939186 valid loss: 0.21452156
# 1832 train loss: 0.24629097 valid loss: 0.22943857
# 1833 train loss: 0.19698656 valid loss: 0.19325893
# 1834 train loss: 0.20033976 valid loss: 0.19895078
# 1835 train loss: 0.21300039 valid loss: 0.2120596
# 1836 train loss: 0.19743496 valid loss: 0.19625372
# 1837 train loss: 0.19863282 valid loss: 0.20459327
# 1838 train loss: 0.19994175 valid loss: 0.20511867
# 1839 train loss: 0.22617367 valid loss: 0.22370699
# 1840 train loss: 0.19697884 valid loss: 0.19593577
# 1841 train loss: 0.20220426 valid loss: 0.20766103
# 1842 train loss: 0.20174743 valid loss: 0.20020647
# 1843 train loss: 0.22904423 valid loss: 0.20442465
# 1844 train loss: 0.2295661 valid loss: 0.21519853
# 1845 train loss: 0.19726002 valid loss: 0.19837691
# 1846 train loss: 0.21887931 valid loss: 0.21181203
# 1847 train loss: 0.2015063 valid loss: 0.19978026
# 1848 train loss: 0.21629779 valid loss: 0.22757968
# 1849 train loss: 0.2058975 valid loss: 0.23180029
# 1850 train loss: 0.24781965 valid loss: 0.2543208
# 1851 train loss: 0.20691997 valid loss: 0.21694341
# 1852 train loss: 0.22299652 valid loss: 0.2351443
# 1853 train loss: 0.19658348 valid loss: 0.19337267
# 1854 train loss: 0.2092209 valid loss: 0.21103191
# 1855 train loss: 0.1939652 valid loss: 0.20088308
# 1856 train loss: 0.20176609 valid loss: 0.21685442
# 1857 train loss: 0.1937011 valid loss: 0.19567099
# 1858 train loss: 0.20742448 valid loss: 0.21206932
# 1859 train loss: 0.22600496 valid loss: 0.24064633
# 1860 train loss: 0.21037422 valid loss: 0.22584012
# 1861 train loss: 0.21095592 valid loss: 0.2111893
# 1862 train loss: 0.25048223 valid loss: 0.2758754
# 1863 train loss: 0.2171264 valid loss: 0.20182604
# 1864 train loss: 0.19967318 valid loss: 0.20890623
# 1865 train loss: 0.19098906 valid loss: 0.18671851
# 1866 train loss: 0.19442616 valid loss: 0.19439597
# 1867 train loss: 0.19343211 valid loss: 0.19650224
# 1868 train loss: 0.22467315 valid loss: 0.20680127
# 1869 train loss: 0.19449076 valid loss: 0.19210045
# 1870 train loss: 0.24216539 valid loss: 0.23354751
# 1871 train loss: 0.19799432 valid loss: 0.20136273
# 1872 train loss: 0.23910604 valid loss: 0.23541015
# 1873 train loss: 0.19531976 valid loss: 0.18302041
# best loss: 0.18302041
# 1874 train loss: 0.20027062 valid loss: 0.1994688
# 1875 train loss: 0.20859405 valid loss: 0.23305902
# 1876 train loss: 0.31372172 valid loss: 0.33112848
# 1877 train loss: 0.20040399 valid loss: 0.1846371
# 1878 train loss: 0.19314821 valid loss: 0.19572297
# 1879 train loss: 0.19434749 valid loss: 0.20533346
# 1880 train loss: 0.2054377 valid loss: 0.23508154
# 1881 train loss: 0.19743311 valid loss: 0.20185523
# 1882 train loss: 0.2181991 valid loss: 0.248866
# 1883 train loss: 0.19601402 valid loss: 0.19491959
# 1884 train loss: 0.1971043 valid loss: 0.21999176
# 1885 train loss: 0.21508935 valid loss: 0.21472095
# 1886 train loss: 0.18848073 valid loss: 0.18755038
# 1887 train loss: 0.19751653 valid loss: 0.19445819
# 1888 train loss: 0.19217686 valid loss: 0.18938471
# 1889 train loss: 0.19096074 valid loss: 0.18922319
# 1890 train loss: 0.19532885 valid loss: 0.18667647
# 1891 train loss: 0.19338371 valid loss: 0.19936721
# 1892 train loss: 0.18957792 valid loss: 0.18621768
# 1893 train loss: 0.22982289 valid loss: 0.21876213
# 1894 train loss: 0.20681708 valid loss: 0.23208657
# 1895 train loss: 0.19727892 valid loss: 0.20350857
# 1896 train loss: 0.20527221 valid loss: 0.20246375
# 1897 train loss: 0.21129286 valid loss: 0.22366977
# 1898 train loss: 0.19001664 valid loss: 0.19569089
# 1899 train loss: 0.19614333 valid loss: 0.19465415
# 1900 train loss: 0.20989469 valid loss: 0.21105957
# 1901 train loss: 0.19146255 valid loss: 0.20990151
# 1902 train loss: 0.20121753 valid loss: 0.22104946
# 1903 train loss: 0.1965275 valid loss: 0.19545603
# 1904 train loss: 0.19575584 valid loss: 0.20032425
# 1905 train loss: 0.19166292 valid loss: 0.19640148
# 1906 train loss: 0.1897731 valid loss: 0.21417722
# 1907 train loss: 0.20345035 valid loss: 0.20980658
# 1908 train loss: 0.19190916 valid loss: 0.20506717
# 1909 train loss: 0.18872695 valid loss: 0.20364806
# 1910 train loss: 0.19095065 valid loss: 0.20409779
# 1911 train loss: 0.20685787 valid loss: 0.21031186
# 1912 train loss: 0.19643602 valid loss: 0.20685674
# 1913 train loss: 0.19731855 valid loss: 0.20282087
# 1914 train loss: 0.1950396 valid loss: 0.18949054
# 1915 train loss: 0.20990321 valid loss: 0.22327861
# 1916 train loss: 0.1879602 valid loss: 0.18560494
# 1917 train loss: 0.22370312 valid loss: 0.2268134
# 1918 train loss: 0.20023793 valid loss: 0.20880015
# 1919 train loss: 0.21613994 valid loss: 0.22982065
# 1920 train loss: 0.19237654 valid loss: 0.20183472
# 1921 train loss: 0.22168458 valid loss: 0.21027803
# 1922 train loss: 0.20196438 valid loss: 0.20034622
# 1923 train loss: 0.20856982 valid loss: 0.23444802
# 1924 train loss: 0.23390602 valid loss: 0.22263813
# 1925 train loss: 0.19191867 valid loss: 0.19573732
# 1926 train loss: 0.20621109 valid loss: 0.20803185
# 1927 train loss: 0.19642189 valid loss: 0.19861741
# 1928 train loss: 0.20217279 valid loss: 0.20371841
# 1929 train loss: 0.19512637 valid loss: 0.19882916
# 1930 train loss: 0.19802181 valid loss: 0.1982094
# 1931 train loss: 0.19567959 valid loss: 0.21921179
# 1932 train loss: 0.19356538 valid loss: 0.20293814
# 1933 train loss: 0.20691164 valid loss: 0.20861128
# 1934 train loss: 0.19042934 valid loss: 0.20248154
# 1935 train loss: 0.21301217 valid loss: 0.22435111
# 1936 train loss: 0.19307016 valid loss: 0.19816642
# 1937 train loss: 0.19731082 valid loss: 0.20392026
# 1938 train loss: 0.20841226 valid loss: 0.19891626
# 1939 train loss: 0.1945339 valid loss: 0.21283716
# 1940 train loss: 0.19761325 valid loss: 0.20522983
# 1941 train loss: 0.22377598 valid loss: 0.24553034
# 1942 train loss: 0.20209989 valid loss: 0.1898161
# 1943 train loss: 0.19190937 valid loss: 0.20986384
# 1944 train loss: 0.20207204 valid loss: 0.20121302
# 1945 train loss: 0.19397044 valid loss: 0.20439991
# 1946 train loss: 0.20453198 valid loss: 0.23100257
# 1947 train loss: 0.22171752 valid loss: 0.26209345
# 1948 train loss: 0.2011258 valid loss: 0.21431378
# 1949 train loss: 0.19324733 valid loss: 0.19622849
# 1950 train loss: 0.2093457 valid loss: 0.21702334
# 1951 train loss: 0.20158026 valid loss: 0.200857
# 1952 train loss: 0.20235406 valid loss: 0.21062927
# 1953 train loss: 0.199379 valid loss: 0.2113909
# 1954 train loss: 0.19443399 valid loss: 0.1899387
# 1955 train loss: 0.21823147 valid loss: 0.23208362
# 1956 train loss: 0.19418061 valid loss: 0.18814942
# 1957 train loss: 0.19700252 valid loss: 0.20598252
# 1958 train loss: 0.20722021 valid loss: 0.22145444
# 1959 train loss: 0.19474204 valid loss: 0.1848056
# 1960 train loss: 0.19784208 valid loss: 0.20660734
# 1961 train loss: 0.21985088 valid loss: 0.22900847
# 1962 train loss: 0.24132295 valid loss: 0.2567248
# 1963 train loss: 0.22484717 valid loss: 0.22831827
# 1964 train loss: 0.21451162 valid loss: 0.19457184
# 1965 train loss: 0.19364622 valid loss: 0.2065245
# 1966 train loss: 0.19956866 valid loss: 0.18604851
# 1967 train loss: 0.2002642 valid loss: 0.21839339
# 1968 train loss: 0.19672671 valid loss: 0.1999146
# 1969 train loss: 0.1918645 valid loss: 0.18600266
# 1970 train loss: 0.20469648 valid loss: 0.21715981
# 1971 train loss: 0.24818555 valid loss: 0.22218364
# 1972 train loss: 0.19162516 valid loss: 0.19589204
# 1973 train loss: 0.19048966 valid loss: 0.19786741
# 1974 train loss: 0.20059519 valid loss: 0.20300703
# 1975 train loss: 0.19376399 valid loss: 0.19437529
# 1976 train loss: 0.19649251 valid loss: 0.19543312
# 1977 train loss: 0.19850317 valid loss: 0.2021909
# 1978 train loss: 0.21205351 valid loss: 0.21527527
# 1979 train loss: 0.2042283 valid loss: 0.2094956
# 1980 train loss: 0.19913451 valid loss: 0.19855028
# 1981 train loss: 0.19823276 valid loss: 0.20661496
# 1982 train loss: 0.21745649 valid loss: 0.23386745
# 1983 train loss: 0.19206762 valid loss: 0.19440234
# 1984 train loss: 0.19573516 valid loss: 0.2023314
# 1985 train loss: 0.21650353 valid loss: 0.20655477
# 1986 train loss: 0.19009954 valid loss: 0.1851896
# 1987 train loss: 0.21850601 valid loss: 0.21761584
# 1988 train loss: 0.19860788 valid loss: 0.18684599
# 1989 train loss: 0.19338137 valid loss: 0.18440804
# 1990 train loss: 0.19760153 valid loss: 0.20072404
# 1991 train loss: 0.19185147 valid loss: 0.19994652
# 1992 train loss: 0.20348111 valid loss: 0.20104882
# 1993 train loss: 0.20998384 valid loss: 0.19672364
# 1994 train loss: 0.20868772 valid loss: 0.2231298
# 1995 train loss: 0.19384901 valid loss: 0.20095776
# 1996 train loss: 0.2575005 valid loss: 0.23447129
# 1997 train loss: 0.19856331 valid loss: 0.19032271
# 1998 train loss: 0.19551596 valid loss: 0.19632638
# 1999 train loss: 0.19068484 valid loss: 0.19562656

# %%
os.remove(checkpoint_epoch_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-33514d26c96d> in <module>
# ----> 1 os.remove(checkpoint_epoch_path)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\kicjo\\Desktop\\my-anns\\nuclei\\nuclei-updated-2-inputs-2-outputs-forked\\sinus_tmp\\sinus_full_model.ckpt.epoch'

# %% [markdown]
# # Predictions

# %%
with tf.Session() as sess:
    saver.restore(sess, final_model_path)
    test_mse = mse.eval(feed_dict={X_node: X_test, y_node: y_test})
    print(test_mse)
    predictions_left = y_pred_left.eval(feed_dict={X_node: X_test, y_node: y_test})
    predictions_right = y_pred_right.eval(feed_dict={X_node: X_test, y_node: y_test})
# Out:
# 0.21574585

# %%
print(predictions_left.shape)
print(predictions_right.shape)
# Out:
# (468, 1)
# (468, 1)

# %% [markdown]
# # Concatenate predictions

# %%
predictions = np.concatenate((predictions_left, predictions_right), axis=1)
predictions.shape
# Out:
# (468, 2)

# %% [markdown]
# # Plot  _first (0th)_ output column of _predictions_

# %%
y_new_inverse = y_scaler.inverse_transform(predictions)
x_test_inverse = x_scaler.inverse_transform(X_test)

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = y_new_inverse[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
y_test_o.shape[0]
# Out:
# 468

# %%
plt.scatter(range(y_new_inverse.shape[0]), y_new_inverse[:,0], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot _first 0th_ column of TEST set

# %%
plt.scatter(range(y_test_o.shape[0]), y_test_o[:,0], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = X_test_o[:,0]
ys = X_test_o[:,1]
zs = y_test_o[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Plot second column of Predictions

# %%
y_new_inverse = y_scaler.inverse_transform(predictions)
x_test_inverse = x_scaler.inverse_transform(X_test)

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = y_new_inverse[:,1]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
plt.scatter(range(y_new_inverse.shape[0]), y_new_inverse[:,1], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot second column of TEST set

# %%
plt.scatter(range(y_test_o.shape[0]), y_test_o[:,1], s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = X_test_o[:,0]
ys = X_test_o[:,1]
zs = y_test_o[:,1]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.15)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %% [markdown]
# # Calculate _diff_ and _diff_abs_ (no distinction for columns)

# %%
#diff = np.square((y_new_inverse - y_test_o) / y_test_o)
substraction = y_new_inverse - y_test_o
diff = np.divide( substraction , y_test_o, out = substraction, where = y_test_o != 0)
diff_abs = y_new_inverse - y_test_o

# %%
diff_df = pd.DataFrame(data={'rel diff mass': diff[:,0],
                            'rel diff sep': diff[:,1],
                            'abs diff mass' : diff_abs[:,0],
                             'abs diff sep' : diff_abs[:,1],
                            })
diff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 4 columns):
# rel diff mass    468 non-null float64
# rel diff sep     468 non-null float64
# abs diff mass    468 non-null float64
# abs diff sep     468 non-null float64
# dtypes: float64(4)
# memory usage: 14.7 KB

# %% [markdown]
# # Replace inf and -inf with Nan, then drop the nans

# %%
diff_df = diff_df.replace([np.inf, -np.inf], np.nan)

# %%
print(diff_df.isnull().values.any())
print(diff_df.isnull().sum())
diff_df = diff_df.dropna()
# Out:
# False
# rel diff mass    0
# rel diff sep     0
# abs diff mass    0
# abs diff sep     0
# dtype: int64

# %%
diff_df.describe()
# Out:
#        rel diff mass  rel diff sep  abs diff mass  abs diff sep
# count     468.000000    468.000000     468.000000    468.000000
# mean       -0.390628      0.041162       0.071579      0.131089
# std         6.278493      0.650216       0.094092      1.331053
# min      -127.807673    -12.013827      -0.270639     -6.510848
# 25%        -0.144151     -0.103781       0.039299     -0.909280
# 50%        -0.111132      0.046153       0.060724      0.301317
# 75%        -0.063227      0.165252       0.082294      1.184356
# max        11.253574      4.600047       1.556199      7.656963

# %% [markdown]
# # Plot the relative diff of the first column

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111,projection='3d')

xs = x_test_inverse[:,0]
ys = x_test_inverse[:,1]
zs = diff_df['rel diff mass']# diff[:,0]

colmap = cm.ScalarMappable(cmap=cm.get_cmap("jet"))
colmap.set_array(zs)

yg = ax.scatter(xs, ys, zs, c=cm.get_cmap("jet")(zs/max(zs)), marker='^',alpha=0.5)
cb = fig.colorbar(colmap)

ax.set_xlabel('N')
ax.set_ylabel('Z')
ax.set_zlabel('D')


plt.show()

# %%
#%matplotlib notebook

# %%
vals = diff_df['rel diff mass'].to_numpy()
print(vals.shape)
print(vals.shape[0])
# Out:
# (468,)
# 468

# %%
#plt.scatter(iterate_x, diff[:,0], s=5)

plt.scatter(range(vals.shape[0]),vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot the relative diff of the second column

# %%
vals = diff_df['rel diff sep'].to_numpy()
print(vals.shape)
print(vals.shape[0])
# Out:
# (468,)
# 468

# %%
plt.scatter(range(vals.shape[0]), vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Diff ABSOLUTE of first column

# %%
vals = diff_df['abs diff mass'].to_numpy()
print(vals.shape)
range_x = range(vals.shape[0])
# Out:
# (468,)

# %%
plt.scatter(range_x,vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Diff ABSOLUTE of second column

# %%
vals = diff_df['abs diff sep'].to_numpy()
print(vals.shape)
range_x = range(vals.shape[0])
# Out:
# (468,)

# %%
plt.scatter(range_x,vals, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()
